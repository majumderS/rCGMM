# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import numpy as np
# Set the font size
plt.rcParams['font.size'] = 20
# font = {'family' : 'normal',
#         'size'   : 30,
#        'weight' : 'bold'}
path = "/home/subhasree/IISC_Bangalore/My_PhD_Studies/Lab_work/CG_Models//data_collect_AA_vs_CG"

# %%
#EQUILIBRATION

# %%
#MEAN
#potential_energy
pot_pirna_aa = [-129182.2301,-112653.5869,-536210.199,-459422.0863,-138350.2545]
pot_mirna_aa = [-431578.768,-579400.5423,-323957.611,-492047.3646,-2399322.415,-276651.0118]
pot_sirna_aa = [-499917.0932,-377029.4911,-409896.6399,-417971.1116,-385146.3633,-221813.5986,\
                -508990.6878,-349836.8601,-111034.2042,-403722.787,-1184963.15]
pot_pirna_cg = [-41046.06155,-21220.27423,-100087.8266,-79547.43962,-43912.48856]
pot_mirna_cg = [-154335.1395,-191056.4978,-200015.666,-209040.1123,-243395.5128,-78577.08797]
pot_sirna_cg = [2201.892763,826.9084077,283.6713224,383.2873639,487.9727312,581.031453,\
                1077.234994,249.0253695,215.4962608,256.0342135,1080.583375]

#density 
den_pirna_aa = [1021.879306,1011.567831,1004.395531,1008.023762,1044.607273]
den_mirna_aa = [1027.014612,1020.306813,1027.514405,1053.143782,1001.705891,1028.667705]
den_sirna_aa = [1035.052326,1040.989816,999.1899298,1001.434925,1008.750916,1027.342283,\
                1032.4632,1012.986756,1023.38715,1005.8743,1006.920884]
den_pirna_cg = [1001.21123,1004.127073,997.7530226,1004.644999,1012.345534]
den_mirna_cg = [1000.616444,998.8058841,996.0984405,1006.17583,999.2964128,1005.330356]
den_sirna_cg = [1000.232088,1019.086928,1006.251633,1006.581499,1001.907508,1007.268503,\
                1004.32966,1012.580835,1009.98253,1012.049541,1004.359808]

#temp
temp_pirna_aa = [299.8446619,300.2830055,299.9177106,299.963911,300.2082683]
temp_mirna_aa = [299.7303845,300.1989635,299.9657843,299.9132043,299.9305495,299.8763467]
temp_sirna_aa = [300.0293504,300.0343454,299.6896871,299.8911395,300.0961546,299.8411922,\
                 299.9316946,299.6941574,299.8469115,300.0088034,299.9856301]
temp_pirna_cg = [299.1056088,299.3776652,299.4336687,299.6811869,299.4256457]
temp_mirna_cg = [299.6609622,299.710688,299.5490891,299.1907271,299.490025,299.3451107]
temp_sirna_cg = [299.1272103,299.9178289,299.2648384,299.6574193,299.4322424,299.3020537,\
                 299.1590117,299.5041111,299.3418995,299.3996591,298.9568882]

#pressure
pres_pirna_aa = [41.53574837,-44.23509591,-6.116539284,-38.74726768,-29.00314025]
pres_mirna_aa = [3.210958667,-1.847650318,-16.63244449,-15.55840517,2.092639188,-27.51546398]
pres_sirna_aa = [-1.205851037,-16.0057008,-105.030728,-123.7558471,-0.913320119,21.34353391,\
                 8.024647754,-15.8692862,-2.635932109,-22.45955149,10.49645581]
pres_pirna_cg = [-1.267719688,3.104750296,0.893665909,1.89603557,-0.327382338]
pres_mirna_cg = [2.925538498,0.492196517,4.635925421,2.526055659,2.181753873,-0.277454055]
pres_sirna_cg = [0.924534605,1.928321585,2.63592349,1.642822393,4.188767877,7.037018482,\
                 1.930668046,5.786982246,6.070071458,7.067157169,3.464591958]

#-----------------------------------STD---------------------------------------------#

#potential_energy
pot_pirna_aa_std = [377.9565173,329.3775159,746.9184416,972.3851416,446.6895058]
pot_mirna_aa_std = [761.1950133,795.7623695,652.1083085,877.3613587,1611.139677,538.2306781]
pot_sirna_aa_std = [765.7559597,655.8733702,832.3989551,541.5952166,703.8226504,456.7728508,\
                    738.928702,610.006684,338.240786,700.7925277,1142.976446]
pot_pirna_cg_std = [317.4264795,202.531791,738.6914981,406.3098178,341.4021139]
pot_mirna_cg_std = [1090.689013,1301.395199,1352.193593,1103.241167,1183.21771,599.4212041]
pot_sirna_cg_std = [2201.892763,826.9084077,283.6713224,383.2873639,487.9727312,581.031453,\
                    1077.234994,249.0253695,215.4962608,256.0342135,1080.583375]
#density 
den_pirna_aa_std = [6.692388438,7.809814578,2.824934403,11.3184294,11.01504196]
den_mirna_aa_std = [5.421851856,3.286510083,4.104235623,6.589474806,1.436384718,2.747291639]
den_sirna_aa_std = [3.964229469,3.529849755,6.994629138,7.592414081,3.954522693,6.437158459,\
                    1.43486649,5.012257715,6.186298109,3.775663558,2.458866958]
den_pirna_cg_std = [6.461701952,8.084349702,5.744825628,3.958454073,6.459058049]
den_mirna_cg_std = [4.746757117,4.529627372,4.609245755,3.646145871,3.855619417,5.607611705]
den_sirna_cg_std = [5.795607615,4.615995665,5.18330128,6.197585041,5.371152806,6.824744757,\
                    4.710199793,5.488388517,7.104497265,6.344481631,5.540054873]
#temp
temp_pirna_aa_std = [3.656331042,3.882533382,1.808717014,1.838387571,3.974944384]
temp_mirna_aa_std = [1.94310162,1.569054931,2.436959459,1.740818606,0.74003516,2.372654476]
temp_sirna_aa_std = [1.841381447,2.050499366,2.267815174,1.7861596,1.99434348,2.717781728,\
                     1.897049961,2.29259455,3.744368271,1.919817042,1.149415728]
temp_pirna_cg_std = [9.310362163,11.21208379,8.12225942,7.772673036,9.602187745]
temp_mirna_cg_std = [7.587657143,7.472824961,7.608333926,6.724459241,6.90792157,10.5292774]
temp_sirna_cg_std = [10.89781206,10.03789524,9.178622038,9.78821472,9.321742438,10.30390971,\
                     9.370092601,9.877225686,11.12311282,10.08042217,10.41473342]
#pressure
pres_pirna_aa_std = [322.7040065,348.9546964,130.875352,247.9382274,305.7039263]
pres_mirna_aa_std = [199.4969388,140.6470697,210.3511886,211.5678622,65.56824631,192.330673]
pres_sirna_aa_std = [169.5599955,199.4205749,217.8875669,267.8033373,169.6298578,251.6563353,\
                     135.1697048,179.8354621,306.5420353,185.4885262,102.497406]
pres_pirna_cg_std = [82.77102334,112.4705231,54.73176304,79.03173464,94.74247577]
pres_mirna_cg_std = [51.29127566,51.86972676,52.49811264,48.232284,45.38649751,69.316646]
pres_sirna_cg_std = [74.02630869,55.73075547,79.6709582,76.88346353,68.16659755,73.43049723,\
                     46.17206234,116.7470639,119.2393359,99.89405821,58.09124108]

# %%
plt.errorbar(range(len(pot_mirna_aa)),pot_mirna_aa,yerr=pot_mirna_aa_std,color="red",fmt="*")
plt.errorbar(range(len(pot_mirna_cg)),pot_mirna_cg,yerr=pot_mirna_cg_std,color="green",fmt="*")
plt.errorbar(range(len(pot_pirna_aa)),pot_pirna_aa,yerr=pot_pirna_aa_std,color="red",fmt="s")
plt.errorbar(range(len(pot_pirna_cg)),pot_pirna_cg,yerr=pot_pirna_cg_std,color="green",fmt="s")
plt.errorbar(range(len(pot_sirna_aa)),pot_sirna_aa,yerr=pot_sirna_aa_std,color="red",fmt="v")
plt.errorbar(range(len(pot_sirna_cg)),pot_sirna_cg,yerr=pot_sirna_cg_std,color="green",fmt="v")
plt.ylabel("Potential Energy (kJmol$^{-1}$)")
plt.ylim([plt.gca().get_ylim()[0]-100,plt.gca().get_ylim()[1]+100])
plt.show()

# %%
plt.errorbar(range(len(temp_mirna_aa)),temp_mirna_aa,yerr=temp_mirna_aa_std,color="orange",fmt="*")
plt.errorbar(range(len(temp_mirna_cg)),temp_mirna_cg,yerr=temp_mirna_cg_std,color="limegreen",fmt="*")
plt.errorbar(range(len(temp_pirna_aa)),temp_pirna_aa,yerr=temp_pirna_aa_std,color="orange",fmt="s")
plt.errorbar(range(len(temp_pirna_cg)),temp_pirna_cg,yerr=temp_pirna_cg_std,color="limegreen",fmt="s")
plt.errorbar(range(len(temp_sirna_aa)),temp_sirna_aa,yerr=temp_sirna_aa_std,color="orange",fmt="v")
plt.errorbar(range(len(temp_sirna_cg)),temp_sirna_cg,yerr=temp_sirna_cg_std,color="limegreen",fmt="v")
plt.ylabel("Temperature (K)")
plt.ylim([plt.gca().get_ylim()[0]-100,plt.gca().get_ylim()[1]+100])
plt.show()

# %%
plt.errorbar(range(len(pres_mirna_aa)),pres_mirna_aa,yerr=pres_mirna_aa_std,color="tomato",fmt="*")
plt.errorbar(range(len(pres_mirna_cg)),pres_mirna_cg,yerr=pres_mirna_cg_std,color="olive",fmt="*")
plt.errorbar(range(len(pres_pirna_aa)),pres_pirna_aa,yerr=pres_pirna_aa_std,color="tomato",fmt="s")
plt.errorbar(range(len(pres_pirna_cg)),pres_pirna_cg,yerr=pres_pirna_cg_std,color="olive",fmt="s")
plt.errorbar(range(len(pres_sirna_aa)),pres_sirna_aa,yerr=pres_sirna_aa_std,color="tomato",fmt="v")
plt.errorbar(range(len(pres_sirna_cg)),pres_sirna_cg,yerr=pres_sirna_cg_std,color="olive",fmt="v")
plt.ylabel("Pressure (bar)")
plt.ylim([plt.gca().get_ylim()[0]-100,plt.gca().get_ylim()[1]+100])
plt.show()

# %%
plt.errorbar(range(len(den_mirna_aa)),den_mirna_aa,yerr=den_mirna_aa_std,color="maroon",fmt="*")
plt.errorbar(range(len(den_mirna_cg)),den_mirna_cg,yerr=den_mirna_cg_std,color="limegreen",fmt="*")
plt.errorbar(range(len(den_pirna_aa)),den_pirna_aa,yerr=den_pirna_aa_std,color="maroon",fmt="s")
plt.errorbar(range(len(den_pirna_cg)),den_pirna_cg,yerr=den_pirna_cg_std,color="limegreen",fmt="s")
plt.errorbar(range(len(den_sirna_aa)),den_sirna_aa,yerr=den_sirna_aa_std,color="maroon",fmt="v")
plt.errorbar(range(len(den_sirna_cg)),den_sirna_cg,yerr=den_sirna_cg_std,color="limegreen",fmt="v")
plt.ylabel("Density (Kgm$^-3$)")
plt.ylim([plt.gca().get_ylim()[0]-100,plt.gca().get_ylim()[1]+100])
plt.show()

# %% [markdown]
# #### Production

# %%
#MEAN
#potential_energy
pot_pirna_aa = [-129260.3573,-112799.1758,-536434.8313,-459960.1188,-138839.4586]
pot_mirna_aa = [-432049.4626,-580084.831,-324404.6966,-493368.4916,-2399785.627,-277237.5275]
pot_sirna_aa = [-336931.8363,-377472.936,-177022.9342,-199039.6904,-385481.8971,-222060.7049,\
                    -509273.3038,-350085.6798,-111182.7713,-404053.4942,-1185056.268]
pot_pirna_cg = [-41313.4765,-21498.54027,-47526.27072,-80423.45261,-44138.98011]
pot_mirna_cg = [-155469.0515,-193013.9719,-201417.4687,-212473.0805,-245385.3916,-79517.03555]
pot_sirna_cg = [-261492.7355,-116185.9555,-47714.32834,-50783.93357,-74950.00303,\
                -63670.76015,-174866.5336,-46353.86959,-29585.92207,-38416.37992,-149757.7363]

#density 
den_pirna_aa = [1020.583691,1011.887344,1004.366446,1010.79488,1048.496469]
den_mirna_aa = [1026.800336,1019.891868,1026.172533,1052.092843,1001.487462,1027.724957]
den_sirna_aa = [1053.868384,1041.143933,1024.152379,1023.034911,1009.098282,1026.581988,\
                    1032.032697,1013.270146,1024.879192,1006.232264,1005.731583]
den_pirna_cg = [1001.102145,1003.64839,1009.756684,1004.395972,1012.173566]
den_mirna_cg = [1000.701915,998.9386736,995.873267,1006.000016,1003.577841,1003.629763]
den_sirna_cg = [999.3638686,1010.10395,1006.942396,1007.281195,1001.476185,1006.987318,\
                1004.028335,1011.735733,1008.58659,1010.544505,1003.783967]

#temp
temp_pirna_aa = [299.9899278,300.0373377,300.0291915,299.9870758,300.0203135]
temp_mirna_aa = [300.0543734,300.0067998,299.9893814,300.0401419,300.0031989,299.9991781]
temp_sirna_aa = [300.0096019,299.9847998,299.9953794,300.0006618,300.0181791,300.0335771,\
                     300.0026107,300.0339778,300.0290573,300.0195788,300.0105053]
temp_pirna_cg = [299.9502739,299.9913984,299.9116619,299.903531,299.9401212]
temp_mirna_cg = [299.95989,299.9026564,299.9084616,299.8436125,299.8684684,299.9140551]
temp_sirna_cg = [299.8795197,299.8908299,299.9146763,299.9783014,299.9046357,299.8600561,\
                 299.9154567,299.8595741,299.899679,299.9803729,299.9483686]

#pressure
pres_pirna_aa = [3.974013093,4.419518086,0.587071398,2.369557001,-0.478677118]
pres_mirna_aa = [-2.71761481,1.823456683,-0.353007783,-0.164621287,0.580951171,3.638985934]
pres_sirna_aa = [2.715834786,2.25934186,4.062449313,1.284777493,2.384734489,1.209232237,\
                     0.666837187,4.135491568,0.581342097,1.152589929,2.003715862]
pres_pirna_cg = [0.416182013,0.654881956,0.773434045,0.851227003,0.330813275]
pres_mirna_cg = [2.155261961,0.745245913,0.889883833,0.6302686,1.218786349,0.832943959]
pres_sirna_cg = [0.626004287,0.293469615,0.750396286,0.592169924,0.90911621,0.700601271,\
                 0.468203475,0.721896736,0.848490909,0.648126267,0.958222313]
#-----------------------------------STD---------------------------------------------#

#potential_energy
pot_pirna_aa_std = [375.7093119,347.2201396,802.4362921,701.288751,388.0018154]
pot_mirna_aa_std = [745.245374,783.8164975,628.76348,732.0315144,1664.464238,548.3307851]
pot_sirna_aa_std = [610.1927826,634.7981039,437.7785005,463.0274355,685.6839149,
                    525.6851205,744.9586968,655.7893722,377.0876561,693.5915298,1185.113948]
pot_pirna_cg_std = [212.2945486,152.0453523,228.3771556,295.6129121,226.4542242]
pot_mirna_cg_std = [416.9634694,467.8490165,469.3896716,516.3006925,568.230876,319.1244806]
pot_sirna_cg_std = [544.7089954,369.9996916,232.5631523,241.4735862,289.1367726,272.7081977,
                    450.5591699,228.5501021,182.3662488,210.0621803,410.1405926]
#density 
den_pirna_aa_std = [5.142122917,5.495533228,4.04070982,2.72351245,5.110937354]
den_mirna_aa_std = [4.973243009,2.445022679,5.40246752,2.72398723,1.772617472,3.562548873]
den_sirna_aa_std = [3.339043865,3.037150519,4.321088473,4.052414708,4.709215325,6.628728305,
                    2.598823556,5.192717959,9.429742199,4.473993551,2.699371055]
den_pirna_cg_std = [4.630776196,6.339572857,4.305792975,3.283788132,4.61928535]
den_mirna_cg_std = [2.240981826,2.048891045,2.022776665,1.993005998,2.018867271,3.272996979]
den_sirna_cg_std = [1.860090443,2.608040134,4.18076171,4.083967902,3.534560905,3.61207873,\
                    2.14403593,4.267786725,5.705094085,5.026921926,2.507806185]
#temp
temp_pirna_aa_std = [3.568605326,3.809008112,1.71167045,1.848775759,3.563013593]
temp_mirna_aa_std = [1.956893101,1.68558342,2.277802426,1.912063392,0.799023919,2.450074463]
temp_sirna_aa_std = [2.30331934,2.132052398,3.043022053,2.896005369,2.023990679,2.752493582,\
                     1.825050751,2.150399219,3.806633628,1.971953957,1.144831642]
temp_pirna_cg_std = [6.332340347,8.90681956,6.043601314,4.6636764,6.249191543]
temp_mirna_cg_std = [3.057042912,2.86809836,2.816443432,2.714047138,2.598602196,4.370124757]
temp_sirna_cg_std = [2.512753927,3.676799185,5.876229512,5.723173964,4.766720647,5.013699789\
                     ,3.019468593,6.032011775,7.607851584,6.69921781,3.298472628]
#pressure
pres_pirna_aa_std = [295.2801528,302.0867582,172.4166893,149.8917473,315.9236432]
pres_mirna_aa_std = [220.0458629,138.2561866,243.3625987,170.9083341,77.74093535,208.6939]
pres_sirna_aa_std = [208.7021705,184.2121664,255.8097558,237.2602128,205.8964258,296.4880244,\
                     154.1013921,223.9731011,423.5321745,196.5397727,115.5701237]
pres_pirna_cg_std = [79.05631173,108.2647283,74.47383417,56.68388678,89.52144776]
pres_mirna_cg_std = [40.36701026,35.34613131,34.82670592,36.65781143,31.92729714,61.02978491]
pres_sirna_cg_std = [32.24063395,48.9104569,72.4349168,70.81295163,61.72032748,63.4374875,\
                     39.07036323,80.73440966,100.1186519,88.3883852,45.67680193]

# %%
plt.errorbar(range(len(pot_mirna_aa)),pot_mirna_aa,yerr=pot_mirna_aa_std,color="red",fmt="*")
plt.errorbar(range(len(pot_mirna_cg)),pot_mirna_cg,yerr=pot_mirna_cg_std,color="green",fmt="*")
plt.errorbar(range(len(pot_pirna_aa)),pot_pirna_aa,yerr=pot_pirna_aa_std,color="red",fmt="s")
plt.errorbar(range(len(pot_pirna_cg)),pot_pirna_cg,yerr=pot_pirna_cg_std,color="green",fmt="s")
plt.errorbar(range(len(pot_sirna_aa)),pot_sirna_aa,yerr=pot_sirna_aa_std,color="red",fmt="v")
plt.errorbar(range(len(pot_sirna_cg)),pot_sirna_cg,yerr=pot_sirna_cg_std,color="green",fmt="v")
plt.ylabel("Potential Energy (kJmol$^{-1}$)")
plt.ylim([plt.gca().get_ylim()[0]-100,plt.gca().get_ylim()[1]+100])
plt.show()

# %%
plt.errorbar(range(len(temp_mirna_aa)),temp_mirna_aa,yerr=temp_mirna_aa_std,color="orange",fmt="*")
plt.errorbar(range(len(temp_mirna_cg)),temp_mirna_cg,yerr=temp_mirna_cg_std,color="limegreen",fmt="*")
plt.errorbar(range(len(temp_pirna_aa)),temp_pirna_aa,yerr=temp_pirna_aa_std,color="orange",fmt="s")
plt.errorbar(range(len(temp_pirna_cg)),temp_pirna_cg,yerr=temp_pirna_cg_std,color="limegreen",fmt="s")
plt.errorbar(range(len(temp_sirna_aa)),temp_sirna_aa,yerr=temp_sirna_aa_std,color="orange",fmt="v")
plt.errorbar(range(len(temp_sirna_cg)),temp_sirna_cg,yerr=temp_sirna_cg_std,color="limegreen",fmt="v")
plt.ylabel("Temperature (K)")
plt.ylim([plt.gca().get_ylim()[0]-100,plt.gca().get_ylim()[1]+100])
plt.show()

# %%
plt.errorbar(range(len(pres_mirna_aa)),pres_mirna_aa,yerr=pres_mirna_aa_std,color="tomato",fmt="*")
plt.errorbar(range(len(pres_mirna_cg)),pres_mirna_cg,yerr=pres_mirna_cg_std,color="olive",fmt="*")
plt.errorbar(range(len(pres_pirna_aa)),pres_pirna_aa,yerr=pres_pirna_aa_std,color="tomato",fmt="s")
plt.errorbar(range(len(pres_pirna_cg)),pres_pirna_cg,yerr=pres_pirna_cg_std,color="olive",fmt="s")
plt.errorbar(range(len(pres_sirna_aa)),pres_sirna_aa,yerr=pres_sirna_aa_std,color="tomato",fmt="v")
plt.errorbar(range(len(pres_sirna_cg)),pres_sirna_cg,yerr=pres_sirna_cg_std,color="olive",fmt="v")
plt.ylabel("Pressure (bar)")
plt.ylim([plt.gca().get_ylim()[0]-100,plt.gca().get_ylim()[1]+100])
plt.show()

# %%
plt.errorbar(range(len(den_mirna_aa)),den_mirna_aa,yerr=den_mirna_aa_std,color="maroon",fmt="*")
plt.errorbar(range(len(den_mirna_cg)),den_mirna_cg,yerr=den_mirna_cg_std,color="limegreen",fmt="*")
plt.errorbar(range(len(den_pirna_aa)),den_pirna_aa,yerr=den_pirna_aa_std,color="maroon",fmt="s")
plt.errorbar(range(len(den_pirna_cg)),den_pirna_cg,yerr=den_pirna_cg_std,color="limegreen",fmt="s")
plt.errorbar(range(len(den_sirna_aa)),den_sirna_aa,yerr=den_sirna_aa_std,color="maroon",fmt="v")
plt.errorbar(range(len(den_sirna_cg)),den_sirna_cg,yerr=den_sirna_cg_std,color="limegreen",fmt="v")
plt.ylabel("Density (Kgm$^-3$)")
plt.ylim([plt.gca().get_ylim()[0]-100,plt.gca().get_ylim()[1]+100])
plt.show()
