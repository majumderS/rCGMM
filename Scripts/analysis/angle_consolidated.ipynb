# %%
import pandas as pd
import seaborn as sns
import math
from scipy import stats
import numpy as np
import matplotlib.pyplot as plot
import math
from scipy.optimize import curve_fit
# %matplotlib inline

# %%
angle_dict = dict.fromkeys(['BB1_BB2_BB3','BB2_BB3_ASC1','BB3_ASC1_ASC2','BB3_ASC1_ASC4','ASC1_ASC2_ASC3',\
'ASC2_ASC1_ASC4','ASC2_ASC3_ASC4','ASC3_ASC4_ASC1','BB2_BB3_USC1','BB3_USC1_USC2','BB3_USC1_USC3','USC1_USC2_USC3',\
'USC1_USC2_USC3','USC2_USC1_USC3','USC2_USC3_USC1','BB2_BB3_GSC1','BB3_GSC1_GSC2','BB3_GSC1_GSC4','GSC1_GSC2_GSC3','GSC2_GSC1_GSC4',\
'GSC2_GSC3_GSC4','GSC3_GSC4_GSC1','BB2_BB3_CSC1','BB3_CSC1_CSC2','BB3_CSC1_CSC3','CSC1_CSC2_CSC3','CSC2_CSC1_CSC3',\
'CSC2_CSC3_CSC1','BB2_BB3_pBB1','BB3_pBB1_pBB2','ASC1_BB3_pBB1','USC1_BB3_pBB1','GSC1_BB3_pBB1','CSC1_BB3_pBB1'])

# %%
df_sirna_angle = pd.read_csv('angle_final_allmolecules.csv')
df_pirna_angle = pd.read_csv('../../pirna_CG_model/analysis_scripts/angle_final_allmolecules.xvg')
df_mirna_angle = pd.read_csv('../../mirna_CG_model/analysis_scripts/angle_final.xvg')

# %%
df_pirna_angle['USC2_USC1_USC3']
# Out:
# 0       77.682
# 1       77.178
# 2       78.063
# 3       76.237
# 4       77.075
#          ...
# 4999    77.880
# 5000    78.240
# 5001    76.445
# 5002    75.095
# 5003    75.337
# Name: USC2_USC1_USC3, Length: 5004, dtype: float64

# %%
#sirna
BB1_BB2_BB3_sirna = df_sirna_angle['BB1_BB2_BB3']
BB2_BB3_ASC1_sirna = df_sirna_angle['BB2_BB3_ASC1']
BB3_ASC1_ASC2_sirna = df_sirna_angle['BB3_ASC1_ASC2']
BB3_ASC1_ASC4_sirna = df_sirna_angle['BB3_ASC1_ASC4']
ASC1_ASC2_ASC3_sirna = df_sirna_angle['ASC1_ASC2_ASC3']
ASC2_ASC1_ASC4_sirna = df_sirna_angle['ASC2_ASC1_ASC4']
ASC2_ASC3_ASC4_sirna = df_sirna_angle['ASC2_ASC3_ASC4']
ASC3_ASC4_ASC1_sirna = df_sirna_angle['ASC3_ASC4_ASC1']
BB2_BB3_USC1_sirna = df_sirna_angle['BB2_BB3_USC1']
BB3_USC1_USC2_sirna = df_sirna_angle['BB3_USC1_USC2']
BB3_USC1_USC3_sirna = df_sirna_angle['BB3_USC1_USC3']
USC1_USC2_USC3_sirna = df_sirna_angle['USC1_USC2_USC3']
BB3_USC1_USC3_sirna = df_sirna_angle['BB3_USC1_USC3']
# USC2_USC1_USC3_sirna = df_sirna_angle['USC2_USC1_USC3']
USC2_USC3_USC1_sirna = df_sirna_angle['USC2_USC3_USC1']
BB2_BB3_ASC1_sirna = df_sirna_angle['BB2_BB3_ASC1']
BB2_BB3_GSC1_sirna = df_sirna_angle['BB2_BB3_GSC1']
BB3_GSC1_GSC2_sirna = df_sirna_angle['BB3_GSC1_GSC2']
BB3_GSC1_GSC4_sirna = df_sirna_angle['BB3_GSC1_GSC4']
GSC1_GSC2_GSC3_sirna = df_sirna_angle['GSC1_GSC2_GSC3']
GSC2_GSC1_GSC4_sirna = df_sirna_angle['GSC2_GSC1_GSC4']
GSC2_GSC3_GSC4_sirna = df_sirna_angle['GSC2_GSC3_GSC4']
GSC3_GSC4_GSC1_sirna = df_sirna_angle['GSC3_GSC4_GSC1']
BB2_BB3_CSC1_sirna = df_sirna_angle['BB2_BB3_CSC1']
BB3_CSC1_CSC2_sirna = df_sirna_angle['BB3_CSC1_CSC2']
BB3_CSC1_CSC3_sirna = df_sirna_angle['BB3_CSC1_CSC3']
CSC1_CSC2_CSC3_sirna = df_sirna_angle['CSC1_CSC2_CSC3']
CSC2_CSC1_CSC3_sirna = df_sirna_angle['CSC2_CSC1_CSC3']
CSC2_CSC3_CSC1_sirna = df_sirna_angle['CSC2_CSC3_CSC1']
BB2_BB3_pBB1_sirna = df_sirna_angle['BB2_BB3_pBB1']
BB3_pBB1_pBB2_sirna = df_sirna_angle['BB3_pBB1_pBB2']
ASC1_BB3_pBB1_sirna = df_sirna_angle['ASC1_BB3_pBB1']
USC1_BB3_pBB1_sirna = df_sirna_angle['USC1_BB3_pBB1']
GSC1_BB3_pBB1_sirna = df_sirna_angle['GSC1_BB3_pBB1']
CSC1_BB3_pBB1_sirna = df_sirna_angle['CSC1_BB3_pBB1']

#pirna
BB1_BB2_BB3_pirna = df_pirna_angle['BB1_BB2_BB3']
BB2_BB3_ASC1_pirna = df_pirna_angle['BB2_BB3_ASC1']
BB3_ASC1_ASC2_pirna = df_pirna_angle['BB3_ASC1_ASC2']
BB3_ASC1_ASC4_pirna = df_pirna_angle['BB3_ASC1_ASC4']
ASC1_ASC2_ASC3_pirna = df_pirna_angle['ASC1_ASC2_ASC3']
ASC2_ASC1_ASC4_pirna = df_pirna_angle['ASC2_ASC1_ASC4']
ASC2_ASC3_ASC4_pirna = df_pirna_angle['ASC2_ASC3_ASC4']
ASC3_ASC4_ASC1_pirna = df_pirna_angle['ASC3_ASC4_ASC1']
BB2_BB3_USC1_pirna = df_pirna_angle['BB2_BB3_USC1']
BB3_USC1_USC2_pirna = df_pirna_angle['BB3_USC1_USC2']
BB3_USC1_USC3_pirna = df_pirna_angle['BB3_USC1_USC3']
USC1_USC2_USC3_pirna = df_pirna_angle['USC1_USC2_USC3']
BB3_USC1_USC3_pirna = df_pirna_angle['BB3_USC1_USC3']
USC2_USC1_USC3_pirna = df_pirna_angle['USC2_USC1_USC3']
USC2_USC3_USC1_pirna = df_pirna_angle['USC2_USC3_USC1']
BB2_BB3_ASC1_pirna = df_pirna_angle['BB2_BB3_ASC1']
BB2_BB3_GSC1_pirna = df_pirna_angle['BB2_BB3_GSC1']
BB3_GSC1_GSC2_pirna = df_pirna_angle['BB3_GSC1_GSC2']
BB3_GSC1_GSC4_pirna = df_pirna_angle['BB3_GSC1_GSC4']
GSC1_GSC2_GSC3_pirna = df_pirna_angle['GSC1_GSC2_GSC3']
GSC2_GSC1_GSC4_pirna = df_pirna_angle['GSC2_GSC1_GSC4']
GSC2_GSC3_GSC4_pirna = df_pirna_angle['GSC2_GSC3_GSC4']
GSC3_GSC4_GSC1_pirna = df_pirna_angle['GSC3_GSC4_GSC1']
BB2_BB3_CSC1_pirna = df_pirna_angle['BB2_BB3_CSC1']
BB3_CSC1_CSC2_pirna = df_pirna_angle['BB3_CSC1_CSC2']
BB3_CSC1_CSC3_pirna = df_pirna_angle['BB3_CSC1_CSC3']
CSC1_CSC2_CSC3_pirna = df_pirna_angle['CSC1_CSC2_CSC3']
CSC2_CSC1_CSC3_pirna = df_pirna_angle['CSC2_CSC1_CSC3']
CSC2_CSC3_CSC1_pirna = df_pirna_angle['CSC2_CSC3_CSC1']
BB2_BB3_pBB1_pirna = df_pirna_angle['BB2_BB3_pBB1']
BB3_pBB1_pBB2_pirna = df_pirna_angle['BB3_pBB1_pBB2']
ASC1_BB3_pBB1_pirna = df_pirna_angle['ASC1_BB3_pBB1']
USC1_BB3_pBB1_pirna = df_pirna_angle['USC1_BB3_pBB1']
GSC1_BB3_pBB1_pirna = df_pirna_angle['GSC1_BB3_pBB1']
CSC1_BB3_pBB1_pirna = df_pirna_angle['CSC1_BB3_pBB1']

#mirna
BB1_BB2_BB3_mirna = df_mirna_angle['BB1_BB2_BB3']
BB2_BB3_ASC1_mirna = df_mirna_angle['BB2_BB3_ASC1']
BB3_ASC1_ASC2_mirna = df_mirna_angle['BB3_ASC1_ASC2']
BB3_ASC1_ASC4_mirna = df_mirna_angle['BB3_ASC1_ASC4']
ASC1_ASC2_ASC3_mirna = df_mirna_angle['ASC1_ASC2_ASC3']
ASC2_ASC1_ASC4_mirna = df_mirna_angle['ASC2_ASC1_ASC4']
ASC2_ASC3_ASC4_mirna = df_mirna_angle['ASC2_ASC3_ASC4']
ASC3_ASC4_ASC1_mirna = df_mirna_angle['ASC3_ASC4_ASC1']
BB2_BB3_USC1_mirna = df_mirna_angle['BB2_BB3_USC1']
BB3_USC1_USC2_mirna = df_mirna_angle['BB3_USC1_USC2']
BB3_USC1_USC3_mirna = df_mirna_angle['BB3_USC1_USC3']
USC1_USC2_USC3_mirna = df_mirna_angle['USC1_USC2_USC3']
BB3_USC1_USC3_mirna = df_mirna_angle['BB3_USC1_USC3']
USC2_USC1_USC3_mirna = df_mirna_angle['USC2_USC1_USC3']
USC2_USC3_USC1_mirna = df_mirna_angle['USC2_USC3_USC1']
BB2_BB3_ASC1_mirna = df_mirna_angle['BB2_BB3_ASC1']
BB2_BB3_GSC1_mirna = df_mirna_angle['BB2_BB3_GSC1']
BB3_GSC1_GSC2_mirna = df_mirna_angle['BB3_GSC1_GSC2']
BB3_GSC1_GSC4_mirna = df_mirna_angle['BB3_GSC1_GSC4']
GSC1_GSC2_GSC3_mirna = df_mirna_angle['GSC1_GSC2_GSC3']
GSC2_GSC1_GSC4_mirna = df_mirna_angle['GSC2_GSC1_GSC4']
GSC2_GSC3_GSC4_mirna = df_mirna_angle['GSC2_GSC3_GSC4']
GSC3_GSC4_GSC1_mirna = df_mirna_angle['GSC3_GSC4_GSC1']
BB2_BB3_CSC1_mirna = df_mirna_angle['BB2_BB3_CSC1']
BB3_CSC1_CSC2_mirna = df_mirna_angle['BB3_CSC1_CSC2']
BB3_CSC1_CSC3_mirna = df_mirna_angle['BB3_CSC1_CSC3']
CSC1_CSC2_CSC3_mirna = df_mirna_angle['CSC1_CSC2_CSC3']
CSC2_CSC1_CSC3_mirna = df_mirna_angle['CSC2_CSC1_CSC3']
CSC2_CSC3_CSC1_mirna = df_mirna_angle['CSC2_CSC3_CSC1']
BB2_BB3_pBB1_mirna = df_mirna_angle['BB2_BB3_pBB1']
BB3_pBB1_pBB2_mirna = df_mirna_angle['BB3_pBB1_pBB2']
ASC1_BB3_pBB1_mirna = df_mirna_angle['ASC1_BB3_pBB1']
USC1_BB3_pBB1_mirna = df_mirna_angle['USC1_BB3_pBB1']
GSC1_BB3_pBB1_mirna = df_mirna_angle['GSC1_BB3_pBB1']
CSC1_BB3_pBB1_mirna = df_mirna_angle['CSC1_BB3_pBB1']

# %%
#density plot
BB1_BB2_BB3 = {'sirna': BB1_BB2_BB3_sirna,'pirna': BB1_BB2_BB3_pirna,'mirna': BB1_BB2_BB3_mirna}
ax = sns.kdeplot(data=BB1_BB2_BB3,bw=0.4)
plt.ylabel("Probability density")
plt.xlabel('BB1_BB2_BB3 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.4 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
#density plot
BB2_BB3_ASC1 = {'sirna': BB2_BB3_ASC1_sirna,'pirna': BB2_BB3_ASC1_pirna,'mirna': BB2_BB3_ASC1_mirna}
ax = sns.kdeplot(data=BB2_BB3_ASC1,bw=0.5)
plt.ylabel("Probability density")
plt.xlabel('BB2_BB3_ASC1 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
#density plot
BB3_ASC1_ASC2 = {'sirna': BB3_ASC1_ASC2_sirna,'pirna':BB3_ASC1_ASC2_pirna,'mirna': BB3_ASC1_ASC2_mirna}
ax = sns.kdeplot(data=BB3_ASC1_ASC2,bw=0.8)
plt.ylabel("Probability density")
plt.xlabel('BB3_ASC1_ASC2 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.8 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
#density plot
BB3_ASC1_ASC4 = {'sirna': BB3_ASC1_ASC4_sirna,'pirna': BB3_ASC1_ASC4_pirna,'mirna': BB3_ASC1_ASC4_mirna}
ax = sns.kdeplot(data=BB3_ASC1_ASC4,bw=0.35)
plt.ylabel("Probability density")
plt.xlabel('BB3_ASC1_ASC4 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.35 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
#density plot
ASC1_ASC2_ASC3 = {'sirna': ASC1_ASC2_ASC3_sirna,'pirna': ASC1_ASC2_ASC3_pirna,'mirna': ASC1_ASC2_ASC3_mirna}
ax = sns.kdeplot(data=ASC1_ASC2_ASC3,bw=0.3)
plt.ylabel("Probability density")
plt.xlabel('ASC1_ASC2_ASC3 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.3 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
#density plot
ASC2_ASC1_ASC4 = {'sirna': ASC2_ASC1_ASC4_sirna,'pirna': ASC2_ASC1_ASC4_pirna,'mirna': ASC2_ASC1_ASC4_mirna}
ax = sns.kdeplot(data=ASC2_ASC1_ASC4,bw=0.3)
plt.ylabel("Probability density")
plt.xlabel('ASC2_ASC1_ASC4 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.3 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
#density plot
ASC2_ASC3_ASC4 = {'sirna': ASC2_ASC3_ASC4_sirna,'pirna': ASC2_ASC3_ASC4_pirna,'mirna': ASC2_ASC3_ASC4_mirna}
ax = sns.kdeplot(data=ASC2_ASC3_ASC4,bw=0.3)
plt.ylabel("Probability density")
plt.xlabel('ASC2_ASC3_ASC4 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.3 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
#density plot
ASC3_ASC4_ASC1 = {'sirna': ASC3_ASC4_ASC1_sirna,'pirna': ASC3_ASC4_ASC1_pirna,'mirna': ASC3_ASC4_ASC1_mirna}
ax = sns.kdeplot(data=ASC3_ASC4_ASC1,bw=0.3)
plt.ylabel("Probability density")
plt.xlabel('ASC3_ASC4_ASC1 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.3 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
#density plot
BB2_BB3_USC1 = {'sirna':BB2_BB3_USC1_sirna,'pirna': BB2_BB3_USC1_pirna,'mirna': BB2_BB3_USC1_mirna}
ax = sns.kdeplot(data=BB2_BB3_USC1,bw=0.2)
plt.ylabel("Probability density")
plt.xlabel('BB2_BB3_USC1 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.2 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
#density plot
BB3_USC1_USC2 = {'sirna': BB3_USC1_USC2_sirna,'pirna': BB3_USC1_USC2_pirna,'mirna': BB3_USC1_USC2_mirna}
ax = sns.kdeplot(data=BB3_USC1_USC2,bw=0.5)
plt.ylabel("Probability density")
plt.xlabel('BB3_USC1_USC2 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
#density plot
BB3_USC1_USC3 = {'sirna': BB3_USC1_USC3_sirna,'pirna': BB3_USC1_USC3_pirna,'mirna': BB3_USC1_USC3_mirna}
ax = sns.kdeplot(data=BB3_USC1_USC3,bw=0.5)
plt.ylabel("Probability density")
plt.xlabel('BB3_USC1_USC3 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
#density plot
USC1_USC2_USC3 = {'sirna': USC1_USC2_USC3_sirna,'pirna': USC1_USC2_USC3_pirna,'mirna': USC1_USC2_USC3_mirna}
ax = sns.kdeplot(data=USC1_USC2_USC3,bw=0.3)
plt.ylabel("Probability density")
plt.xlabel('USC1_USC2_USC3 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.3 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
#density plot
USC2_USC1_USC3 = {'pirna': USC2_USC1_USC3_pirna,'mirna': USC2_USC1_USC3_mirna}
ax = sns.kdeplot(data=USC2_USC1_USC3,bw=0.3)
plt.ylabel("Probability density")
plt.xlabel('USC2_USC1_USC3 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.3 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
#density plot
BB3_USC1_USC3 = {'sirna': BB3_USC1_USC3_sirna,'pirna': BB3_USC1_USC3_pirna,'mirna': BB3_USC1_USC3_mirna}
ax = sns.kdeplot(data=BB3_USC1_USC3,bw=0.4)
plt.ylabel("Probability density")
plt.xlabel('BB3_USC1_USC3 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.4 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
#density plot
USC2_USC3_USC1 = {'sirna': USC2_USC3_USC1_sirna,'pirna': USC2_USC3_USC1_pirna,'mirna': USC2_USC3_USC1_mirna}
ax = sns.kdeplot(data=USC2_USC3_USC1,bw=0.3)
plt.ylabel("Probability density")
plt.xlabel('USC2_USC3_USC1 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.3 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
#density plot
BB2_BB3_ASC1 = {'sirna': BB2_BB3_ASC1_sirna,'pirna': BB2_BB3_ASC1_pirna,'mirna': BB2_BB3_ASC1_mirna}
ax = sns.kdeplot(data=BB2_BB3_ASC1,bw=0.7)
plt.ylabel("Probability density")
plt.xlabel('BB2_BB3_ASC1 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
#density plot
BB2_BB3_GSC1 = {'sirna': BB2_BB3_GSC1_sirna,'pirna': BB2_BB3_GSC1_pirna,'mirna': BB2_BB3_GSC1_mirna}
ax = sns.kdeplot(data=BB2_BB3_GSC1,bw=1.2)
plt.ylabel("Probability density")
plt.xlabel('BB2_BB3_GSC1 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 1.2 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
#density plot
BB3_GSC1_GSC2 = {'sirna': BB3_GSC1_GSC2_sirna,'pirna': BB3_GSC1_GSC2_pirna,'mirna': BB3_GSC1_GSC2_mirna}
ax = sns.kdeplot(data=BB1_BB2_BB3,bw=0.5)
plt.ylabel("Probability density")
plt.xlabel('BB3_GSC1_GSC2 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
#density plot
BB3_GSC1_GSC4 = {'sirna': BB3_GSC1_GSC4_sirna,'pirna': BB3_GSC1_GSC4_pirna,'mirna': BB3_GSC1_GSC4_mirna}
ax = sns.kdeplot(data=BB3_GSC1_GSC4,bw=0.8)
plt.ylabel("Probability density")
plt.xlabel('BB3_GSC1_GSC4 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.8 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
#density plot
GSC1_GSC2_GSC3 = {'sirna': GSC1_GSC2_GSC3_sirna,'pirna': GSC1_GSC2_GSC3_pirna,'mirna': GSC1_GSC2_GSC3_mirna}
ax = sns.kdeplot(data=GSC1_GSC2_GSC3,bw=0.3)
plt.ylabel("Probability density")
plt.xlabel('GSC1_GSC2_GSC3 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.3 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
#density plot
GSC2_GSC1_GSC4 = {'sirna': GSC2_GSC1_GSC4_sirna,'pirna': GSC2_GSC1_GSC4_pirna,'mirna': GSC2_GSC1_GSC4_mirna}
ax = sns.kdeplot(data=GSC2_GSC1_GSC4,bw=0.3)
plt.ylabel("Probability density")
plt.xlabel('GSC2_GSC1_GSC4 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.3 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
#density plot
GSC2_GSC3_GSC4 = {'sirna': GSC2_GSC3_GSC4_sirna,'pirna': GSC2_GSC3_GSC4_pirna,'mirna': GSC2_GSC3_GSC4_mirna}
ax = sns.kdeplot(data=GSC2_GSC3_GSC4,bw=0.25)
plt.ylabel("Probability density")
plt.xlabel('GSC2_GSC3_GSC4 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.25 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
#density plot
GSC3_GSC4_GSC1 = {'sirna': GSC3_GSC4_GSC1_sirna,'pirna': GSC3_GSC4_GSC1_pirna,'mirna': GSC3_GSC4_GSC1_mirna}
ax = sns.kdeplot(data=GSC3_GSC4_GSC1,bw=0.3)
plt.ylabel("Probability density")
plt.xlabel('GSC3_GSC4_GSC1 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.3 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
#density plot
BB2_BB3_CSC1 = {'sirna': BB2_BB3_CSC1_sirna,'pirna': BB2_BB3_CSC1_pirna,'mirna': BB2_BB3_CSC1_mirna}
ax = sns.kdeplot(data=BB2_BB3_CSC1,bw=0.3)
plt.ylabel("Probability density")
plt.xlabel('BB2_BB3_CSC1 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.3 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
#density plot
import matplotlib.pyplot as plt
plt.ylabel("Probability density")
BB3_CSC1_CSC2 = {'sirna': BB3_CSC1_CSC2_sirna,'pirna': BB3_CSC1_CSC2_pirna,'mirna': BB3_CSC1_CSC2_mirna}
ax = sns.kdeplot(data=BB3_CSC1_CSC2,bw=0.2)
plt.ylabel("Probability density")
plt.xlabel('BB3_CSC1_CSC2 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.2 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
#density plot
BB3_CSC1_CSC3 = {'sirna': BB3_CSC1_CSC3_sirna,'pirna': BB3_CSC1_CSC3_pirna,'mirna':BB3_CSC1_CSC3_mirna}
ax = sns.kdeplot(data=BB3_CSC1_CSC3)
plt.ylabel("Probability density")
plt.xlabel('BB3_CSC1_CSC3 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
#density plot
CSC1_CSC2_CSC3 = {'sirna': CSC1_CSC2_CSC3_sirna,'pirna': CSC1_CSC2_CSC3_pirna,'mirna': CSC1_CSC2_CSC3_mirna}
ax = sns.kdeplot(data=CSC1_CSC2_CSC3,bw=0.3)
plt.ylabel("Probability density")
plt.xlabel('CSC1_CSC2_CSC3 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.3 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
#density plot
CSC2_CSC1_CSC3 = {'sirna': CSC2_CSC1_CSC3_sirna,'pirna': CSC2_CSC1_CSC3_pirna,'mirna': CSC2_CSC1_CSC3_mirna}
ax = sns.kdeplot(data=CSC2_CSC1_CSC3)
plt.ylabel("Probability density")
plt.xlabel('CSC2_CSC1_CSC3 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
#density plot
CSC2_CSC3_CSC1 = {'sirna': CSC2_CSC3_CSC1_sirna,'pirna': CSC2_CSC3_CSC1_pirna,'mirna': CSC2_CSC3_CSC1_mirna}
ax = sns.kdeplot(data=CSC2_CSC3_CSC1)
plt.ylabel("Probability density")
plt.xlabel('CSC2_CSC3_CSC1 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
#density plot
BB2_BB3_pBB1 = {'sirna': BB2_BB3_pBB1_sirna,'pirna': BB2_BB3_pBB1_pirna,'mirna': BB2_BB3_pBB1_mirna}
ax = sns.kdeplot(data=BB2_BB3_pBB1,bw=1)
plt.ylabel("Probability density")
plt.xlabel('BB2_BB3_pBB1 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
#density plot
BB3_pBB1_pBB2 = {'sirna': BB3_pBB1_pBB2_sirna,'pirna': BB3_pBB1_pBB2_pirna,'mirna': BB3_pBB1_pBB2_mirna}
ax = sns.kdeplot(data=BB3_pBB1_pBB2,bw=1)
plt.ylabel("Probability density")
plt.xlabel('BB3_pBB1_pBB2 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
#density plot
ASC1_BB3_pBB1 = {'sirna': ASC1_BB3_pBB1_sirna,'pirna': ASC1_BB3_pBB1_pirna,'mirna': ASC1_BB3_pBB1_mirna}
ax = sns.kdeplot(data=ASC1_BB3_pBB1,bw=1)
plt.ylabel("Probability density")
plt.xlabel('ASC1_BB3_pBB1 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
#density plot
USC1_BB3_pBB1 = {'sirna': USC1_BB3_pBB1_sirna,'pirna': USC1_BB3_pBB1_pirna,'mirna': USC1_BB3_pBB1_mirna}
ax = sns.kdeplot(data=USC1_BB3_pBB1,bw=1)
plt.ylabel("Probability density")
plt.xlabel('USC1_BB3_pBB1 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
#density plot
GSC1_BB3_pBB1 = {'sirna': GSC1_BB3_pBB1_sirna,'pirna': GSC1_BB3_pBB1_pirna,'mirna': GSC1_BB3_pBB1_mirna}
ax = sns.kdeplot(data=GSC1_BB3_pBB1,bw=1)
plt.ylabel("Probability density")
plt.xlabel('GSC1_BB3_pBB1 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
#density plot
CSC1_BB3_pBB1 = {'sirna': CSC1_BB3_pBB1_sirna,'pirna': CSC1_BB3_pBB1_pirna,'mirna': CSC1_BB3_pBB1_mirna}
ax = sns.kdeplot(data=CSC1_BB3_pBB1,bw=0.7)
plt.ylabel("Probability density")
plt.xlabel('CSC1_BB3_pBB1 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.
