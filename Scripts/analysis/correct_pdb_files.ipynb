# %%
with open("pdb_file.txt") as f:
    lines = f.readlines()

# %%
i = 0
new_lines = []
for i in range(0,len(lines),2):
    print(lines[i],end='')
    new_lines.append(lines[i])
# Out:
# ATOM    892  O3'A  C D   1     -11.398  37.360  86.614  0.60 24.03           O
# ATOM    894  P  A  C D   1     -11.903  36.706  87.889  0.60 26.14           P
# ATOM    896  O1PA  C D   1     -12.702  37.680  88.743  0.60 28.36           O
# ATOM    898  O2PA  C D   1     -12.622  35.385  87.675  0.60 26.53           O
# ATOM    900  O5'A  C D   1     -10.574  36.348  88.750  0.60 24.64           O
# ATOM    902  C5'A  C D   1      -9.658  37.384  89.122  0.60 26.15           C
# ATOM    904  C4'A  C D   1      -8.489  36.798  89.860  0.60 26.65           C
# ATOM    906  O4'A  C D   1      -8.930  36.313  91.156  0.60 26.54           O
# ATOM    908  C3'A  C D   1      -7.869  35.574  89.215  0.60 26.36           C
# ATOM    910  O3'A  C D   1      -6.955  35.925  88.195  0.60 25.91           O
# ATOM    912  C2'A  C D   1      -7.162  34.940  90.396  0.60 26.54           C
# ATOM    914  O2'A  C D   1      -5.978  35.640  90.720  0.60 26.15           O
# ...

# %%
s = ''
s = s + ' ' + 'a' + ' '+ 'b'
s
# Out:
# ' a b'

# %%
ct = 100
s = ''
for line in new_lines:
    for i in range(0,len(line.split(' ')[0:7])):
        if(line.split(' ')[i] == ' '):
            s = s + ' '
            
        else:
            s = s + line.split(' ')[i]
#         print(line.split(' ')[i])
    print(s)
    break
# Out:
# ATOM1

# %%
for line in new_lines:
    for strn in line.split(' '):
        print(strn,end=' ')
# new_lines[0].split(' ')[]
# Out:
# ATOM      1  O3'A  C E   1       4.957  39.542 -14.282  0.50129.98           O
#  ATOM      3  P  A  C E   1       4.436  40.379 -15.386  0.50129.95           P
#  ATOM      5  O1PA  C E   1       2.978  40.404 -15.652  0.50130.05           O
#  ATOM      7  O2PA  C E   1       4.862  41.771 -15.118  0.50129.91           O
#  ATOM      9  O5'A  C E   1       5.166  39.855 -16.710  0.50129.89           O
#  ATOM     11  C5'A  C E   1       5.056  40.545 -17.954  0.50129.97           C
#  ATOM     13  C4'A  C E   1       6.424  40.853 -18.544  0.50130.09           C
#  ATOM     15  O4'A  C E   1       6.820  42.211 -18.203  0.50130.44           O
#  ATOM     17  C3'A  C E   1       7.593  40.026 -18.018  0.50129.97           C
#  ATOM     19  O3'A  C E   1       7.657  38.724 -18.580  0.50129.64           O
#  ATOM     21  C2'A  C E   1       8.783  40.893 -18.422  0.50130.06           C
#  ATOM     23  O2'A  C E   1       9.124  40.767 -19.792  0.50129.87           O
# ...
