# %%
f = open("CG_test.pdb","r")
lines = f.read().split("\n")
# print(lines)
lines[-1]
# Out:
# ''

# %%
distance_params = dict.fromkeys(['BB1-BB2','BB2-BB3','BB3-ASC1','ASC2-ASC4','ASC1-ASC3','ASC1-ASC2','ASC2-ASC3','ASC3-ASC4',
                   'ASC4-ASC1','BB3-USC1','USC1-USC2','USC2-USC3','USC3-USC1','BB3-GSC1','GSC2-GSC4','GSC1-GSC3',
                  'GSC1-GSC2','GSC2-GSC3','GSC3-GSC4','GSC4-GSC1','BB3-CSC1','CSC1-CSC2','CSC2-CSC3','CSC3-CSC1',
                  'BB3-+BB1'])

angle_params = dict.fromkeys(['BB1-BB2-BB3','BB2-BB3-ASC1','BB3-BB2-ASC1','BB3-ASC1-ASC2','BB3-ASC1-ASC4','ASC1-ASC2-ASC3',
                'ASC2-ASC1-ASC4','ASC2-ASC3-ASC4','ASC3-ASC4-ASC1','BB2-BB3-USC1','BB3-BB2-USC1','BB3-USC1-USC2',
               'BB2-USC1-USC3','BB3-USC1-USC3','USC1-USC2-USC3','USC2-USC1-USC3','USC2-USC3-USC1','BB2-BB3-GSC1',
                'BB3-BB2-GSC1','BB3-GSC1-GSC2','BB3-GSC1-GSC4','GSC1-GSC2-GSC3','GSC2-GSC1-GSC4','GSC2-GSC3-GSC4','GSC3-GSC4-GSC1',
               'BB2-BB3-CSC1','BB3-BB2-CSC1','BB3-CSC1-CSC2','BB3-CSC1-CSC3','BB2-CSC1-CSC3','CSC1-CSC2-CSC3',
                'CSC2-CSC1-CSC3','CSC2-CSC3-CSC1','BB2-BB3-+BB1','BB3-+BB1-+BB2','ASC1-BB3-+BB1','USC1-BB3-+BB1',
               'GSC1-BB3-+BB1','CSC1-BB3-+BB1'])

dihedral_params = dict.fromkeys(['BB1-BB2-BB3-ASC1','BB2-BB3-ASC1-ASC2','BB2-BB3-ASC1-ASC4','ASC1-ASC2-ASC3-ASC4','BB1-BB2-BB3-USC1',
                  'BB2-BB3-USC1-USC2','BB2-BB3-USC1-USC3','BB1-BB2-BB3-GSC1','BB2-BB3-GSC1-GSC2','BB2-BB3-GSC1-GSC4',
                  'GSC1-GSC2-GSC3-GSC4','BB1-BB2-BB3-CSC1','BB2-BB3-CSC1-CSC2','BB2-BB3-CSC1-CSC3','BB1-BB2-BB3-+BB1',
                  'BB2-BB3-+BB1-+BB2','BB3-+BB1-+BB2-+BB3'])

# %%
for key in distance_params:
    distance_params[key] = []
for key in angle_params:
    angle_params[key] = []
for key in dihedral_params:
    dihedral_params[key] = []

# %%
for line in lines[:-1]:
    print(line)
    if(line.split()[2] == "BB1"):
        BB1 = int(line.split()[1])
        BB2 = BB1+1
        BB3 = BB1+2
        BB1p = BB1+3
        BB2p = BB1+4
        BB3p = BB1+5
        distance_params['BB1-BB2'].append(str(BB1)+' '+str(BB2))
        distance_params['BB2-BB3'].append(str(BB2)+' '+str(BB3))
        angle_params['BB1-BB2-BB3'].append(str(BB1)+' '+str(BB2)+ ' '+str(BB3))
        angle_params['BB2-BB3-+BB1'].append(str(BB1)+' '+str(BB2)+ ' '+str(BB3))
        angle_params['BB3-+BB1-+BB2'].append(str(BB1)+' '+str(BB2)+ ' '+str(BB3))
        dihedral_params['BB1-BB2-BB3-+BB1'].append(str(BB1)+' '+str(BB2)+' '+str(BB3)+' '+str(BB1p))
        dihedral_params['BB2-BB3-+BB1-+BB2'].append(str(BB2)+' '+str(BB3)+' '+str(BB1p)+' '+str(BB2p))
        dihedral_params['BB3-+BB1-+BB2-+BB3'].append(str(BB3)+' '+str(BB1)+' '+str(BB2p)+' '+str(BB3p))
    elif(line.split()[2] == "BB2"):
        distance_params['BB2-BB3'].append((line.split()[1]+' '+str(int(line.split()[1])+1)))
    elif(line.split()[2] == "ASC1"):
        ASC1 = int(line.split()[1])
        ASC2 = ASC1+1
        ASC3 = ASC1+2
        ASC4 = ASC1+3
        BB1 = ASC1 - 3
        BB2 = ASC1 - 2
        BB3 = ASC1 - 1 
        distance_params['BB3-ASC1'].append(str(BB3)+' '+str(ASC1))
        distance_params['ASC2-ASC4'].append(str(ASC2)+' '+str(ASC4))
        distance_params['ASC1-ASC3'].append(str(ASC1)+' '+str(ASC3))
        distance_params['ASC1-ASC2'].append(str(ASC1)+' '+str(ASC2))
        distance_params['ASC2-ASC3'].append(str(ASC2)+' '+str(ASC3))
        distance_params['ASC3-ASC4'].append(str(ASC3)+' '+str(ASC4))
        distance_params['ASC4-ASC1'].append(str(ASC4)+' '+str(ASC1))
        angle_params['BB2-BB3-ASC1'].append(str(BB2)+' '+str(BB3)+' '+str(ASC1))
        angle_params['BB3-BB2-ASC1'].append(str(BB3)+' '+str(BB2)+' '+str(ASC1))
        angle_params['BB3-ASC1-ASC2'].append(str(BB3)+' '+str(ASC1)+' '+str(ASC2))
        angle_params['BB3-ASC1-ASC4'].append(str(BB3)+' '+str(ASC1)+' '+str(ASC4))
        angle_params['ASC1-ASC2-ASC3'].append(str(ASC1)+' '+str(ASC2)+' '+str(ASC3))
        angle_params['ASC2-ASC1-ASC4'].append(str(ASC2)+' '+str(ASC1)+' '+str(ASC4))
        angle_params['ASC3-ASC4-ASC1'].append(str(ASC3)+' '+str(ASC4)+' '+str(ASC1))
        dihedral_params['BB1-BB2-BB3-ASC1'].append(str(BB1)+' '+str(BB2)+' '+str(BB3)+' '+str(ASC1))
        dihedral_params['BB2-BB3-ASC1-ASC2'].append(str(BB2)+' '+str(BB3)+' '+str(ASC1)+' '+str(ASC2))
        dihedral_params['BB2-BB3-ASC1-ASC4'].append(str(BB2)+' '+str(BB3)+' '+str(ASC1)+' '+str(ASC4))
        dihedral_params['ASC1-ASC2-ASC3-ASC4'].append(str(ASC1)+' '+str(ASC2)+' '+str(ASC3)+' '+str(ASC4))
    elif(line.split()[2] == "GSC1"):
        GSC1 = int(line.split()[1])
        GSC2 = GSC1+1
        GSC3 = GSC1+2
        GSC4 = GSC2+3
        BB1 = GSC1 - 3
        BB2 = GSC1 - 2
        BB3 = GSC1 - 1 
        distance_params['BB3-GSC1'].append(str(BB3)+' '+str(GSC1))
        distance_params['GSC2-GSC4'].append(str(GSC2)+' '+str(GSC4))
        distance_params['GSC1-GSC3'].append(str(GSC1)+' '+str(GSC3))
        distance_params['GSC1-GSC2'].append(str(GSC1)+' '+str(GSC2))
        distance_params['GSC2-GSC3'].append(str(GSC2)+' '+str(GSC3))
        distance_params['GSC3-GSC4'].append(str(GSC3)+' '+str(GSC4))
        distance_params['GSC4-GSC1'].append(str(GSC4)+' '+str(GSC1))
        angle_params['BB2-BB3-GSC1'].append(str(BB2)+' '+str(BB3)+' '+str(GSC1))
        angle_params['BB3-BB2-GSC1'].append(str(BB3)+' '+str(BB2)+' '+str(GSC1))
        angle_params['BB3-GSC1-GSC2'].append(str(BB3)+' '+str(GSC1)+' '+str(GSC2))
        angle_params['BB3-GSC1-GSC4'].append(str(BB3)+' '+str(GSC1)+' '+str(GSC4))
        angle_params['GSC1-GSC2-GSC3'].append(str(GSC1)+' '+str(GSC2)+' '+str(GSC3))
        angle_params['GSC2-GSC1-GSC4'].append(str(GSC2)+' '+str(GSC1)+' '+str(GSC4))
        angle_params['GSC3-GSC4-GSC1'].append(str(GSC3)+' '+str(GSC4)+' '+str(GSC1))
        dihedral_params['BB1-BB2-BB3-GSC1'].append(str(BB1)+' '+str(BB2)+' '+str(BB3)+' '+str(GSC1))
        dihedral_params['BB2-BB3-GSC1-GSC2'].append(str(BB2)+' '+str(BB3)+' '+str(GSC1)+' '+str(GSC2))
        dihedral_params['BB2-BB3-GSC1-GSC4'].append(str(BB2)+' '+str(BB3)+' '+str(GSC1)+' '+str(GSC4))
        dihedral_params['GSC1-GSC2-GSC3-GSC4'].append(str(GSC1)+' '+str(GSC2)+' '+str(GSC3)+' '+str(GSC4))
    elif(line.split()[2] == "USC1"):
        USC1 = int(line.split()[1])
        USC2 = USC1+1
        USC3 = USC1+2
        BB1 = USC1 - 3
        BB2 = USC1 - 2
        BB3 = USC1 - 1 
            
        distance_params['BB3-USC1'].append(str(BB3)+' '+str(USC1))
        distance_params['USC1-USC2'].append(str(USC1)+' '+str(USC2))
        distance_params['USC2-USC3'].append(str(USC2)+' '+str(USC3))
        distance_params['USC3-USC1'].append(str(USC3)+' '+str(USC1))
        angle_params['BB2-BB3-USC1'].append(str(BB2)+' '+str(BB3)+' '+str(USC1))
        angle_params['BB3-BB2-USC1'].append(str(BB3)+' '+str(BB2)+' '+str(USC1))
        angle_params['BB3-USC1-USC2'].append(str(BB3)+' '+str(USC1)+' '+str(USC2))
        angle_params['BB2-USC1-USC3'].append(str(BB2)+' '+str(USC1)+' '+str(USC3))
        angle_params['BB3-USC1-USC3'].append(str(BB3)+' '+str(USC1)+' '+str(USC3))
        angle_params['USC1-USC2-USC3'].append(str(USC1)+' '+str(USC2)+' '+str(USC3))
        angle_params['USC2-USC1-USC3'].append(str(USC2)+' '+str(USC1)+' '+str(USC3))
        angle_params['USC2-USC3-USC1'].append(str(USC2)+' '+str(USC3)+' '+str(USC1))
        dihedral_params['BB1-BB2-BB3-USC1'].append(str(BB1)+' '+str(BB2)+' '+str(BB3)+' '+str(USC1))
        dihedral_params['BB2-BB3-USC1-USC2'].append(str(BB2)+' '+str(BB3)+' '+str(USC1)+' '+str(USC2))
        dihedral_params['BB2-BB3-USC1-USC3'].append(str(BB2)+' '+str(BB3)+' '+str(USC1)+' '+str(USC3))
    elif(line.split()[2] == "CSC1"):
        CSC1 = int(line.split()[1])
        CSC2 = CSC1+1
        CSC3 = CSC1+2
        BB1 = CSC1 - 3
        BB2 = CSC1 - 2
        BB3 = CSC1 - 1 
            
        distance_params['BB3-CSC1'].append(str(BB3)+' '+str(CSC1))
        distance_params['CSC1-CSC2'].append(str(CSC1)+' '+str(CSC2))
        distance_params['CSC2-CSC3'].append(str(CSC2)+' '+str(CSC3))
        distance_params['CSC3-CSC1'].append(str(CSC3)+' '+str(CSC1))
        angle_params['BB2-BB3-CSC1'].append(str(BB2)+' '+str(BB3)+' '+str(CSC1))
        angle_params['BB3-BB2-CSC1'].append(str(BB3)+' '+str(BB2)+' '+str(CSC1))
        angle_params['BB3-CSC1-CSC2'].append(str(BB3)+' '+str(CSC1)+' '+str(CSC2))
        angle_params['BB2-CSC1-CSC3'].append(str(BB2)+' '+str(CSC1)+' '+str(CSC3))
        angle_params['BB3-CSC1-CSC3'].append(str(BB3)+' '+str(CSC1)+' '+str(CSC3))
        angle_params['CSC1-CSC2-CSC3'].append(str(CSC1)+' '+str(CSC2)+' '+str(CSC3))
        angle_params['CSC2-CSC1-CSC3'].append(str(CSC2)+' '+str(CSC1)+' '+str(CSC3))
        angle_params['CSC2-CSC3-CSC1'].append(str(CSC2)+' '+str(CSC3)+' '+str(CSC1))
        dihedral_params['BB1-BB2-BB3-CSC1'].append(str(BB1)+' '+str(BB2)+' '+str(BB3)+' '+str(CSC1))
        dihedral_params['BB2-BB3-CSC1-CSC2'].append(str(BB2)+' '+str(BB3)+' '+str(CSC1)+' '+str(CSC2))
        dihedral_params['BB2-BB3-CSC1-CSC3'].append(str(BB2)+' '+str(BB3)+' '+str(CSC1)+' '+str(CSC3))
# Out:
# ATOM      1 BB1  U   C   1      18.292  35.167  49.649  1.00  0.00
# ATOM      2 BB2  U   C   1      19.580  35.775  46.682  1.00  0.00
# ATOM      3 BB3  U   C   1      19.032  36.723  44.217  1.00  0.00
# ATOM      4 USC1 U   C   1      17.917  33.743  44.949  1.00  0.00
# ATOM      5 USC2 U   C   1      17.475  33.065  42.812  1.00  0.00
# ATOM      6 USC3 U   C   1      15.872  31.939  44.953  1.00  0.00
# ATOM      7 BB1  C   C   2      17.060  39.317  45.402  1.00  0.00
# ATOM      8 BB2  C   C   2      16.846  38.606  42.161  1.00  0.00
# ATOM      9 BB3  C   C   2      15.080  38.679  40.171  1.00  0.00
# ATOM     10 CSC1 C   C   2      15.044  35.983  42.021  1.00  0.00
# ATOM     11 CSC2 C   C   2      13.782  34.747  40.565  1.00  0.00
# ATOM     12 CSC3 C   C   2      13.573  34.121  43.395  1.00  0.00
# ATOM     13 BB1  G   C   3      13.664  41.439  41.821  1.00  0.00
# ATOM     14 BB2  G   C   3      11.720  39.983  39.573  1.00  0.00
# ...

# %%
dihedral_params
# Out:
# {'ASC1-ASC2-ASC3-ASC4': ['23 24 25 26',
#   '30 31 32 33',
#   '50 51 52 53',
#   '107 108 109 110',
#   '159 160 161 162',
#   '199 200 201 202',
#   '206 207 208 209',
#   '219 220 221 222',
#   '257 258 259 260'],
#  'BB1-BB2-BB3-+BB1': ['1 2 3 4',
#   '7 8 9 10',
#   '13 14 15 16',
#   '20 21 22 23',
#   '27 28 29 30',
#   '34 35 36 37',
#   '41 42 43 44',
#   '47 48 49 50',
#   '54 55 56 57',
#   '60 61 62 63',
#   '66 67 68 69',
#   '72 73 74 75',
#   '78 79 80 81',
#   '85 86 87 88',
#   '91 92 93 94',
#   '98 99 100 101',
#   '104 105 106 107',
#   '111 112 113 114',
#   '117 118 119 120',
#   '124 125 126 127',
#   '130 131 132 133',
#   '137 138 139 140',
#   '143 144 145 146',
#   '150 151 152 153',
#   '156 157 158 159',
#   '163 164 165 166',
#   '169 170 171 172',
#   '176 177 178 179',
#   '182 183 184 185',
#   '189 190 191 192',
#   '196 197 198 199',
#   '203 204 205 206',
#   '210 211 212 213',
#   '216 217 218 219',
#   '223 224 225 226',
#   '229 230 231 232',
# ...

# %%
angle_params
# Out:
# {'ASC1-ASC2-ASC3': ['23 24 25',
#   '30 31 32',
#   '50 51 52',
#   '107 108 109',
#   '159 160 161',
#   '199 200 201',
#   '206 207 208',
#   '219 220 221',
#   '257 258 259'],
#  'ASC1-BB3-+BB1': [],
#  'ASC2-ASC1-ASC4': ['24 23 26',
#   '31 30 33',
#   '51 50 53',
#   '108 107 110',
#   '160 159 162',
#   '200 199 202',
#   '207 206 209',
#   '220 219 222',
#   '258 257 260'],
#  'ASC2-ASC3-ASC4': [],
#  'ASC3-ASC4-ASC1': ['25 26 23',
#   '32 33 30',
#   '52 53 50',
#   '109 110 107',
#   '161 162 159',
#   '201 202 199',
#   '208 209 206',
#   '221 222 219',
#   '259 260 257'],
#  'BB1-BB2-BB3': ['1 2 3',
#   '7 8 9',
#   '13 14 15',
#   '20 21 22',
#   '27 28 29',
#   '34 35 36',
#   '41 42 43',
#   '47 48 49',
#   '54 55 56',
#   '60 61 62',
#   '66 67 68',
#   '72 73 74',
#   '78 79 80',
#   '85 86 87',
#   '91 92 93',
#   '98 99 100',
#   '104 105 106',
#   '111 112 113',
#   '117 118 119',
#   '124 125 126',
#   '130 131 132',
#   '137 138 139',
#   '143 144 145',
# ...

# %%
distance_params
# Out:
# {'ASC1-ASC2': ['23 24',
#   '30 31',
#   '50 51',
#   '107 108',
#   '159 160',
#   '199 200',
#   '206 207',
#   '219 220',
#   '257 258'],
#  'ASC1-ASC3': ['23 25',
#   '30 32',
#   '50 52',
#   '107 109',
#   '159 161',
#   '199 201',
#   '206 208',
#   '219 221',
#   '257 259'],
#  'ASC2-ASC3': ['24 25',
#   '31 32',
#   '51 52',
#   '108 109',
#   '160 161',
#   '200 201',
#   '207 208',
#   '220 221',
#   '258 259'],
#  'ASC2-ASC4': ['24 26',
#   '31 33',
#   '51 53',
#   '108 110',
#   '160 162',
#   '200 202',
#   '207 209',
#   '220 222',
#   '258 260'],
#  'ASC3-ASC4': ['25 26',
#   '32 33',
#   '52 53',
#   '109 110',
#   '161 162',
#   '201 202',
#   '208 209',
#   '221 222',
#   '259 260'],
#  'ASC4-ASC1': ['26 23',
#   '33 30',
#   '53 50',
#   '110 107',
#   '162 159',
#   '202 199',
#   '209 206',
#   '222 219',
#   '260 257'],
#  'BB1-BB2': ['1 2',
#   '7 8',
#   '13 14',
#   '20 21',
#   '27 28',
#   '34 35',
#   '41 42',
#   '47 48',
#   '54 55',
#   '60 61',
# ...
