# %%
import pandas as pd
import seaborn as sns
import math
from scipy import stats
import numpy as np
import matplotlib.pyplot as plot
import math
from scipy.optimize import curve_fit
# %matplotlib inline

# %%
dihedral_dict = dict.fromkeys(['BB1_BB2_BB3_ASC1','BB2_BB3_ASC1_ASC2','BB2_BB3_ASC1_ASC4',\
'BB2_BB3_ASC1_ASC4','ASC1_ASC2_ASC3_ASC4','BB1_BB2_BB3_USC1','BB2_BB3_USC1_USC2','BB2_BB3_USC1_USC3','BB1_BB2_BB3_GSC1',\
'BB2_BB3_GSC1_GSC2','BB2_BB3_GSC1_GSC4','GSC1_GSC2_GSC3_GSC4','BB1_BB2_BB3_CSC1','BB1_BB2_BB3_CSC1','BB2_BB3_CSC1_CSC2',
'BB2_BB3_CSC1_CSC2','BB2_BB3_CSC1_CSC3','BB1_BB2_BB3_pBB1','BB2_BB3_pBB1_pBB2','BB3_pBB1_pBB2_pBB3','BB3_pBB1_pBB2_pBB3'
])

# %%
df_sirna_dihedral = pd.read_csv('dihedral_final_allmolecules.csv')
df_pirna_dihedral = pd.read_csv('../../pirna_CG_model/analysis_scripts/dihedral_final_allmolecules.xvg')
df_mirna_dihedral = pd.read_csv('../../mirna_CG_model/analysis_scripts/dihedral_final.xvg')

# %%
#sirna
BB1_BB2_BB3_ASC1_sirna_dihedral = df_sirna_dihedral['BB1_BB2_BB3_ASC1']
BB2_BB3_ASC1_ASC2_sirna_dihedral = df_sirna_dihedral['BB2_BB3_ASC1_ASC2']
BB2_BB3_ASC1_ASC4_sirna_dihedral = df_sirna_dihedral['BB2_BB3_ASC1_ASC4']
ASC1_ASC2_ASC3_ASC4_sirna_dihedral = df_sirna_dihedral['ASC1_ASC2_ASC3_ASC4']
BB1_BB2_BB3_USC1_sirna_dihedral = df_sirna_dihedral['BB1_BB2_BB3_USC1']
BB2_BB3_USC1_USC2_sirna_dihedral = df_sirna_dihedral['BB2_BB3_USC1_USC2']
BB2_BB3_USC1_USC3_sirna_dihedral = df_sirna_dihedral['BB2_BB3_USC1_USC3']
BB1_BB2_BB3_GSC1_sirna_dihedral = df_sirna_dihedral['BB1_BB2_BB3_GSC1']
BB2_BB3_GSC1_GSC2_sirna_dihedral = df_sirna_dihedral['BB2_BB3_GSC1_GSC2']
BB2_BB3_GSC1_GSC4_sirna_dihedral = df_sirna_dihedral['BB2_BB3_GSC1_GSC4']
GSC1_GSC2_GSC3_GSC4_sirna_dihedral = df_sirna_dihedral['GSC1_GSC2_GSC3_GSC4']
BB1_BB2_BB3_CSC1_sirna_dihedral = df_sirna_dihedral['BB1_BB2_BB3_CSC1']
BB2_BB3_CSC1_CSC2_sirna_dihedral = df_sirna_dihedral['BB2_BB3_CSC1_CSC2']
BB2_BB3_CSC1_CSC3_sirna_dihedral = df_sirna_dihedral['BB2_BB3_CSC1_CSC3']
BB1_BB2_BB3_pBB1_sirna_dihedral = df_sirna_dihedral['BB1_BB2_BB3_pBB1']
BB2_BB3_pBB1_pBB2_sirna_dihedral = df_sirna_dihedral['BB2_BB3_pBB1_pBB2']
BB3_pBB1_pBB2_pBB3_sirna_dihedral = df_sirna_dihedral['BB3_pBB1_pBB2_pBB3']

#pirna
BB1_BB2_BB3_ASC1_pirna_dihedral = df_pirna_dihedral['BB1_BB2_BB3_ASC1']
BB2_BB3_ASC1_ASC2_pirna_dihedral = df_pirna_dihedral['BB2_BB3_ASC1_ASC2']
BB2_BB3_ASC1_ASC4_pirna_dihedral = df_pirna_dihedral['BB2_BB3_ASC1_ASC4']
ASC1_ASC2_ASC3_ASC4_pirna_dihedral = df_pirna_dihedral['ASC1_ASC2_ASC3_ASC4']
BB1_BB2_BB3_USC1_pirna_dihedral = df_pirna_dihedral['BB1_BB2_BB3_USC1']
BB2_BB3_USC1_USC2_pirna_dihedral = df_pirna_dihedral['BB2_BB3_USC1_USC2']
BB2_BB3_USC1_USC3_pirna_dihedral = df_pirna_dihedral['BB2_BB3_USC1_USC3']
BB1_BB2_BB3_GSC1_pirna_dihedral = df_pirna_dihedral['BB1_BB2_BB3_GSC1']
BB2_BB3_GSC1_GSC2_pirna_dihedral = df_pirna_dihedral['BB2_BB3_GSC1_GSC2']
BB2_BB3_GSC1_GSC4_pirna_dihedral = df_pirna_dihedral['BB2_BB3_GSC1_GSC4']
GSC1_GSC2_GSC3_GSC4_pirna_dihedral = df_pirna_dihedral['GSC1_GSC2_GSC3_GSC4']
BB1_BB2_BB3_CSC1_pirna_dihedral = df_pirna_dihedral['BB1_BB2_BB3_CSC1']
BB2_BB3_CSC1_CSC2_pirna_dihedral = df_pirna_dihedral['BB2_BB3_CSC1_CSC2']
BB2_BB3_CSC1_CSC3_pirna_dihedral = df_pirna_dihedral['BB2_BB3_CSC1_CSC3']
BB1_BB2_BB3_pBB1_pirna_dihedral = df_pirna_dihedral['BB1_BB2_BB3_pBB1']
BB2_BB3_pBB1_pBB2_pirna_dihedral = df_pirna_dihedral['BB2_BB3_pBB1_pBB2']
BB3_pBB1_pBB2_pBB3_pirna_dihedral = df_pirna_dihedral['BB3_pBB1_pBB2_pBB3']

#mirna
BB1_BB2_BB3_ASC1_mirna_dihedral = df_mirna_dihedral['BB1_BB2_BB3_ASC1']
BB2_BB3_ASC1_ASC2_mirna_dihedral = df_mirna_dihedral['BB2_BB3_ASC1_ASC2']
BB2_BB3_ASC1_ASC4_mirna_dihedral = df_mirna_dihedral['BB2_BB3_ASC1_ASC4']
ASC1_ASC2_ASC3_ASC4_mirna_dihedral = df_mirna_dihedral['ASC1_ASC2_ASC3_ASC4']
BB1_BB2_BB3_USC1_mirna_dihedral = df_mirna_dihedral['BB1_BB2_BB3_USC1']
BB2_BB3_USC1_USC2_mirna_dihedral = df_mirna_dihedral['BB2_BB3_USC1_USC2']
BB2_BB3_USC1_USC3_mirna_dihedral = df_mirna_dihedral['BB2_BB3_USC1_USC3']
BB1_BB2_BB3_GSC1_mirna_dihedral = df_mirna_dihedral['BB1_BB2_BB3_GSC1']
BB2_BB3_GSC1_GSC2_mirna_dihedral = df_mirna_dihedral['BB2_BB3_GSC1_GSC2']
BB2_BB3_GSC1_GSC4_mirna_dihedral = df_mirna_dihedral['BB2_BB3_GSC1_GSC4']
GSC1_GSC2_GSC3_GSC4_mirna_dihedral = df_mirna_dihedral['GSC1_GSC2_GSC3_GSC4']
BB1_BB2_BB3_CSC1_mirna_dihedral = df_mirna_dihedral['BB1_BB2_BB3_CSC1']
BB2_BB3_CSC1_CSC2_mirna_dihedral = df_mirna_dihedral['BB2_BB3_CSC1_CSC2']
BB2_BB3_CSC1_CSC3_mirna_dihedral = df_mirna_dihedral['BB2_BB3_CSC1_CSC3']
BB1_BB2_BB3_pBB1_mirna_dihedral = df_mirna_dihedral['BB1_BB2_BB3_pBB1']
BB2_BB3_pBB1_pBB2_mirna_dihedral = df_mirna_dihedral['BB2_BB3_pBB1_pBB2']
BB3_pBB1_pBB2_pBB3_mirna_dihedral = df_mirna_dihedral['BB3_pBB1_pBB2_pBB3']

# %%
#density plot
import matplotlib.pyplot as plt
BB1_BB2_BB3_ASC1 = {'sirna': BB1_BB2_BB3_ASC1_sirna_dihedral,'pirna': BB1_BB2_BB3_ASC1_pirna_dihedral,'mirna': BB1_BB2_BB3_ASC1_mirna_dihedral}
ax = sns.kdeplot(data=BB1_BB2_BB3_ASC1,bw=0.3)
plt.ylabel("Probability density")
plt.xlabel('BB1_BB2_BB3_ASC1 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.3 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
#density plot
BB2_BB3_ASC1_ASC2 = {'sirna': BB2_BB3_ASC1_ASC2_sirna_dihedral,'pirna': BB2_BB3_ASC1_ASC2_pirna_dihedral,'mirna': BB2_BB3_ASC1_ASC2_mirna_dihedral}
ax = sns.kdeplot(data=BB2_BB3_ASC1_ASC2,bw=0.5)
plt.ylabel("Probability density")
plt.xlabel('BB2_BB3_ASC1_ASC2 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
#density plot
BB2_BB3_ASC1_ASC4 = {'sirna': BB2_BB3_ASC1_ASC4_sirna_dihedral,'pirna': BB2_BB3_ASC1_ASC4_pirna_dihedral,'mirna': BB2_BB3_ASC1_ASC4_mirna_dihedral}
ax = sns.kdeplot(data=BB2_BB3_ASC1_ASC4)
plt.ylabel("Probability density")
plt.xlabel('BB2_BB3_ASC1_ASC4 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)
# No handles with labels found to put in legend.

# %%
#density plot
ASC1_ASC2_ASC3_ASC4 = {'sirna': ASC1_ASC2_ASC3_ASC4_sirna_dihedral,'pirna': ASC1_ASC2_ASC3_ASC4_pirna_dihedral,'mirna': ASC1_ASC2_ASC3_ASC4_mirna_dihedral}
ax = sns.kdeplot(data=ASC1_ASC2_ASC3_ASC4,bw=0.2)
plt.ylabel("Probability density")
plt.xlabel('ASC1_ASC2_ASC3_ASC4 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.2 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
#density plot
BB1_BB2_BB3_USC1 = {'sirna': BB1_BB2_BB3_USC1_sirna_dihedral,'pirna': BB1_BB2_BB3_USC1_pirna_dihedral,'mirna': BB1_BB2_BB3_USC1_mirna_dihedral}
ax = sns.kdeplot(data=BB1_BB2_BB3_USC1,bw=0.2)
plt.ylabel("Probability density")
plt.xlabel('BB1_BB2_BB3_USC1 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.2 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
#density plot
BB2_BB3_USC1_USC2 = {'sirna': BB2_BB3_USC1_USC2_sirna_dihedral,'pirna':BB2_BB3_USC1_USC2_pirna_dihedral,'mirna': BB2_BB3_USC1_USC2_mirna_dihedral}
ax = sns.kdeplot(data=BB2_BB3_USC1_USC2)
plt.ylabel("Probability density")
plt.xlabel('BB2_BB3_USC1_USC2 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
#density plot
BB2_BB3_USC1_USC3 = {'sirna': BB2_BB3_USC1_USC3_sirna_dihedral,'pirna': BB2_BB3_USC1_USC3_pirna_dihedral,'mirna': BB2_BB3_USC1_USC3_mirna_dihedral}
ax = sns.kdeplot(data=BB2_BB3_USC1_USC3)
plt.ylabel("Probability density")
plt.xlabel('BB2_BB3_USC1_USC3 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
#density plot
BB1_BB2_BB3_GSC1 = {'sirna': BB1_BB2_BB3_GSC1_sirna_dihedral,'pirna': BB1_BB2_BB3_GSC1_pirna_dihedral,'mirna': BB1_BB2_BB3_GSC1_mirna_dihedral}
ax = sns.kdeplot(data=BB1_BB2_BB3_GSC1).set(title='BB1_BB2_BB3_GSC1')
plt.ylabel("Probability density")
plt.xlabel('BB1_BB2_BB3_GSC1 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
#density plot
BB2_BB3_GSC1_GSC2 = {'sirna': BB2_BB3_GSC1_GSC2_sirna_dihedral,'pirna': BB2_BB3_GSC1_GSC2_pirna_dihedral,'mirna': BB2_BB3_GSC1_GSC2_mirna_dihedral}
ax = sns.kdeplot(data=BB2_BB3_GSC1_GSC2,bw=1.2)
plt.ylabel("Probability density")
plt.xlabel('BB2_BB3_GSC1_GSC2 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 1.2 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
#density plot
BB2_BB3_GSC1_GSC4 = {'sirna': BB2_BB3_GSC1_GSC4_sirna_dihedral,'pirna': BB2_BB3_GSC1_GSC4_pirna_dihedral,'mirna': BB2_BB3_GSC1_GSC4_mirna_dihedral}
ax = sns.kdeplot(data=BB2_BB3_GSC1_GSC4,bw=1)
plt.ylabel("Probability density")
plt.xlabel('BB2_BB3_GSC1_GSC4 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
#density plot
GSC1_GSC2_GSC3_GSC4 = {'sirna': GSC1_GSC2_GSC3_GSC4_sirna_dihedral,'pirna': GSC1_GSC2_GSC3_GSC4_pirna_dihedral,'mirna': GSC1_GSC2_GSC3_GSC4_mirna_dihedral}
ax = sns.kdeplot(data=GSC1_GSC2_GSC3_GSC4)
plt.ylabel("Probability density")
plt.xlabel('GSC1_GSC2_GSC3_GSC4 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
#density plot
BB1_BB2_BB3_CSC1 = {'sirna': BB1_BB2_BB3_CSC1_sirna_dihedral,'pirna': BB1_BB2_BB3_CSC1_pirna_dihedral,'mirna': BB1_BB2_BB3_CSC1_mirna_dihedral}
ax = sns.kdeplot(data=BB1_BB2_BB3_CSC1,bw=0.5)
plt.ylabel("Probability density")
plt.xlabel('BB1_BB2_BB3_CSC1 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
#density plot
BB2_BB3_CSC1_CSC2 = {'sirna': BB2_BB3_CSC1_CSC2_sirna_dihedral,'pirna': BB2_BB3_CSC1_CSC2_pirna_dihedral,'mirna': BB2_BB3_CSC1_CSC2_mirna_dihedral}
ax = sns.kdeplot(data=BB2_BB3_CSC1_CSC2,bw=0.5)
plt.ylabel("Probability density")
plt.xlabel('BB2_BB3_CSC1_CSC2 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
#density plot
BB2_BB3_CSC1_CSC3 = {'sirna': BB2_BB3_CSC1_CSC3_sirna_dihedral,'pirna': BB2_BB3_CSC1_CSC3_pirna_dihedral,'mirna': BB2_BB3_CSC1_CSC3_mirna_dihedral}
ax = sns.kdeplot(data=BB2_BB3_CSC1_CSC3)
plt.ylabel("Probability density")
plt.xlabel('BB2_BB3_CSC1_CSC3 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
#density plot
BB1_BB2_BB3_pBB1 = {'sirna': BB1_BB2_BB3_pBB1_sirna_dihedral,'pirna': BB1_BB2_BB3_pBB1_pirna_dihedral,'mirna': BB1_BB2_BB3_pBB1_mirna_dihedral}
ax = sns.kdeplot(data=BB1_BB2_BB3_pBB1,bw=0.6)
plt.ylabel("Probability density")
plt.xlabel('BB1_BB2_BB3_pBB1 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.6 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
#density plot
BB2_BB3_pBB1_pBB2 = {'sirna': BB2_BB3_pBB1_pBB2_sirna_dihedral,'pirna': BB2_BB3_pBB1_pBB2_pirna_dihedral,'mirna': BB2_BB3_pBB1_pBB2_mirna_dihedral}
ax = sns.kdeplot(data=BB2_BB3_pBB1_pBB2,bw=1)
plt.ylabel("Probability density")
plt.xlabel('BB2_BB3_pBB1_pBB2 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
#density plot
BB3_pBB1_pBB2_pBB3 = {'sirna': BB3_pBB1_pBB2_pBB3_sirna_dihedral,'pirna': BB3_pBB1_pBB2_pBB3_pirna_dihedral,'mirna': BB3_pBB1_pBB2_pBB3_mirna_dihedral}
ax = sns.kdeplot(data=BB3_pBB1_pBB2_pBB3,bw=1.2)
plt.ylabel("Probability density")
plt.xlabel('BB3_pBB1_pBB2_pBB3 (deg)')
plt.xlim(0,0.5)
plt.ylim(0,50)
plt.yticks(np.arange(0,52,step=25))
plt.legend()
# Out:
# /home/subha/.local/lib/python3.6/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 1.2 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.
