# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
# df_Hmapped = pd.read_csv('dist_Hmapped.csv',delimiter=" ")

# %%
dihedral_dict = dict.fromkeys(['BB1_BB2_BB3_ASC1','BB2_BB3_ASC1_ASC2','BB2_BB3_ASC1_ASC4',\
'BB2_BB3_ASC1_ASC4','ASC1_ASC2_ASC3_ASC4','BB1_BB2_BB3_USC1','BB2_BB3_USC1_USC2','BB2_BB3_USC1_USC3','BB1_BB2_BB3_GSC1',\
'BB2_BB3_GSC1_GSC2','BB2_BB3_GSC1_GSC4','GSC1_GSC2_GSC3_GSC4','BB1_BB2_BB3_CSC1','BB1_BB2_BB3_CSC1','BB2_BB3_CSC1_CSC2',
'BB2_BB3_CSC1_CSC2','BB2_BB3_CSC1_CSC3','BB1_BB2_BB3_pBB1','BB2_BB3_pBB1_pBB2','BB3_pBB1_pBB2_pBB3','BB3_pBB1_pBB2_pBB3'
])

# %%
df_Hmapped_dihedral_7w0f = pd.read_csv('7w0f/dihedral_final.xvg')
df_Hmapped_dihedral_6ra4 = pd.read_csv('6ra4/dihedral_final.xvg')
df_Hmapped_dihedral_6bjv = pd.read_csv('6bjv/dihedral_final.xvg')
df_Hmapped_dihedral_5n8l = pd.read_csv('5n8l/dihedral_final.xvg')
df_Hmapped_dihedral_4nh3 = pd.read_csv('4nh3/dihedral_final.xvg')
df_Hmapped_dihedral_4ngd = pd.read_csv('4ngd/dihedral_final.xvg')
df_Hmapped_dihedral_3cz3 = pd.read_csv('3cz3/dihedral_final.xvg')
df_Hmapped_dihedral_2f8s = pd.read_csv('2f8s/dihedral_final.xvg')
df_Hmapped_dihedral_1si3 = pd.read_csv('1si3/dihedral_final.xvg')

# %%
df_Hmapped_dihedral_6bjv
# Out:
#          time  BB2_BB3_USC1_USC2  BB2_BB3_USC1_USC3  BB2_BB3_GSC1_GSC4  \
# 0           0           -161.042                NaN                NaN
# 1        1000           -162.153                NaN                NaN
# 2        2000           -163.611                NaN                NaN
# 3        3000           -153.336                NaN                NaN
# 4        4000           -154.201                NaN                NaN
# ...       ...                ...                ...                ...
# 996    996000           -147.692                NaN                NaN
# 997    997000           -145.244                NaN                NaN
# 998    998000           -146.219                NaN                NaN
# 999    999000           -145.614                NaN                NaN
# 1000  1000000           -147.619                NaN                NaN
#
#       BB2_BB3_ASC1_ASC2  BB3_pBB1_pBB2_pBB3  GSC1_GSC2_GSC3_GSC4  \
# ...

# %%
BB1_BB2_BB3_ASC1_Hmapped_dihedral_7w0f = df_Hmapped_dihedral_7w0f['BB1_BB2_BB3_ASC1']
BB1_BB2_BB3_ASC1_Hmapped_dihedral_6ra4 = df_Hmapped_dihedral_6ra4['BB1_BB2_BB3_ASC1']
BB1_BB2_BB3_ASC1_Hmapped_dihedral_6bjv = df_Hmapped_dihedral_6bjv['BB1_BB2_BB3_ASC1']
BB1_BB2_BB3_ASC1_Hmapped_dihedral_5n8l = df_Hmapped_dihedral_5n8l['BB1_BB2_BB3_ASC1']
BB1_BB2_BB3_ASC1_Hmapped_dihedral_4nh3 = df_Hmapped_dihedral_4nh3['BB1_BB2_BB3_ASC1']
BB1_BB2_BB3_ASC1_Hmapped_dihedral_4ngd = df_Hmapped_dihedral_4ngd['BB1_BB2_BB3_ASC1']
BB1_BB2_BB3_ASC1_Hmapped_dihedral_3cz3 = df_Hmapped_dihedral_3cz3['BB1_BB2_BB3_ASC1']
BB1_BB2_BB3_ASC1_Hmapped_dihedral_2f8s = df_Hmapped_dihedral_2f8s['BB1_BB2_BB3_ASC1']
BB1_BB2_BB3_ASC1_Hmapped_dihedral_1si3 = df_Hmapped_dihedral_1si3['BB1_BB2_BB3_ASC1']
# BB1_BB2_BB3_ASC1_Hmapped_dihedral_1rpu = df_Hmapped_dihedral_1rpu['BB1_BB2_BB3_ASC1']


BB2_BB3_ASC1_ASC2_Hmapped_dihedral_7w0f = df_Hmapped_dihedral_7w0f['BB2_BB3_ASC1_ASC2']
BB2_BB3_ASC1_ASC2_Hmapped_dihedral_6ra4 = df_Hmapped_dihedral_6ra4['BB2_BB3_ASC1_ASC2']
BB2_BB3_ASC1_ASC2_Hmapped_dihedral_6bjv = df_Hmapped_dihedral_6bjv['BB2_BB3_ASC1_ASC2']
BB2_BB3_ASC1_ASC2_Hmapped_dihedral_5n8l = df_Hmapped_dihedral_5n8l['BB2_BB3_ASC1_ASC2']
BB2_BB3_ASC1_ASC2_Hmapped_dihedral_4nh3 = df_Hmapped_dihedral_4nh3['BB2_BB3_ASC1_ASC2']
BB2_BB3_ASC1_ASC2_Hmapped_dihedral_4ngd = df_Hmapped_dihedral_4ngd['BB2_BB3_ASC1_ASC2']
BB2_BB3_ASC1_ASC2_Hmapped_dihedral_3cz3 = df_Hmapped_dihedral_3cz3['BB2_BB3_ASC1_ASC2']
BB2_BB3_ASC1_ASC2_Hmapped_dihedral_2f8s = df_Hmapped_dihedral_2f8s['BB2_BB3_ASC1_ASC2']
BB2_BB3_ASC1_ASC2_Hmapped_dihedral_1si3 = df_Hmapped_dihedral_1si3['BB2_BB3_ASC1_ASC2']
# BB2_BB3_ASC1_ASC2_Hmapped_dihedral_1rpu = df_Hmapped_dihedral_1rpu['BB2_BB3_ASC1_ASC2']


# BB2_BB3_ASC1_ASC4_Hmapped_dihedral = df_Hmapped_dihedral['BB2_BB3_ASC1_ASC4']
ASC1_ASC2_ASC3_ASC4_Hmapped_dihedral_7w0f = df_Hmapped_dihedral_7w0f['ASC1_ASC2_ASC3_ASC4']
ASC1_ASC2_ASC3_ASC4_Hmapped_dihedral_6ra4 = df_Hmapped_dihedral_6ra4['ASC1_ASC2_ASC3_ASC4']
ASC1_ASC2_ASC3_ASC4_Hmapped_dihedral_6bjv = df_Hmapped_dihedral_6bjv['ASC1_ASC2_ASC3_ASC4']
ASC1_ASC2_ASC3_ASC4_Hmapped_dihedral_5n8l = df_Hmapped_dihedral_5n8l['ASC1_ASC2_ASC3_ASC4']
ASC1_ASC2_ASC3_ASC4_Hmapped_dihedral_4nh3 = df_Hmapped_dihedral_4nh3['ASC1_ASC2_ASC3_ASC4']
ASC1_ASC2_ASC3_ASC4_Hmapped_dihedral_4ngd = df_Hmapped_dihedral_4ngd['ASC1_ASC2_ASC3_ASC4']
ASC1_ASC2_ASC3_ASC4_Hmapped_dihedral_3cz3 = df_Hmapped_dihedral_3cz3['ASC1_ASC2_ASC3_ASC4']
ASC1_ASC2_ASC3_ASC4_Hmapped_dihedral_2f8s = df_Hmapped_dihedral_2f8s['ASC1_ASC2_ASC3_ASC4']
ASC1_ASC2_ASC3_ASC4_Hmapped_dihedral_1si3 = df_Hmapped_dihedral_1si3['ASC1_ASC2_ASC3_ASC4']
# ASC1_ASC2_ASC3_ASC4_Hmapped_dihedral_1rpu = df_Hmapped_dihedral_1rpu['ASC1_ASC2_ASC3_ASC4']


BB1_BB2_BB3_USC1_Hmapped_dihedral_7w0f = df_Hmapped_dihedral_7w0f['BB1_BB2_BB3_USC1']
BB1_BB2_BB3_USC1_Hmapped_dihedral_6ra4 = df_Hmapped_dihedral_6ra4['BB1_BB2_BB3_USC1']
BB1_BB2_BB3_USC1_Hmapped_dihedral_6bjv = df_Hmapped_dihedral_6bjv['BB1_BB2_BB3_USC1']
BB1_BB2_BB3_USC1_Hmapped_dihedral_5n8l = df_Hmapped_dihedral_5n8l['BB1_BB2_BB3_USC1']
BB1_BB2_BB3_USC1_Hmapped_dihedral_4nh3 = df_Hmapped_dihedral_4nh3['BB1_BB2_BB3_USC1']
BB1_BB2_BB3_USC1_Hmapped_dihedral_4ngd = df_Hmapped_dihedral_4ngd['BB1_BB2_BB3_USC1']
BB1_BB2_BB3_USC1_Hmapped_dihedral_3cz3 = df_Hmapped_dihedral_3cz3['BB1_BB2_BB3_USC1']
BB1_BB2_BB3_USC1_Hmapped_dihedral_2f8s = df_Hmapped_dihedral_2f8s['BB1_BB2_BB3_USC1']
BB1_BB2_BB3_USC1_Hmapped_dihedral_1si3 = df_Hmapped_dihedral_1si3['BB1_BB2_BB3_USC1']
# BB1_BB2_BB3_USC1_Hmapped_dihedral_1rpu = df_Hmapped_dihedral_1rpu['BB1_BB2_BB3_USC1']

BB2_BB3_USC1_USC2_Hmapped_dihedral_7w0f = df_Hmapped_dihedral_7w0f['BB2_BB3_USC1_USC2']
BB2_BB3_USC1_USC2_Hmapped_dihedral_6ra4 = df_Hmapped_dihedral_6ra4['BB2_BB3_USC1_USC2']
BB2_BB3_USC1_USC2_Hmapped_dihedral_6bjv = df_Hmapped_dihedral_6bjv['BB2_BB3_USC1_USC2']
BB2_BB3_USC1_USC2_Hmapped_dihedral_5n8l = df_Hmapped_dihedral_5n8l['BB2_BB3_USC1_USC2']
BB2_BB3_USC1_USC2_Hmapped_dihedral_4nh3 = df_Hmapped_dihedral_4nh3['BB2_BB3_USC1_USC2']
BB2_BB3_USC1_USC2_Hmapped_dihedral_4ngd = df_Hmapped_dihedral_4ngd['BB2_BB3_USC1_USC2']
BB2_BB3_USC1_USC2_Hmapped_dihedral_3cz3 = df_Hmapped_dihedral_3cz3['BB2_BB3_USC1_USC2']
BB2_BB3_USC1_USC2_Hmapped_dihedral_2f8s = df_Hmapped_dihedral_2f8s['BB2_BB3_USC1_USC2']
BB2_BB3_USC1_USC2_Hmapped_dihedral_1si3 = df_Hmapped_dihedral_1si3['BB2_BB3_USC1_USC2']
# BB2_BB3_USC1_USC2_Hmapped_dihedral_1rpu = df_Hmapped_dihedral_1rpu['BB2_BB3_USC1_USC2']

# BB2_BB3_USC1_USC3_Hmapped_dihedral = df_Hmapped_dihedral['BB2_BB3_USC1_USC3']

BB1_BB2_BB3_GSC1_Hmapped_dihedral_7w0f = df_Hmapped_dihedral_7w0f['BB1_BB2_BB3_GSC1']
BB1_BB2_BB3_GSC1_Hmapped_dihedral_6ra4 = df_Hmapped_dihedral_6ra4['BB1_BB2_BB3_GSC1']
BB1_BB2_BB3_GSC1_Hmapped_dihedral_6bjv = df_Hmapped_dihedral_6bjv['BB1_BB2_BB3_GSC1']
BB1_BB2_BB3_GSC1_Hmapped_dihedral_5n8l = df_Hmapped_dihedral_5n8l['BB1_BB2_BB3_GSC1']
BB1_BB2_BB3_GSC1_Hmapped_dihedral_4nh3 = df_Hmapped_dihedral_4nh3['BB1_BB2_BB3_GSC1']
BB1_BB2_BB3_GSC1_Hmapped_dihedral_4ngd = df_Hmapped_dihedral_4ngd['BB1_BB2_BB3_GSC1']
BB1_BB2_BB3_GSC1_Hmapped_dihedral_3cz3 = df_Hmapped_dihedral_3cz3['BB1_BB2_BB3_GSC1']
BB1_BB2_BB3_GSC1_Hmapped_dihedral_2f8s = df_Hmapped_dihedral_2f8s['BB1_BB2_BB3_GSC1']
BB1_BB2_BB3_GSC1_Hmapped_dihedral_1si3 = df_Hmapped_dihedral_1si3['BB1_BB2_BB3_GSC1']
# BB1_BB2_BB3_GSC1_Hmapped_dihedral_1rpu = df_Hmapped_dihedral_1rpu['BB1_BB2_BB3_GSC1']

BB2_BB3_GSC1_GSC2_Hmapped_dihedral_7w0f = df_Hmapped_dihedral_7w0f['BB2_BB3_GSC1_GSC2']
BB2_BB3_GSC1_GSC2_Hmapped_dihedral_6ra4 = df_Hmapped_dihedral_6ra4['BB2_BB3_GSC1_GSC2']
BB2_BB3_GSC1_GSC2_Hmapped_dihedral_6bjv = df_Hmapped_dihedral_6bjv['BB2_BB3_GSC1_GSC2']
BB2_BB3_GSC1_GSC2_Hmapped_dihedral_5n8l = df_Hmapped_dihedral_5n8l['BB2_BB3_GSC1_GSC2']
BB2_BB3_GSC1_GSC2_Hmapped_dihedral_4nh3 = df_Hmapped_dihedral_4nh3['BB2_BB3_GSC1_GSC2']
BB2_BB3_GSC1_GSC2_Hmapped_dihedral_4ngd = df_Hmapped_dihedral_4ngd['BB2_BB3_GSC1_GSC2']
BB2_BB3_GSC1_GSC2_Hmapped_dihedral_3cz3 = df_Hmapped_dihedral_3cz3['BB2_BB3_GSC1_GSC2']
BB2_BB3_GSC1_GSC2_Hmapped_dihedral_2f8s = df_Hmapped_dihedral_2f8s['BB2_BB3_GSC1_GSC2']
BB2_BB3_GSC1_GSC2_Hmapped_dihedral_1si3 = df_Hmapped_dihedral_1si3['BB2_BB3_GSC1_GSC2']
# BB2_BB3_GSC1_GSC2_Hmapped_dihedral_1rpu = df_Hmapped_dihedral_1rpu['BB2_BB3_GSC1_GSC2']

BB2_BB3_GSC1_GSC2_Hmapped_dihedral_7w0f = df_Hmapped_dihedral_7w0f['BB2_BB3_GSC1_GSC2']
BB2_BB3_GSC1_GSC2_Hmapped_dihedral_6ra4 = df_Hmapped_dihedral_6ra4['BB2_BB3_GSC1_GSC2']
BB2_BB3_GSC1_GSC2_Hmapped_dihedral_6bjv = df_Hmapped_dihedral_6bjv['BB2_BB3_GSC1_GSC2']
BB2_BB3_GSC1_GSC2_Hmapped_dihedral_5n8l = df_Hmapped_dihedral_5n8l['BB2_BB3_GSC1_GSC2']
BB2_BB3_GSC1_GSC2_Hmapped_dihedral_4nh3 = df_Hmapped_dihedral_4nh3['BB2_BB3_GSC1_GSC2']
BB2_BB3_GSC1_GSC2_Hmapped_dihedral_4ngd = df_Hmapped_dihedral_4ngd['BB2_BB3_GSC1_GSC2']
BB2_BB3_GSC1_GSC2_Hmapped_dihedral_3cz3 = df_Hmapped_dihedral_3cz3['BB2_BB3_GSC1_GSC2']
BB2_BB3_GSC1_GSC2_Hmapped_dihedral_2f8s = df_Hmapped_dihedral_2f8s['BB2_BB3_GSC1_GSC2']
BB2_BB3_GSC1_GSC2_Hmapped_dihedral_1si3 = df_Hmapped_dihedral_1si3['BB2_BB3_GSC1_GSC2']
# BB2_BB3_GSC1_GSC2_Hmapped_dihedral_1rpu = df_Hmapped_dihedral_1rpu['BB2_BB3_GSC1_GSC2']

BB2_BB3_GSC1_GSC2_Hmapped_dihedral_7w0f = df_Hmapped_dihedral_7w0f['BB2_BB3_GSC1_GSC2']
BB2_BB3_GSC1_GSC2_Hmapped_dihedral_6ra4 = df_Hmapped_dihedral_6ra4['BB2_BB3_GSC1_GSC2']
BB2_BB3_GSC1_GSC2_Hmapped_dihedral_6bjv = df_Hmapped_dihedral_6bjv['BB2_BB3_GSC1_GSC2']
BB2_BB3_GSC1_GSC2_Hmapped_dihedral_5n8l = df_Hmapped_dihedral_5n8l['BB2_BB3_GSC1_GSC2']
BB2_BB3_GSC1_GSC2_Hmapped_dihedral_4nh3 = df_Hmapped_dihedral_4nh3['BB2_BB3_GSC1_GSC2']
BB2_BB3_GSC1_GSC2_Hmapped_dihedral_4ngd = df_Hmapped_dihedral_4ngd['BB2_BB3_GSC1_GSC2']
BB2_BB3_GSC1_GSC2_Hmapped_dihedral_3cz3 = df_Hmapped_dihedral_3cz3['BB2_BB3_GSC1_GSC2']
BB2_BB3_GSC1_GSC2_Hmapped_dihedral_2f8s = df_Hmapped_dihedral_2f8s['BB2_BB3_GSC1_GSC2']
BB2_BB3_GSC1_GSC2_Hmapped_dihedral_1si3 = df_Hmapped_dihedral_1si3['BB2_BB3_GSC1_GSC2']
# BB2_BB3_GSC1_GSC2_Hmapped_dihedral_1rpu = df_Hmapped_dihedral_1rpu['BB2_BB3_GSC1_GSC2']

# BB2_BB3_GSC1_GSC4_Hmapped_dihedral = df_Hmapped_dihedral['BB2_BB3_GSC1_GSC4']
GSC1_GSC2_GSC3_GSC4_Hmapped_dihedral_7w0f = df_Hmapped_dihedral_7w0f['GSC1_GSC2_GSC3_GSC4']
GSC1_GSC2_GSC3_GSC4_Hmapped_dihedral_6ra4 = df_Hmapped_dihedral_6ra4['GSC1_GSC2_GSC3_GSC4']
GSC1_GSC2_GSC3_GSC4_Hmapped_dihedral_6bjv = df_Hmapped_dihedral_6bjv['GSC1_GSC2_GSC3_GSC4']
GSC1_GSC2_GSC3_GSC4_Hmapped_dihedral_5n8l = df_Hmapped_dihedral_5n8l['GSC1_GSC2_GSC3_GSC4']
GSC1_GSC2_GSC3_GSC4_Hmapped_dihedral_4nh3 = df_Hmapped_dihedral_4nh3['GSC1_GSC2_GSC3_GSC4']
GSC1_GSC2_GSC3_GSC4_Hmapped_dihedral_4ngd = df_Hmapped_dihedral_4ngd['GSC1_GSC2_GSC3_GSC4']
GSC1_GSC2_GSC3_GSC4_Hmapped_dihedral_3cz3 = df_Hmapped_dihedral_3cz3['GSC1_GSC2_GSC3_GSC4']
GSC1_GSC2_GSC3_GSC4_Hmapped_dihedral_2f8s = df_Hmapped_dihedral_2f8s['GSC1_GSC2_GSC3_GSC4']
GSC1_GSC2_GSC3_GSC4_Hmapped_dihedral_1si3 = df_Hmapped_dihedral_1si3['GSC1_GSC2_GSC3_GSC4']
# GSC1_GSC2_GSC3_GSC4_Hmapped_dihedral_1rpu = df_Hmapped_dihedral_1rpu['GSC1_GSC2_GSC3_GSC4']



BB1_BB2_BB3_CSC1_Hmapped_dihedral_7w0f = df_Hmapped_dihedral_7w0f['BB1_BB2_BB3_CSC1']
BB1_BB2_BB3_CSC1_Hmapped_dihedral_6ra4 = df_Hmapped_dihedral_6ra4['BB1_BB2_BB3_CSC1']
BB1_BB2_BB3_CSC1_Hmapped_dihedral_6bjv = df_Hmapped_dihedral_6bjv['BB1_BB2_BB3_CSC1']
BB1_BB2_BB3_CSC1_Hmapped_dihedral_5n8l = df_Hmapped_dihedral_5n8l['BB1_BB2_BB3_CSC1']
BB1_BB2_BB3_CSC1_Hmapped_dihedral_4nh3 = df_Hmapped_dihedral_4nh3['BB1_BB2_BB3_CSC1']
BB1_BB2_BB3_CSC1_Hmapped_dihedral_4ngd = df_Hmapped_dihedral_4ngd['BB1_BB2_BB3_CSC1']
BB1_BB2_BB3_CSC1_Hmapped_dihedral_3cz3 = df_Hmapped_dihedral_3cz3['BB1_BB2_BB3_CSC1']
BB1_BB2_BB3_CSC1_Hmapped_dihedral_2f8s = df_Hmapped_dihedral_2f8s['BB1_BB2_BB3_CSC1']
BB1_BB2_BB3_CSC1_Hmapped_dihedral_1si3 = df_Hmapped_dihedral_1si3['BB1_BB2_BB3_CSC1']
# BB1_BB2_BB3_CSC1_Hmapped_dihedral_1rpu = df_Hmapped_dihedral_1rpu['BB1_BB2_BB3_CSC1']

BB2_BB3_CSC1_CSC2_Hmapped_dihedral_7w0f = df_Hmapped_dihedral_7w0f['BB2_BB3_CSC1_CSC2']
BB2_BB3_CSC1_CSC2_Hmapped_dihedral_6ra4 = df_Hmapped_dihedral_6ra4['BB2_BB3_CSC1_CSC2']
BB2_BB3_CSC1_CSC2_Hmapped_dihedral_6bjv = df_Hmapped_dihedral_6bjv['BB2_BB3_CSC1_CSC2']
BB2_BB3_CSC1_CSC2_Hmapped_dihedral_5n8l = df_Hmapped_dihedral_5n8l['BB2_BB3_CSC1_CSC2']
BB2_BB3_CSC1_CSC2_Hmapped_dihedral_4nh3 = df_Hmapped_dihedral_4nh3['BB2_BB3_CSC1_CSC2']
BB2_BB3_CSC1_CSC2_Hmapped_dihedral_4ngd= df_Hmapped_dihedral_4ngd['BB2_BB3_CSC1_CSC2']
BB2_BB3_CSC1_CSC2_Hmapped_dihedral_3cz3 = df_Hmapped_dihedral_3cz3['BB2_BB3_CSC1_CSC2']
BB2_BB3_CSC1_CSC2_Hmapped_dihedral_2f8s = df_Hmapped_dihedral_2f8s['BB2_BB3_CSC1_CSC2']
BB2_BB3_CSC1_CSC2_Hmapped_dihedral_1si3 = df_Hmapped_dihedral_1si3['BB2_BB3_CSC1_CSC2']
# BB2_BB3_CSC1_CSC2_Hmapped_dihedral_1rpu = df_Hmapped_dihedral_1rpu['BB2_BB3_CSC1_CSC2']

BB2_BB3_CSC1_CSC3_Hmapped_dihedral_7w0f = df_Hmapped_dihedral_7w0f['BB2_BB3_CSC1_CSC3']
BB2_BB3_CSC1_CSC3_Hmapped_dihedral_6ra4 = df_Hmapped_dihedral_6ra4['BB2_BB3_CSC1_CSC3']
BB2_BB3_CSC1_CSC3_Hmapped_dihedral_6bjv = df_Hmapped_dihedral_6bjv ['BB2_BB3_CSC1_CSC3']
BB2_BB3_CSC1_CSC3_Hmapped_dihedral_5n8l = df_Hmapped_dihedral_5n8l['BB2_BB3_CSC1_CSC3']
BB2_BB3_CSC1_CSC3_Hmapped_dihedral_4nh3 = df_Hmapped_dihedral_4nh3['BB2_BB3_CSC1_CSC3']
BB2_BB3_CSC1_CSC3_Hmapped_dihedral_4ngd = df_Hmapped_dihedral_4ngd['BB2_BB3_CSC1_CSC3']
BB2_BB3_CSC1_CSC3_Hmapped_dihedral_3cz3 = df_Hmapped_dihedral_3cz3['BB2_BB3_CSC1_CSC3']
BB2_BB3_CSC1_CSC3_Hmapped_dihedral_2f8s = df_Hmapped_dihedral_2f8s['BB2_BB3_CSC1_CSC3']
BB2_BB3_CSC1_CSC3_Hmapped_dihedral_1si3 = df_Hmapped_dihedral_1si3['BB2_BB3_CSC1_CSC3']
# BB2_BB3_CSC1_CSC3_Hmapped_dihedral_1rpu = df_Hmapped_dihedral_1rpu['BB2_BB3_CSC1_CSC3']

BB1_BB2_BB3_pBB1_Hmapped_dihedral_7w0f = df_Hmapped_dihedral_7w0f['BB1_BB2_BB3_pBB1']
BB1_BB2_BB3_pBB1_Hmapped_dihedral_6ra4 = df_Hmapped_dihedral_6ra4['BB1_BB2_BB3_pBB1']
BB1_BB2_BB3_pBB1_Hmapped_dihedral_6bjv = df_Hmapped_dihedral_6bjv['BB1_BB2_BB3_pBB1']
BB1_BB2_BB3_pBB1_Hmapped_dihedral_5n8l = df_Hmapped_dihedral_5n8l['BB1_BB2_BB3_pBB1']
BB1_BB2_BB3_pBB1_Hmapped_dihedral_4nh3 = df_Hmapped_dihedral_4nh3['BB1_BB2_BB3_pBB1']
BB1_BB2_BB3_pBB1_Hmapped_dihedral_4ngd = df_Hmapped_dihedral_4ngd['BB1_BB2_BB3_pBB1']
BB1_BB2_BB3_pBB1_Hmapped_dihedral_3cz3 = df_Hmapped_dihedral_3cz3['BB1_BB2_BB3_pBB1']
BB1_BB2_BB3_pBB1_Hmapped_dihedral_2f8s = df_Hmapped_dihedral_2f8s['BB1_BB2_BB3_pBB1']
BB1_BB2_BB3_pBB1_Hmapped_dihedral_1si3 = df_Hmapped_dihedral_1si3['BB1_BB2_BB3_pBB1']
# BB1_BB2_BB3_pBB1_Hmapped_dihedral_1rpu = df_Hmapped_dihedral_1rpu['BB1_BB2_BB3_pBB1']

BB2_BB3_pBB1_pBB2_Hmapped_dihedral_7w0f = df_Hmapped_dihedral_7w0f['BB2_BB3_pBB1_pBB2']
BB2_BB3_pBB1_pBB2_Hmapped_dihedral_6ra4 = df_Hmapped_dihedral_6ra4['BB2_BB3_pBB1_pBB2']
BB2_BB3_pBB1_pBB2_Hmapped_dihedral_6bjv = df_Hmapped_dihedral_6bjv['BB2_BB3_pBB1_pBB2']
BB2_BB3_pBB1_pBB2_Hmapped_dihedral_5n8l = df_Hmapped_dihedral_5n8l['BB2_BB3_pBB1_pBB2']
BB2_BB3_pBB1_pBB2_Hmapped_dihedral_4nh3 = df_Hmapped_dihedral_4nh3['BB2_BB3_pBB1_pBB2']
BB2_BB3_pBB1_pBB2_Hmapped_dihedral_4ngd = df_Hmapped_dihedral_4ngd['BB2_BB3_pBB1_pBB2']
BB2_BB3_pBB1_pBB2_Hmapped_dihedral_3cz3 = df_Hmapped_dihedral_3cz3['BB2_BB3_pBB1_pBB2']
BB2_BB3_pBB1_pBB2_Hmapped_dihedral_2f8s = df_Hmapped_dihedral_2f8s['BB2_BB3_pBB1_pBB2']
BB2_BB3_pBB1_pBB2_Hmapped_dihedral_1si3 = df_Hmapped_dihedral_1si3['BB2_BB3_pBB1_pBB2']
# BB2_BB3_pBB1_pBB2_Hmapped_dihedral_1rpu = df_Hmapped_dihedral_1rpu['BB2_BB3_pBB1_pBB2']

BB3_pBB1_pBB2_pBB3_Hmapped_dihedral_7w0f = df_Hmapped_dihedral_7w0f['BB3_pBB1_pBB2_pBB3']
BB3_pBB1_pBB2_pBB3_Hmapped_dihedral_6ra4 = df_Hmapped_dihedral_6ra4['BB3_pBB1_pBB2_pBB3']
BB3_pBB1_pBB2_pBB3_Hmapped_dihedral_6bjv = df_Hmapped_dihedral_6bjv['BB3_pBB1_pBB2_pBB3']
BB3_pBB1_pBB2_pBB3_Hmapped_dihedral_5n8l = df_Hmapped_dihedral_5n8l['BB3_pBB1_pBB2_pBB3']
BB3_pBB1_pBB2_pBB3_Hmapped_dihedral_4nh3 = df_Hmapped_dihedral_4nh3['BB3_pBB1_pBB2_pBB3']
BB3_pBB1_pBB2_pBB3_Hmapped_dihedral_4ngd = df_Hmapped_dihedral_4ngd['BB3_pBB1_pBB2_pBB3']
BB3_pBB1_pBB2_pBB3_Hmapped_dihedral_3cz3 = df_Hmapped_dihedral_3cz3['BB3_pBB1_pBB2_pBB3']
BB3_pBB1_pBB2_pBB3_Hmapped_dihedral_2f8s = df_Hmapped_dihedral_2f8s['BB3_pBB1_pBB2_pBB3']
BB3_pBB1_pBB2_pBB3_Hmapped_dihedral_1si3 = df_Hmapped_dihedral_1si3['BB3_pBB1_pBB2_pBB3']
# BB3_pBB1_pBB2_pBB3_Hmapped_dihedral_1rpu = df_Hmapped_dihedral_1rpu['BB3_pBB1_pBB2_pBB3']

# %%
# Density Plot and Histogram 
l = []
for item in BB1_BB2_BB3_pBB1_Hmapped_dihedral_7w0f.values:
    l.append(int(item+180))

l = pd.Series(l)
plt = sns.distplot(BB1_BB2_BB3_pBB1_Hmapped_dihedral_7w0f, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_BB3_pBB1_Hmapped_dihedral_6ra4, kde=True, 
            color = 'green', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_BB3_pBB1_Hmapped_dihedral_6bjv, kde=True, 
            color = 'grey', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_BB3_pBB1_Hmapped_dihedral_5n8l, kde=True, 
            color = 'purple', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_BB3_pBB1_Hmapped_dihedral_4nh3, kde=True, 
            color = 'red', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_BB3_pBB1_Hmapped_dihedral_4ngd, kde=True, 
            color = 'pink', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_BB3_pBB1_Hmapped_dihedral_3cz3 , kde=True, 
            color = 'cyan', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_BB3_pBB1_Hmapped_dihedral_2f8s, kde=True, 
            color = 'orange', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_BB3_pBB1_Hmapped_dihedral_1si3, kde=True, 
            color = 'black', norm_hist=True,
             kde_kws={'linewidth': 1})

# plt = sns.distplot(BB1_BB2_BB3_pBB1_Hmapped_dihedral_7w0f, kde=True, 
#             color = 'darkblue', norm_hist=True,
#              kde_kws={'linewidth': 4})

# plt.set_xlabel('BB1_BB2_BB3_ASC1(nm)'+'\nMean: '+str("{:.2f}".format(l.mean()))+",\
# SD: "+str("{:.2f}".format(l.std())))
# plt.set(xlim=(0,360))


data1 = []
data2 = []
for item in l.values:
    if(item>=0 and item <200 ):
        data1.append(item)
    elif(item>=200 and item <360):
        data2.append(item)

data1 = pd.Series(data1)
data2 = pd.Series(data2)


plt.set_xlabel('BB1_BB2_BB3_pBB1_Hmapped_dihedral(nm)'+'\n\n(Peak1) Mean: '+str("{:.2f}".format(data1.mean()))+", \
SD: "+str("{:.2f}".format(data1.std())) + '\n\n(Peak2) Mean: '+str("{:.2f}".format(data2.mean()))+", \
SD: "+str("{:.2f}".format(data2.std())))


dihedral_dict['BB1_BB2_BB3_pBB1'] = [str("{:.2f}".format(data1.mean())),str("{:.2f}".format(data2.mean())),str("{:.2f}".format(data1.std())),str("{:.2f}".format(data2.std()))]
plt.figure.savefig("BB1_BB2_BB3_pBB1.png")
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Density Plot and Histogram 
l = []
for item in BB2_BB3_pBB1_pBB2_Hmapped_dihedral_7w0f.values:
    l.append(int(item+180))

plt = sns.distplot(BB2_BB3_pBB1_pBB2_Hmapped_dihedral_7w0f, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_pBB1_pBB2_Hmapped_dihedral_6ra4, kde=True, 
            color = 'green', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_pBB1_pBB2_Hmapped_dihedral_6bjv, kde=True, 
            color = 'grey', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_pBB1_pBB2_Hmapped_dihedral_5n8l, kde=True, 
            color = 'purple', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_pBB1_pBB2_Hmapped_dihedral_4nh3, kde=True, 
            color = 'red', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_pBB1_pBB2_Hmapped_dihedral_4ngd, kde=True, 
            color = 'pink', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_pBB1_pBB2_Hmapped_dihedral_3cz3 , kde=True, 
            color = 'cyan', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_pBB1_pBB2_Hmapped_dihedral_2f8s, kde=True, 
            color = 'orange', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_pBB1_pBB2_Hmapped_dihedral_1si3, kde=True, 
            color = 'black', norm_hist=True,
             kde_kws={'linewidth': 1})
    
# l = pd.Series(l)
# plt = sns.distplot(l, kde=True, 
#             color = 'darkblue', norm_hist=True,
#              kde_kws={'linewidth': 4})
# plt.set_xlabel('BB1_BB2_BB3_ASC1(nm)'+'\nMean: '+str("{:.2f}".format(l.mean()))+",\
# SD: "+str("{:.2f}".format(l.std())))
# plt.set(xlim=(0,360))


data1 = []
data2 = []
for item in l.values:
    if(item>=0 and item <200 ):
        data1.append(item)
    elif(item>=200 and item <360):
        data2.append(item)

data1 = pd.Series(data1)
data2 = pd.Series(data2)


plt.set_xlabel('BB2_BB3_pBB1_pBB2_Hmapped_dihedral(nm)'+'\n\n(Peak1) Mean: '+str("{:.2f}".format(data1.mean()))+", \
SD: "+str("{:.2f}".format(data1.std())) + '\n\n(Peak2) Mean: '+str("{:.2f}".format(data2.mean()))+", \
SD: "+str("{:.2f}".format(data2.std())))

dihedral_dict['BB2_BB3_pBB1_pBB2'] = [str("{:.2f}".format(data1.mean())),str("{:.2f}".format(data2.mean())),str("{:.2f}".format(data1.std())),str("{:.2f}".format(data2.std()))]
plt.figure.savefig("BB2_BB3_pBB1_pBB2.png")
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Density Plot and Histogram 
# l = []
# for item in BB3_pBB1_pBB2_pBB3_Hmapped_dihedral.values:
#     l.append(int(item+180))

plt = sns.distplot(BB3_pBB1_pBB2_pBB3_Hmapped_dihedral_7w0f, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB3_pBB1_pBB2_pBB3_Hmapped_dihedral_6ra4, kde=True, 
            color = 'green', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB3_pBB1_pBB2_pBB3_Hmapped_dihedral_6bjv, kde=True, 
            color = 'grey', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB3_pBB1_pBB2_pBB3_Hmapped_dihedral_5n8l, kde=True, 
            color = 'purple', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB3_pBB1_pBB2_pBB3_Hmapped_dihedral_4nh3, kde=True, 
            color = 'red', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB3_pBB1_pBB2_pBB3_Hmapped_dihedral_4ngd, kde=True, 
            color = 'pink', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB3_pBB1_pBB2_pBB3_Hmapped_dihedral_3cz3 , kde=True, 
            color = 'cyan', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB3_pBB1_pBB2_pBB3_Hmapped_dihedral_2f8s, kde=True, 
            color = 'orange', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB3_pBB1_pBB2_pBB3_Hmapped_dihedral_1si3, kde=True, 
            color = 'black', norm_hist=True,
             kde_kws={'linewidth': 1})

    
# l = pd.Series(l)
# plt = sns.distplot(l, kde=True, 
#             color = 'darkblue', norm_hist=True,
#              kde_kws={'linewidth': 4})
# plt.set_xlabel('BB1_BB2_BB3_ASC1(nm)'+'\nMean: '+str("{:.2f}".format(l.mean()))+",\
# SD: "+str("{:.2f}".format(l.std())))
# plt.set(xlim=(0,360))


data1 = []
data2 = []
for item in l.values:
    if(item>=0 and item <200 ):
        data1.append(item)
    elif(item>=200 and item <360):
        data2.append(item)

data1 = pd.Series(data1)
data2 = pd.Series(data2)


plt.set_xlabel('BB3_pBB1_pBB2_pBB3_Hmapped_dihedral(nm)'+'\n\n(Peak1) Mean: '+str("{:.2f}".format(data1.mean()))+", \
SD: "+str("{:.2f}".format(data1.std())) + '\n\n(Peak2) Mean: '+str("{:.2f}".format(data2.mean()))+", \
SD: "+str("{:.2f}".format(data2.std())))

dihedral_dict['BB3_pBB1_pBB2_pBB3'] = [str("{:.2f}".format(data1.mean())),str("{:.2f}".format(data2.mean())),str("{:.2f}".format(data1.std())),str("{:.2f}".format(data2.std()))]
plt.figure.savefig("BB3_pBB1_pBB2_pBB3.png")
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Density Plot and Histogram 
l = []
# for item in BB1_BB2_BB3_ASC1_Hmapped_dihedral_7w0f.values:
#     l.append(int(item+180))

plt = sns.distplot(BB1_BB2_BB3_ASC1_Hmapped_dihedral_7w0f, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_BB3_ASC1_Hmapped_dihedral_6ra4, kde=True, 
            color = 'green', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_BB3_ASC1_Hmapped_dihedral_6bjv, kde=True, 
            color = 'grey', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_BB3_ASC1_Hmapped_dihedral_5n8l, kde=True, 
            color = 'purple', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_BB3_ASC1_Hmapped_dihedral_4nh3, kde=True, 
            color = 'red', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_BB3_ASC1_Hmapped_dihedral_4ngd, kde=True, 
            color = 'pink', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_BB3_ASC1_Hmapped_dihedral_3cz3 , kde=True, 
            color = 'cyan', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_BB3_ASC1_Hmapped_dihedral_2f8s, kde=True, 
            color = 'orange', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_BB3_ASC1_Hmapped_dihedral_1si3, kde=True, 
            color = 'black', norm_hist=True,
             kde_kws={'linewidth': 1})

    
l = pd.Series(l)
plt = sns.distplot(BB1_BB2_BB3_ASC1_Hmapped_dihedral_7w0f, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 1})
# plt.set_xlabel('BB1_BB2_BB3_ASC1(nm)'+'\nMean: '+str("{:.2f}".format(l.mean()))+",\
# SD: "+str("{:.2f}".format(l.std())))
# plt.set(xlim=(0,360))


data1 = []
data2 = []
for item in l.values:
    if(item>=0 and item <200 ):
        data1.append(item)
    elif(item>=200 and item <360):
        data2.append(item)

data1 = pd.Series(data1)
data2 = pd.Series(data2)


plt.set_xlabel('BB1_BB2_BB3_ASC1_Hmapped_dihedral(nm)'+'\n\n(Peak1) Mean: '+str("{:.2f}".format(data1.mean()))+", \
SD: "+str("{:.2f}".format(data1.std())) + '\n\n(Peak2) Mean: '+str("{:.2f}".format(data2.mean()))+", \
SD: "+str("{:.2f}".format(data2.std())))

dihedral_dict['BB1_BB2_BB3_ASC1'] = [str("{:.2f}".format(data1.mean())),str("{:.2f}".format(data2.mean())),str("{:.2f}".format(data1.std())),str("{:.2f}".format(data2.std()))]
plt.figure.savefig("BB1_BB2_BB3_ASC1.png")
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Density Plot and Histogram 
# l = []
# for item in BB2_BB3_ASC1_ASC2_Hmapped_dihedral.values:
#     l.append(int(item+180))

plt = sns.distplot(BB2_BB3_ASC1_ASC2_Hmapped_dihedral_7w0f, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_ASC1_ASC2_Hmapped_dihedral_6ra4, kde=True, 
            color = 'green', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_ASC1_ASC2_Hmapped_dihedral_6bjv, kde=True, 
            color = 'grey', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_ASC1_ASC2_Hmapped_dihedral_5n8l, kde=True, 
            color = 'purple', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_ASC1_ASC2_Hmapped_dihedral_4nh3, kde=True, 
            color = 'red', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_ASC1_ASC2_Hmapped_dihedral_4ngd, kde=True, 
            color = 'pink', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_ASC1_ASC2_Hmapped_dihedral_3cz3 , kde=True, 
            color = 'cyan', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_ASC1_ASC2_Hmapped_dihedral_2f8s, kde=True, 
            color = 'orange', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_ASC1_ASC2_Hmapped_dihedral_1si3, kde=True, 
            color = 'black', norm_hist=True,
             kde_kws={'linewidth': 1})

    
l = pd.Series(l)

plt = sns.distplot(l, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 4})
# plt.set_xlabel('BB2_BB3(nm)')
plt.set_xlabel('BB2_BB3_ASC1_ASC2_Hmapped_dihedral(nm)'+'\nMean: '+str("{:.2f}".format(l.mean()))+",\
SD: "+str("{:.2f}".format(l.std())))
# plt.set(xlim=(0,360))


dihedral_dict['BB2_BB3_ASC1_ASC2'] = [str("{:.2f}".format(data1.mean())),str("{:.2f}".format(data2.mean())),str("{:.2f}".format(data1.std())),str("{:.2f}".format(data2.std()))]
plt.figure.savefig("BB2_BB3_ASC1_ASC2.png")
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Density Plot and Histogram of all arrival delays
# Density Plot and Histogram 
l = []
# for item in BB2_BB3_ASC1_ASC4_Hmapped_dihedral.values:
#     l.append(int(item+180))

plt = sns.distplot(BB2_BB3_ASC1_ASC4_Hmapped_dihedral_7w0f, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_ASC1_ASC4_Hmapped_dihedral_6ra4, kde=True, 
            color = 'green', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_ASC1_ASC4_Hmapped_dihedral_6bjv, kde=True, 
            color = 'grey', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_ASC1_ASC4_Hmapped_dihedral_5n8l, kde=True, 
            color = 'purple', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_ASC1_ASC4_Hmapped_dihedral_4nh3, kde=True, 
            color = 'red', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_ASC1_ASC4_Hmapped_dihedral_4ngd, kde=True, 
            color = 'pink', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_ASC1_ASC4_Hmapped_dihedral_3cz3 , kde=True, 
            color = 'cyan', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_ASC1_ASC4_Hmapped_dihedral_2f8s, kde=True, 
            color = 'orange', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_ASC1_ASC4_Hmapped_dihedral_1si3, kde=True, 
            color = 'black', norm_hist=True,
             kde_kws={'linewidth': 1})

    
l = pd.Series(l)

plt = sns.distplot(l, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 4})
plt.set_xlabel('BB2_BB3_ASC1_ASC4_Hmapped_dihedral(nm)'+'\nMean: '+str("{:.2f}".format(l.mean()))+", \
SD: "+str("{:.2f}".format(l.std())))

# plt.set(xlim=(0,360))


# data1 = []
# data2 = []
# for item in l.values:
#     if(item>=0 and item <200 ):
#         data1.append(item)
#     elif(item>=200 and item <360):
#         data2.append(item)

# data1 = pd.Series(data1)
# data2 = pd.Series(data2)


# plt.set_xlabel('BB2_BB3_USC1_USC2_Hmapped_dihedral(nm)'+'\n\n(Peak1) Mean: '+str("{:.2f}".format(data1.mean()))+", \
# SD: "+str("{:.2f}".format(data1.std())) + '\n\n(Peak2) Mean: '+str("{:.2f}".format(data2.mean()))+", \
# SD: "+str("{:.2f}".format(data2.std())))

dihedral_dict['BB2_BB3_ASC1_ASC4'] = [str("{:.2f}".format(l.mean())),str("{:.2f}".format(l.std()))]

plt.figure.savefig("BB2_BB3_ASC1_ASC4.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-76-7934efcb8ed0> in <module>
#       5 #     l.append(int(item+180))
#       6
# ----> 7 plt = sns.distplot(BB2_BB3_ASC1_ASC4_Hmapped_dihedral_7w0f, kde=True,
#       8             color = 'darkblue', norm_hist=True,
#       9              kde_kws={'linewidth': 1})
#
# NameError: name 'BB2_BB3_ASC1_ASC4_Hmapped_dihedral_7w0f' is not defined

# %%
# Density Plot and Histogram of all arrival delays

# Density Plot and Histogram 
l = []
# for item in ASC1_ASC2_ASC3_ASC4_Hmapped_dihedral.values:
#     l.append(int(item+180))

plt = sns.distplot(ASC1_ASC2_ASC3_ASC4_Hmapped_dihedral_7w0f, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC1_ASC2_ASC3_ASC4_Hmapped_dihedral_6ra4, kde=True, 
            color = 'green', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC1_ASC2_ASC3_ASC4_Hmapped_dihedral_6bjv, kde=True, 
            color = 'grey', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC1_ASC2_ASC3_ASC4_Hmapped_dihedral_5n8l, kde=True, 
            color = 'purple', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC1_ASC2_ASC3_ASC4_Hmapped_dihedral_4nh3, kde=True, 
            color = 'red', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC1_ASC2_ASC3_ASC4_Hmapped_dihedral_4ngd, kde=True, 
            color = 'pink', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC1_ASC2_ASC3_ASC4_Hmapped_dihedral_3cz3 , kde=True, 
            color = 'cyan', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC1_ASC2_ASC3_ASC4_Hmapped_dihedral_2f8s, kde=True, 
            color = 'orange', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC1_ASC2_ASC3_ASC4_Hmapped_dihedral_1si3, kde=True, 
            color = 'black', norm_hist=True,
             kde_kws={'linewidth': 4})

    
l = pd.Series(l)

plt = sns.distplot(l, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 4})
plt.set_xlabel('ASC1_ASC2_ASC3_ASC4_Hmapped_dihedral(nm)'+'\nMean: '+str("{:.2f}".format(l.mean()))+", \
SD: "+str("{:.2f}".format(l.std())))

# plt.set(xlim=(0,360))


data1 = []
data2 = []
for item in l.values:
    if(item>=0 and item <180 ):
        data1.append(item)
    elif(item>=180 and item <360):
        data2.append(item)

data1 = pd.Series(data1)
data2 = pd.Series(data2)


plt.set_xlabel('ASC1_ASC2_ASC3_ASC4_Hmapped_dihedral(nm)'+'\n\n(Peak1) Mean: '+str("{:.2f}".format(data1.mean()))+", \
SD: "+str("{:.2f}".format(data1.std())) + '\n\n(Peak2) Mean: '+str("{:.2f}".format(data2.mean()))+", \
SD: "+str("{:.2f}".format(data2.std())))


dihedral_dict['ASC1_ASC2_ASC3_ASC4'] = [str("{:.2f}".format(data1.mean())),str("{:.2f}".format(data2.mean())),str("{:.2f}".format(data1.std())),str("{:.2f}".format(data2.std()))]
plt.figure.savefig("ASC1_ASC2_ASC3_ASC4.png")
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Density Plot and Histogram of all arrival delays

# Density Plot and Histogram 
l = []
# for item in BB1_BB2_BB3_USC1_Hmapped_dihedral.values:
#     l.append(int(item+180))

plt = sns.distplot(BB1_BB2_BB3_USC1_Hmapped_dihedral_7w0f, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_BB3_USC1_Hmapped_dihedral_6ra4, kde=True, 
            color = 'green', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_BB3_USC1_Hmapped_dihedral_6bjv, kde=True, 
            color = 'grey', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_BB3_USC1_Hmapped_dihedral_5n8l, kde=True, 
            color = 'purple', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_BB3_USC1_Hmapped_dihedral_4nh3, kde=True, 
            color = 'red', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_BB3_USC1_Hmapped_dihedral_4ngd, kde=True, 
            color = 'pink', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_BB3_USC1_Hmapped_dihedral_3cz3 , kde=True, 
            color = 'cyan', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_BB3_USC1_Hmapped_dihedral_2f8s, kde=True, 
            color = 'orange', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_BB3_USC1_Hmapped_dihedral_1si3, kde=True, 
            color = 'black', norm_hist=True,
             kde_kws={'linewidth': 1})

    
l = pd.Series(l)

plt = sns.distplot(l, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 4})
plt.set_xlabel('BB1_BB2_BB3_USC1_Hmapped_dihedral(nm)'+'\nMean: '+str("{:.2f}".format(l.mean()))+", \
SD: "+str("{:.2f}".format(l.std())))

# plt.set(xlim=(0,360))

data1 = []
data2 = []
for item in l.values:
    if(item>=0 and item <190 ):
        data1.append(item)
    elif(item>=190 and item <360):
        data2.append(item)

data1 = pd.Series(data1)
data2 = pd.Series(data2)


plt.set_xlabel('BB1_BB2_BB3_USC1_Hmapped_dihedral(nm)'+'\n\n(Peak1) Mean: '+str("{:.2f}".format(data1.mean()))+", \
SD: "+str("{:.2f}".format(data1.std())) + '\n\n(Peak2) Mean: '+str("{:.2f}".format(data2.mean()))+", \
SD: "+str("{:.2f}".format(data2.std())))


dihedral_dict['BB1_BB2_BB3_USC1'] = [str("{:.2f}".format(data1.mean())),str("{:.2f}".format(data2.mean())),str("{:.2f}".format(data1.std())),str("{:.2f}".format(data2.std()))]
plt.figure.savefig("BB1_BB2_BB3_USC1.png")
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Density Plot and Histogram of all arrival delays

# Density Plot and Histogram 
l = []
# for item in BB2_BB3_USC1_USC2_Hmapped_dihedral.values:
#     l.append(int(item+180))

plt = sns.distplot(BB2_BB3_USC1_USC2_Hmapped_dihedral_7w0f, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_USC1_USC2_Hmapped_dihedral_6ra4, kde=True, 
            color = 'green', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_USC1_USC2_Hmapped_dihedral_6bjv, kde=True, 
            color = 'grey', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_USC1_USC2_Hmapped_dihedral_5n8l, kde=True, 
            color = 'purple', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_USC1_USC2_Hmapped_dihedral_4nh3, kde=True, 
            color = 'red', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_USC1_USC2_Hmapped_dihedral_4ngd, kde=True, 
            color = 'pink', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_USC1_USC2_Hmapped_dihedral_3cz3 , kde=True, 
            color = 'cyan', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_USC1_USC2_Hmapped_dihedral_2f8s, kde=True, 
            color = 'orange', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_USC1_USC2_Hmapped_dihedral_1si3, kde=True, 
            color = 'black', norm_hist=True,
             kde_kws={'linewidth': 1})

    
l = pd.Series(l)

plt = sns.distplot(l, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 4})

# plt.set(xlim=(0,360))


data1 = []
data2 = []
for item in l.values:
    if(item>=0 and item <200 ):
        data1.append(item)
    elif(item>=200 and item <360):
        data2.append(item)

data1 = pd.Series(data1)
data2 = pd.Series(data2)


plt.set_xlabel('BB2_BB3_USC1_USC2_Hmapped_dihedral(nm)'+'\n\n(Peak1) Mean: '+str("{:.2f}".format(data1.mean()))+", \
SD: "+str("{:.2f}".format(data1.std())) + '\n\n(Peak2) Mean: '+str("{:.2f}".format(data2.mean()))+", \
SD: "+str("{:.2f}".format(data2.std())))


dihedral_dict['BB2_BB3_USC1_USC2'] = [str("{:.2f}".format(data1.mean())),str("{:.2f}".format(data2.mean())),str("{:.2f}".format(data1.std())),str("{:.2f}".format(data2.std()))]
plt.figure.savefig("BB2_BB3_USC1_USC2.png")
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Density Plot and Histogram of all arrival delays

# Density Plot and Histogram 
l = []
# for item in BB2_BB3_USC1_USC3_Hmapped_dihedral.values:
#     l.append(int(item+180))

plt = sns.distplot(BB2_BB3_USC1_USC3_Hmapped_dihedral_7w0f, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_USC1_USC3_Hmapped_dihedral_6ra4, kde=True, 
            color = 'green', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_USC1_USC3_Hmapped_dihedral_6bjv, kde=True, 
            color = 'grey', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_USC1_USC3_Hmapped_dihedral_5n8l, kde=True, 
            color = 'purple', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_USC1_USC3_Hmapped_dihedral_4nh3, kde=True, 
            color = 'red', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_USC1_USC3_Hmapped_dihedral_4ngd, kde=True, 
            color = 'pink', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_USC1_USC3_Hmapped_dihedral_3cz3 , kde=True, 
            color = 'cyan', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_USC1_USC3_Hmapped_dihedral_2f8s, kde=True, 
            color = 'orange', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_USC1_USC3_Hmapped_dihedral, kde=True, 
            color = 'black', norm_hist=True,
             kde_kws={'linewidth': 1})

    
l = pd.Series(l)

plt = sns.distplot(l, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 4})
plt.set_xlabel('BB2_BB3_USC1_USC3_Hmapped_dihedral(nm)'+'\nMean: '+str("{:.2f}".format(l.mean()))+", \
SD: "+str("{:.2f}".format(l.std())))

data1 = []
data2 = []
for item in l.values:
    if(item>=0 and item <180 ):
        data1.append(item)
    elif(item>=180 and item <360):
        data2.append(item)

data1 = pd.Series(data1)
data2 = pd.Series(data2)


plt.set_xlabel('BB2_BB3_USC1_USC3_Hmapped_dihedral(nm)'+'\n\n(Peak1) Mean: '+str("{:.2f}".format(data1.mean()))+", \
SD: "+str("{:.2f}".format(data1.std())) + '\n\n(Peak2) Mean: '+str("{:.2f}".format(data2.mean()))+", \
SD: "+str("{:.2f}".format(data2.std())))

dihedral_dict['BB2_BB3_USC1_USC3'] = [str("{:.2f}".format(data1.mean())),str("{:.2f}".format(data2.mean())),str("{:.2f}".format(data1.std())),str("{:.2f}".format(data2.std()))]
plt.figure.savefig("BB2_BB3_USC1_USC3.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-78-7d77ec94f8c5> in <module>
#       6 #     l.append(int(item+180))
#       7
# ----> 8 plt = sns.distplot(BB2_BB3_USC1_USC3_Hmapped_dihedral_7w0f, kde=True,
#       9             color = 'darkblue', norm_hist=True,
#      10              kde_kws={'linewidth': 1})
#
# NameError: name 'BB2_BB3_USC1_USC3_Hmapped_dihedral_7w0f' is not defined

# %%
# Density Plot and Histogram of all arrival delays

# Density Plot and Histogram 
l = []
# for item in BB1_BB2_BB3_GSC1_Hmapped_dihedral.values:
#     l.append(int(item+180))

plt = sns.distplot(BB1_BB2_BB3_GSC1_Hmapped_dihedral_7w0f, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_BB3_GSC1_Hmapped_dihedral_6ra4, kde=True, 
            color = 'green', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_BB3_GSC1_Hmapped_dihedral_6bjv, kde=True, 
            color = 'grey', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_BB3_GSC1_Hmapped_dihedral_5n8l, kde=True, 
            color = 'purple', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_BB3_GSC1_Hmapped_dihedral_4nh3, kde=True, 
            color = 'red', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_BB3_GSC1_Hmapped_dihedral_4ngd, kde=True, 
            color = 'pink', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_BB3_GSC1_Hmapped_dihedral_3cz3 , kde=True, 
            color = 'cyan', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_BB3_GSC1_Hmapped_dihedral_2f8s, kde=True, 
            color = 'orange', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_BB3_GSC1_Hmapped_dihedral_1si3, kde=True, 
            color = 'black', norm_hist=True,
             kde_kws={'linewidth': 1})

    
l = pd.Series(l)

plt = sns.distplot(l, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 4})
# plt.set_xlabel('BB1_BB2_BB3_GSC1_Hmapped_dihedral(nm)'+'\nMean: '+str("{:.2f}".format(l.mean()))+", \
# SD: "+str("{:.2f}".format(l.std())))

# plt.set(xlim=(0,360))

data1 = []
data2 = []
for item in l.values:
    if(item>=0 and item <110 ):
        data1.append(item)
    elif(item>=110 and item <360):
        data2.append(item)

data1 = pd.Series(data1)
data2 = pd.Series(data2)


plt.set_xlabel('BB1_BB2_BB3_GSC1_Hmapped_dihedral(nm)'+'\n\n(Peak1) Mean: '+str("{:.2f}".format(data1.mean()))+", \
SD: "+str("{:.2f}".format(data1.std())) + '\n\n(Peak2) Mean: '+str("{:.2f}".format(data2.mean()))+", \
SD: "+str("{:.2f}".format(data2.std())))

dihedral_dict['BB1_BB2_BB3_GSC1'] = [str("{:.2f}".format(data1.mean())),str("{:.2f}".format(data2.mean())),str("{:.2f}".format(data1.std())),str("{:.2f}".format(data2.std()))]
plt.figure.savefig("BB1_BB2_BB3_GSC1.png")
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Density Plot and Histogram of all arrival delays

# Density Plot and Histogram 
l = []
# for item in BB2_BB3_GSC1_GSC2_Hmapped_dihedral.values:
#     l.append(int(item+180))

plt = sns.distplot(BB2_BB3_GSC1_GSC2_Hmapped_dihedral_7w0f, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_GSC1_GSC2_Hmapped_dihedral_6ra4, kde=True, 
            color = 'green', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_GSC1_GSC2_Hmapped_dihedral_6bjv, kde=True, 
            color = 'grey', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_GSC1_GSC2_Hmapped_dihedral_5n8l, kde=True, 
            color = 'purple', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_GSC1_GSC2_Hmapped_dihedral_4nh3, kde=True, 
            color = 'red', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_GSC1_GSC2_Hmapped_dihedral_4ngd, kde=True, 
            color = 'pink', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_GSC1_GSC2_Hmapped_dihedral_3cz3 , kde=True, 
            color = 'cyan', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_GSC1_GSC2_Hmapped_dihedral_2f8s, kde=True, 
            color = 'orange', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_GSC1_GSC2_Hmapped_dihedral_1si3, kde=True, 
            color = 'black', norm_hist=True,
             kde_kws={'linewidth': 1})

    
l = pd.Series(l)

plt = sns.distplot(l, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 4})
# plt.set_xlabel('BB2_BB3_GSC1_GSC2_Hmapped_dihedral(nm)'+'\nMean: '+str("{:.2f}".format(l.mean()))+", \
# SD: "+str("{:.2f}".format(l.std())))

# plt.set(xlim=(0,360))



data1 = []
data2 = []
for item in l.values:
    if(item>=0 and item <180 ):
        data1.append(item)
    elif(item>=180 and item <360):
        data2.append(item)

data1 = pd.Series(data1)
data2 = pd.Series(data2)


plt.set_xlabel('BB2_BB3_GSC1_GSC2_Hmapped_dihedral(nm)'+'\n\n(Peak1) Mean: '+str("{:.2f}".format(data1.mean()))+", \
SD: "+str("{:.2f}".format(data1.std())) + '\n\n(Peak2) Mean: '+str("{:.2f}".format(data2.mean()))+", \
SD: "+str("{:.2f}".format(data2.std())))

dihedral_dict['BB2_BB3_GSC1_GSC2'] = [str("{:.2f}".format(data1.mean())),str("{:.2f}".format(data2.mean())),str("{:.2f}".format(data1.std())),str("{:.2f}".format(data2.std()))]
plt.figure.savefig("BB2_BB3_GSC1_GSC2.png")
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Density Plot and Histogram of all arrival delays

# Density Plot and Histogram 
l = []
# for item in BB2_BB3_GSC1_GSC4_Hmapped_dihedral.values:
#     l.append(int(item+180))

plt = sns.distplot(BB2_BB3_GSC1_GSC4_Hmapped_dihedral_7w0f, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_GSC1_GSC4_Hmapped_dihedral_6ra4, kde=True, 
            color = 'green', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_GSC1_GSC4_Hmapped_dihedral_6bjv, kde=True, 
            color = 'grey', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_GSC1_GSC4_Hmapped_dihedral_5n8l, kde=True, 
            color = 'purple', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_GSC1_GSC4_Hmapped_dihedral_4nh3, kde=True, 
            color = 'red', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_GSC1_GSC4_Hmapped_dihedral_4ngd, kde=True, 
            color = 'pink', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_GSC1_GSC4_Hmapped_dihedral_3cz3 , kde=True, 
            color = 'cyan', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_GSC1_GSC4_Hmapped_dihedral_2f8s, kde=True, 
            color = 'orange', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_GSC1_GSC4_Hmapped_dihedral_1si3, kde=True, 
            color = 'black', norm_hist=True,
             kde_kws={'linewidth': 1})

    
l = pd.Series(l)
plt.set(xlim=(0,400))

plt = sns.distplot(l, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 4})
plt.set_xlabel('BB2_BB3_GSC1_GSC4_Hmapped_dihedral(nm)'+'\nMean: '+str("{:.2f}".format(l.mean()))+", \
# SD: "+str("{:.2f}".format(l.std())))

# data1 = []
# data2 = []
# for item in l.values:
#     if(item>=0 and item <50 ):
#         data1.append(item)
#     elif(item>=50 and item <360):
#         data2.append(item)

# data1 = pd.Series(data1)
# data2 = pd.Series(data2)


# plt.set_xlabel('BB2_BB3_USC1_USC2_Hmapped_dihedral(nm)'+'\n\n(Peak1) Mean: '+str("{:.2f}".format(data1.mean()))+", \
# SD: "+str("{:.2f}".format(data1.std())) + '\n\n(Peak2) Mean: '+str("{:.2f}".format(data2.mean()))+", \
# SD: "+str("{:.2f}".format(data2.std())))

# plt.set(xlim=(0,360))

dihedral_dict['BB2_BB3_GSC1_GSC4'] = [str("{:.2f}".format(l.mean())),str("{:.2f}".format(l.std()))]
plt.figure.savefig("BB2_BB3_GSC1_GSC4.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-5cedb320f647> in <module>
#       6 #     l.append(int(item+180))
#       7
# ----> 8 plt = sns.distplot(BB2_BB3_GSC1_GSC4_Hmapped_dihedral_7w0f, kde=True,
#       9             color = 'darkblue', norm_hist=True,
#      10              kde_kws={'linewidth': 1})
#
# NameError: name 'BB2_BB3_GSC1_GSC4_Hmapped_dihedral_7w0f' is not defined

# %%
# Density Plot and Histogram of all arrival delays

# Density Plot and Histogram 
l = []
# for item in GSC1_GSC2_GSC3_GSC4_Hmapped_dihedral.values:
#     l.append(int(item+180))

plt = sns.distplot(GSC1_GSC2_GSC3_GSC4_Hmapped_dihedral_7w0f, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC1_GSC2_GSC3_GSC4_Hmapped_dihedral_6ra4, kde=True, 
            color = 'green', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC1_GSC2_GSC3_GSC4_Hmapped_dihedral_6bjv, kde=True, 
            color = 'grey', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC1_GSC2_GSC3_GSC4_Hmapped_dihedral_5n8l, kde=True, 
            color = 'purple', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC1_GSC2_GSC3_GSC4_Hmapped_dihedral_4nh3, kde=True, 
            color = 'red', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC1_GSC2_GSC3_GSC4_Hmapped_dihedral_4ngd, kde=True, 
            color = 'pink', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC1_GSC2_GSC3_GSC4_Hmapped_dihedral_3cz3 , kde=True, 
            color = 'cyan', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC1_GSC2_GSC3_GSC4_Hmapped_dihedral_2f8s, kde=True, 
            color = 'orange', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC1_GSC2_GSC3_GSC4_Hmapped_dihedral_1si3, kde=True, 
            color = 'black', norm_hist=True,
             kde_kws={'linewidth': 1})

    
l = pd.Series(l)
plt.set(xlim=(0,400))

plt = sns.distplot(l, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 4})
plt.set_xlabel('GSC1_GSC2_GSC3_GSC4_Hmapped_dihedral(nm)'+'\nMean: '+str("{:.2f}".format(l.mean()))+", \
SD: "+str("{:.2f}".format(l.std())))

dihedral_dict['GSC1_GSC2_GSC3_GSC4'] = [str("{:.2f}".format(l.mean())),str("{:.2f}".format(l.std()))]

plt.figure.savefig("GSC1_GSC2_GSC3_GSC4.png")
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Density Plot and Histogram of all arrival delays

# Density Plot and Histogram 
l = []
# for item in BB1_BB2_BB3_CSC1_Hmapped_dihedral.values:
#     l.append(int(item+180))

plt = sns.distplot(BB1_BB2_BB3_CSC1_Hmapped_dihedral_7w0f, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_BB3_CSC1_Hmapped_dihedral_6ra4, kde=True, 
            color = 'green', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_BB3_CSC1_Hmapped_dihedral_6bjv, kde=True, 
            color = 'grey', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_BB3_CSC1_Hmapped_dihedral_5n8l, kde=True, 
            color = 'purple', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_BB3_CSC1_Hmapped_dihedral_4nh3, kde=True, 
            color = 'red', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_BB3_CSC1_Hmapped_dihedral_4ngd, kde=True, 
            color = 'pink', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_BB3_CSC1_Hmapped_dihedral_3cz3 , kde=True, 
            color = 'cyan', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BBB1_BB2_BB3_CSC1_Hmapped_dihedral_2f8s, kde=True, 
            color = 'orange', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_BB3_CSC1_Hmapped_dihedral_1si3, kde=True, 
            color = 'black', norm_hist=True,
             kde_kws={'linewidth': 1})

l = pd.Series(l)
plt.set(xlim=(0,400))

plt = sns.distplot(l, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 4})
# plt.set_xlabel('BB1_BB2_BB3_CSC1_Hmapped_dihedral(nm)'+'\nMean: '+str("{:.2f}".format(l.mean()))+", \
# SD: "+str("{:.2f}".format(l.std())))


data1 = []
data2 = []
for item in l.values:
    if(item>=0 and item <150 ):
        data1.append(item)
    elif(item>=150 and item <360):
        data2.append(item)

data1 = pd.Series(data1)
data2 = pd.Series(data2)


plt.set_xlabel('BB1_BB2_BB3_CSC1_Hmapped_dihedral(nm)'+'\n\n(Peak1) Mean: '+str("{:.2f}".format(data1.mean()))+", \
SD: "+str("{:.2f}".format(data1.std())) + '\n\n(Peak2) Mean: '+str("{:.2f}".format(data2.mean()))+", \
SD: "+str("{:.2f}".format(data2.std())))


# plt.set(xlim=(0,360))
dihedral_dict['BB1_BB2_BB3_CSC1'] = [str("{:.2f}".format(data1.mean())),str("{:.2f}".format(data2.mean())),str("{:.2f}".format(data1.std())),str("{:.2f}".format(data2.std()))]

plt.figure.savefig("BB1_BB2_BB3_CSC1.png")
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Density Plot and Histogram of all arrival delays

# Density Plot and Histogram 
l = []
# for item in BB2_BB3_CSC1_CSC2_Hmapped_dihedral.values:
#     l.append(int(item+180))

plt = sns.distplot(BB2_BB3_CSC1_CSC2_Hmapped_dihedral_7w0f, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_CSC1_CSC2_Hmapped_dihedral_6ra4, kde=True, 
            color = 'green', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_CSC1_CSC2_Hmapped_dihedral_6bjv, kde=True, 
            color = 'grey', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_CSC1_CSC2_Hmapped_dihedral_5n8l, kde=True, 
            color = 'purple', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_CSC1_CSC2_Hmapped_dihedral_4nh3, kde=True, 
            color = 'red', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_CSC1_CSC2_Hmapped_dihedral_4ngd, kde=True, 
            color = 'pink', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_CSC1_CSC2_Hmapped_dihedral_3cz3 , kde=True, 
            color = 'cyan', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_CSC1_CSC2_Hmapped_dihedral_2f8s, kde=True, 
            color = 'orange', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_CSC1_CSC2_Hmapped_dihedral_1si3, kde=True, 
            color = 'black', norm_hist=True,
             kde_kws={'linewidth': 1})

    
l = pd.Series(l)
plt.set(xlim=(0,400))

plt = sns.distplot(l, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 4})
# plt.set_xlabel('BB2_BB3_CSC1_CSC2_Hmapped_dihedral(nm)'+'\nMean: '+str("{:.2f}".format(l.mean()))+", \
# SD: "+str("{:.2f}".format(l.std())))


data1 = []
data2 = []
for item in l.values:
    if(item>=0 and item <180 ):
        data1.append(item)
    elif(item>=180 and item <360):
        data2.append(item)

data1 = pd.Series(data1)
data2 = pd.Series(data2)


plt.set_xlabel('BB2_BB3_CSC1_CSC2_Hmapped_dihedral(nm)'+'\n\n(Peak1) Mean: '+str("{:.2f}".format(data1.mean()))+", \
SD: "+str("{:.2f}".format(data1.std())) + '\n\n(Peak2) Mean: '+str("{:.2f}".format(data2.mean()))+", \
SD: "+str("{:.2f}".format(data2.std())))

dihedral_dict['BB2_BB3_CSC1_CSC2'] = [str("{:.2f}".format(data1.mean())),str("{:.2f}".format(data2.mean())),str("{:.2f}".format(data1.std())),str("{:.2f}".format(data2.std()))]
plt.figure.savefig("BB2_BB3_CSC1_CSC2.png")
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Density Plot and Histogram of all arrival delays

# Density Plot and Histogram 
l = []
# for item in BB2_BB3_CSC1_CSC3_Hmapped_dihedral.values:
#     l.append(int(item+180))

plt = sns.distplot(BB2_BB3_CSC1_CSC3_Hmapped_dihedral_7w0f, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_CSC1_CSC3_Hmapped_dihedral_6ra4, kde=True, 
            color = 'green', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_CSC1_CSC3_Hmapped_dihedral_6bjv, kde=True, 
            color = 'grey', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_CSC1_CSC3_Hmapped_dihedral_5n8l, kde=True, 
            color = 'purple', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_CSC1_CSC3_Hmapped_dihedral_4nh3, kde=True, 
            color = 'red', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_CSC1_CSC3_Hmapped_dihedral_4ngd, kde=True, 
            color = 'pink', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_CSC1_CSC3_Hmapped_dihedral_3cz3 , kde=True, 
            color = 'cyan', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_CSC1_CSC3_Hmapped_dihedral_2f8s, kde=True, 
            color = 'orange', norm_hist=True,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_CSC1_CSC3_Hmapped_dihedral_1si3, kde=True, 
            color = 'black', norm_hist=True,
             kde_kws={'linewidth': 1})

l = pd.Series(l)
plt.set(xlim=(0,400))

plt = sns.distplot(l, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 4})
# plt.set_xlabel('BB2_BB3_CSC1_CSC3_Hmapped_dihedral(nm)'+'\nMean: '+str("{:.2f}".format(l.mean()))+", \
# SD: "+str("{:.2f}".format(l.std())))

# plt.set(xlim=(0,360))

data1 = []
data2 = []
for item in l.values:
    if(item>=0 and item <180 ):
        data1.append(item)
    elif(item>=180 and item <360):
        data2.append(item)

data1 = pd.Series(data1)
data2 = pd.Series(data2)


plt.set_xlabel('BB2_BB3_CSC1_CSC3_Hmapped_dihedral(nm)'+'\n\n(Peak1) Mean: '+str("{:.2f}".format(data1.mean()))+", \
SD: "+str("{:.2f}".format(data1.std())) + '\n\n(Peak2) Mean: '+str("{:.2f}".format(data2.mean()))+", \
SD: "+str("{:.2f}".format(data2.std())))


dihedral_dict['BB2_BB3_CSC1_CSC3'] = [str("{:.2f}".format(data1.mean())),str("{:.2f}".format(data2.mean())),str("{:.2f}".format(data1.std())),str("{:.2f}".format(data2.std()))]
plt.figure.savefig("BB2_BB3_CSC1_CSC3.png")
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...
