# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
# df_Hmapped = pd.read_csv('dist_Hmapped.csv',delimiter=" ")

# %%
df_Hmapped_dihedral = pd.read_csv('dihedral0.xvg')

# %%
df_Hmapped_dihedral
# Out:
#          time  BB1_BB2_BB3_ASC1  BB2_BB3_ASC1_ASC2  ASC1_ASC2_ASC3_ASC4  \
# 0           0          -140.576           -153.485                1.469
# 1        1000          -140.077           -156.448                1.235
# 2        2000          -140.380           -153.165                1.305
# 3        3000          -141.660           -147.521                0.139
# 4        4000          -141.665           -154.632                1.309
# ...       ...               ...                ...                  ...
# 996    996000          -142.806           -154.943                0.754
# 997    997000          -142.628           -153.613                0.556
# 998    998000          -142.582           -155.663                0.421
# 999    999000          -140.614           -154.476                0.840
# 1000  1000000          -140.358           -157.182                1.187
#
#       BB1_BB2_BB3_USC1  BB2_BB3_USC1_USC2  BB1_BB2_BB3_GSC1  \
# ...

# %%
BB1_BB2_BB3_ASC1_Hmapped_dihedral = df_Hmapped_dihedral['BB1_BB2_BB3_ASC1']
BB2_BB3_ASC1_ASC2_Hmapped_dihedral = df_Hmapped_dihedral['BB2_BB3_ASC1_ASC2']
# BB2_BB3_ASC1_ASC4_Hmapped_dihedral = df_Hmapped_dihedral['BB2_BB3_ASC1_ASC4']
ASC1_ASC2_ASC3_ASC4_Hmapped_dihedral = df_Hmapped_dihedral['ASC1_ASC2_ASC3_ASC4']

BB1_BB2_BB3_USC1_Hmapped_dihedral = df_Hmapped_dihedral['BB1_BB2_BB3_USC1']
BB2_BB3_USC1_USC2_Hmapped_dihedral = df_Hmapped_dihedral['BB2_BB3_USC1_USC2']
# BB2_BB3_USC1_USC3_Hmapped_dihedral = df_Hmapped_dihedral['BB2_BB3_USC1_USC3']

BB1_BB2_BB3_GSC1_Hmapped_dihedral = df_Hmapped_dihedral['BB1_BB2_BB3_GSC1']
BB2_BB3_GSC1_GSC2_Hmapped_dihedral = df_Hmapped_dihedral['BB2_BB3_GSC1_GSC2']
# BB2_BB3_GSC1_GSC4_Hmapped_dihedral = df_Hmapped_dihedral['BB2_BB3_GSC1_GSC4']
GSC1_GSC2_GSC3_GSC4_Hmapped_dihedral = df_Hmapped_dihedral['GSC1_GSC2_GSC3_GSC4']


BB1_BB2_BB3_CSC1_Hmapped_dihedral = df_Hmapped_dihedral['BB1_BB2_BB3_CSC1']
BB2_BB3_CSC1_CSC2_Hmapped_dihedral = df_Hmapped_dihedral['BB2_BB3_CSC1_CSC2']
BB2_BB3_CSC1_CSC3_Hmapped_dihedral = df_Hmapped_dihedral['BB2_BB3_CSC1_CSC3']

# %%
plt = sns.distplot(BB1_BB2_BB3_ASC1_Hmapped_dihedral, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 4})
plt.set_xlabel('BB1_BB2_BB3_ASC1(nm)'+'\nMean: '+str("{:.2f}".format(BB1_BB2_BB3_ASC1_Hmapped_dihedral.mean()))+",\
SD: "+str("{:.2f}".format(BB1_BB2_BB3_ASC1_Hmapped_dihedral.std())))


plt
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='BB1_BB2_BB3_ASC1(nm)\nMean: -140.59,SD: 1.58', ylabel='Density'>

# %%
# Density Plot and Histogram 
l = []
for item in BB2_BB3_ASC1_ASC2_Hmapped_dihedral.values:
    l.append(int(item+180))
    
l = pd.Series(l)

plt = sns.distplot(BB2_BB3_ASC1_ASC2_Hmapped_dihedral, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 4})
# plt.set_xlabel('BB2_BB3(nm)')
plt.set_xlabel('BB2_BB3_ASC1_ASC2_Hmapped_dihedral(nm)'+'\nMean: '+str("{:.2f}".format(BB2_BB3_ASC1_ASC2_Hmapped_dihedral.mean()))+",\
SD: "+str("{:.2f}".format(BB2_BB3_ASC1_ASC2_Hmapped_dihedral.std())))
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'BB2_BB3_ASC1_ASC2_Hmapped_dihedral(nm)\nMean: -154.58,SD: 2.17')

# %%
# Density Plot and Histogram of all arrival delays
plt = sns.distplot(BB2_BB3_ASC1_ASC4_Hmapped_dihedral, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 4})
plt.set_xlabel('BB2_BB3_ASC1_ASC4_Hmapped_dihedral(nm)'+'\nMean: '+str("{:.2f}".format(BB2_BB3_ASC1_ASC4_Hmapped_dihedral.mean()))+", \
SD: "+str("{:.2f}".format(BB2_BB3_ASC1_ASC4_Hmapped_dihedral.std())))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-2d103688b7af> in <module>
#       1 # Density Plot and Histogram of all arrival delays
# ----> 2 plt = sns.distplot(BB2_BB3_ASC1_ASC4_Hmapped_dihedral, kde=True,
#       3             color = 'darkblue', norm_hist=True,
#       4              kde_kws={'linewidth': 4})
#       5 plt.set_xlabel('BB2_BB3_ASC1_ASC4_Hmapped_dihedral(nm)'+'\nMean: '+str("{:.2f}".format(BB2_BB3_ASC1_ASC4_Hmapped_dihedral.mean()))+", \
#
# NameError: name 'BB2_BB3_ASC1_ASC4_Hmapped_dihedral' is not defined

# %%
# Density Plot and Histogram of all arrival delays
plt = sns.distplot(ASC1_ASC2_ASC3_ASC4_Hmapped_dihedral, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 4})
plt.set_xlabel('ASC1_ASC2_ASC3_ASC4_Hmapped_dihedral(nm)'+'\nMean: '+str("{:.2f}".format(ASC1_ASC2_ASC3_ASC4_Hmapped_dihedral.mean()))+", \
SD: "+str("{:.2f}".format(ASC1_ASC2_ASC3_ASC4_Hmapped_dihedral.std())))
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'ASC1_ASC2_ASC3_ASC4_Hmapped_dihedral(nm)\nMean: 0.82, SD: 0.62')

# %%
# Density Plot and Histogram of all arrival delays
plt = sns.distplot(BB1_BB2_BB3_USC1_Hmapped_dihedral, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 4})
plt.set_xlabel('BB1_BB2_BB3_USC1_Hmapped_dihedral(nm)'+'\nMean: '+str("{:.2f}".format(BB1_BB2_BB3_USC1_Hmapped_dihedral.mean()))+", \
SD: "+str("{:.2f}".format(BB1_BB2_BB3_USC1_Hmapped_dihedral.std())))
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'BB1_BB2_BB3_USC1_Hmapped_dihedral(nm)\nMean: -133.23, SD: 1.97')

# %%
# Density Plot and Histogram of all arrival delays
plt = sns.distplot(BB2_BB3_USC1_USC2_Hmapped_dihedral, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 4})
plt.set_xlabel('BB2_BB3_USC1_USC2_Hmapped_dihedral(nm)'+'\nMean: '+str("{:.2f}".format(BB2_BB3_USC1_USC2_Hmapped_dihedral.mean()))+", \
SD: "+str("{:.2f}".format(BB2_BB3_USC1_USC2_Hmapped_dihedral.std())))
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'BB2_BB3_USC1_USC2_Hmapped_dihedral(nm)\nMean: -145.80, SD: 2.65')

# %%
# Density Plot and Histogram of all arrival delays
plt = sns.distplot(BB2_BB3_USC1_USC3_Hmapped_dihedral, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 4})
plt.set_xlabel('BB2_BB3_USC1_USC3_Hmapped_dihedral(nm)'+'\nMean: '+str("{:.2f}".format(BB2_BB3_USC1_USC3_Hmapped_dihedral.mean()))+", \
SD: "+str("{:.2f}".format(BB2_BB3_USC1_USC3_Hmapped_dihedral.std())))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-0f273d1043bc> in <module>
#       1 # Density Plot and Histogram of all arrival delays
# ----> 2 plt = sns.distplot(BB2_BB3_USC1_USC3_Hmapped_dihedral, kde=True,
#       3             color = 'darkblue', norm_hist=True,
#       4              kde_kws={'linewidth': 4})
#       5 plt.set_xlabel('BB2_BB3_USC1_USC3_Hmapped_dihedral(nm)'+'\nMean: '+str("{:.2f}".format(BB2_BB3_USC1_USC3_Hmapped_dihedral.mean()))+", \
#
# NameError: name 'BB2_BB3_USC1_USC3_Hmapped_dihedral' is not defined

# %%
# Density Plot and Histogram of all arrival delays
plt = sns.distplot(BB1_BB2_BB3_GSC1_Hmapped_dihedral, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 4})
plt.set_xlabel('BB1_BB2_BB3_GSC1_Hmapped_dihedral(nm)'+'\nMean: '+str("{:.2f}".format(BB1_BB2_BB3_GSC1_Hmapped_dihedral.mean()))+", \
SD: "+str("{:.2f}".format(BB1_BB2_BB3_GSC1_Hmapped_dihedral.std())))

# %%
# Density Plot and Histogram of all arrival delays
plt = sns.distplot(BB2_BB3_GSC1_GSC2_Hmapped_dihedral, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 4})
plt.set_xlabel('BB2_BB3_GSC1_GSC2_Hmapped_dihedral(nm)'+'\nMean: '+str("{:.2f}".format(BB2_BB3_GSC1_GSC2_Hmapped_dihedral.mean()))+", \
SD: "+str("{:.2f}".format(BB2_BB3_GSC1_GSC2_Hmapped_dihedral.std())))

# %%
# Density Plot and Histogram of all arrival delays
plt = sns.distplot(BB2_BB3_GSC1_GSC4_Hmapped_dihedral, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 4})
plt.set_xlabel('BB2_BB3_GSC1_GSC4_Hmapped_dihedral(nm)'+'\nMean: '+str("{:.2f}".format(BB2_BB3_GSC1_GSC4_Hmapped_dihedral.mean()))+", \
SD: "+str("{:.2f}".format(BB2_BB3_GSC1_GSC4_Hmapped_dihedral.std())))

# %%
# Density Plot and Histogram of all arrival delays
plt = sns.distplot(GSC1_GSC2_GSC3_GSC4_Hmapped_dihedral, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 4})
plt.set_xlabel('GSC1_GSC2_GSC3_GSC4_Hmapped_dihedral(nm)'+'\nMean: '+str("{:.2f}".format(GSC1_GSC2_GSC3_GSC4_Hmapped_dihedral.mean()))+", \
SD: "+str("{:.2f}".format(GSC1_GSC2_GSC3_GSC4_Hmapped_dihedral.std())))

# %%
# Density Plot and Histogram of all arrival delays
plt = sns.distplot(BB1_BB2_BB3_CSC1_Hmapped_dihedral, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 4})
plt.set_xlabel('BB1_BB2_BB3_CSC1_Hmapped_dihedral(nm)'+'\nMean: '+str("{:.2f}".format(BB1_BB2_BB3_CSC1_Hmapped_dihedral.mean()))+", \
SD: "+str("{:.2f}".format(BB1_BB2_BB3_CSC1_Hmapped_dihedral.std())))

# %%
# Density Plot and Histogram of all arrival delays
plt = sns.distplot(BB2_BB3_CSC1_CSC2_Hmapped_dihedral, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 4})
plt.set_xlabel('BB2_BB3_CSC1_CSC2_Hmapped_dihedral(nm)'+'\nMean: '+str("{:.2f}".format(BB2_BB3_CSC1_CSC2_Hmapped_dihedral.mean()))+", \
SD: "+str("{:.2f}".format(BB2_BB3_CSC1_CSC2_Hmapped_dihedral.std())))
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'BB2_BB3_CSC1_CSC2_Hmapped_dihedral(nm)\nMean: -151.49, SD: 1.95')

# %%
# Density Plot and Histogram of all arrival delays
plt = sns.distplot(BB2_BB3_CSC1_CSC3_Hmapped_dihedral, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 4})
plt.set_xlabel('BB2_BB3_CSC1_CSC3_Hmapped_dihedral(nm)'+'\nMean: '+str("{:.2f}".format(BB2_BB3_CSC1_CSC3_Hmapped_dihedral.mean()))+", \
SD: "+str("{:.2f}".format(BB2_BB3_CSC1_CSC3_Hmapped_dihedral.std())))
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'BB2_BB3_CSC1_CSC3_Hmapped_dihedral(nm)\nMean: 144.44, SD: 2.08')
