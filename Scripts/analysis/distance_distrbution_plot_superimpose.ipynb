# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
# df_Hmapped = pd.read_csv('dist_Hmapped.csv',delimiter=" ")

# %%
distance_dict = dict.fromkeys(['BB1_BB2','BB2_BB3','BB3_ASC1','ASC2_ASC4','ASC1_ASC3','ASC1_ASC2','ASC2_ASC3','ASC3_ASC4',\
'ASC4_ASC1','BB3_USC1','USC1_USC2','USC2_USC3','USC3_USC1','BB3_GSC1','GSC2_GSC4','GSC1_GSC3','GSC1_GSC2','GSC2_GSC3',\
'GSC3_GSC4','GSC4_GSC1','BB3_CSC1','CSC1_CSC2','CSC2_CSC3','CSC3_CSC1'])

# %%
df_Hmapped_distance_7w0f = pd.read_csv('7w0f/dist_final.xvg')
df_Hmapped_distance_6ra4 = pd.read_csv('6ra4/dist_final.xvg')
df_Hmapped_distance_6bjv = pd.read_csv('6bjv/dist_final.xvg')
df_Hmapped_distance_5n8l = pd.read_csv('5n8l/dist_final.xvg')
df_Hmapped_distance_4nh3 = pd.read_csv('4nh3/dist_final.xvg')
df_Hmapped_distance_4ngd = pd.read_csv('4ngd/dist_final.xvg')
df_Hmapped_distance_3cz3 = pd.read_csv('3cz3/dist_final.xvg')
df_Hmapped_distance_2f8s = pd.read_csv('2f8s/dist_final.xvg')
df_Hmapped_distance_1si3 = pd.read_csv('1si3/dist_final.xvg')
# df_Hmapped_distance_1rpu = pd.read_csv('1rpu/dist.xvg')

# %%
# 1rpu  1si3  2f8s  3cz3  4ngd  4nh3  5n8l  6bjv  6ra4  7w0f

BB1_BB2_Hmapped_distance_7w0f = df_Hmapped_distance_7w0f['BB1_BB2']
BB1_BB2_Hmapped_distance_6ra4 = df_Hmapped_distance_6ra4['BB1_BB2']
BB1_BB2_Hmapped_distance_6bjv = df_Hmapped_distance_6bjv['BB1_BB2']
BB1_BB2_Hmapped_distance_5n8l = df_Hmapped_distance_5n8l['BB1_BB2']
BB1_BB2_Hmapped_distance_4nh3 = df_Hmapped_distance_4nh3['BB1_BB2']
BB1_BB2_Hmapped_distance_4ngd = df_Hmapped_distance_4ngd['BB1_BB2']
BB1_BB2_Hmapped_distance_3cz3 = df_Hmapped_distance_3cz3['BB1_BB2']
BB1_BB2_Hmapped_distance_2f8s = df_Hmapped_distance_2f8s['BB1_BB2']
BB1_BB2_Hmapped_distance_1si3 = df_Hmapped_distance_1si3['BB1_BB2']
# BB1_BB2_Hmapped_distance_1rpu = df_Hmapped_distance_1rpu['BB1_BB2']

BB2_BB3_Hmapped_distance_7w0f = df_Hmapped_distance_7w0f['BB2_BB3']
BB2_BB3_Hmapped_distance_6ra4 = df_Hmapped_distance_6ra4['BB2_BB3']
BB2_BB3_Hmapped_distance_6bjv = df_Hmapped_distance_6bjv['BB2_BB3']
BB2_BB3_Hmapped_distance_5n8l = df_Hmapped_distance_5n8l['BB2_BB3']
BB2_BB3_Hmapped_distance_4nh3 = df_Hmapped_distance_4nh3['BB2_BB3']
BB2_BB3_Hmapped_distance_4ngd = df_Hmapped_distance_4ngd['BB2_BB3']
BB2_BB3_Hmapped_distance_3cz3 = df_Hmapped_distance_3cz3['BB2_BB3']
BB2_BB3_Hmapped_distance_2f8s = df_Hmapped_distance_2f8s['BB2_BB3']
BB2_BB3_Hmapped_distance_1si3 = df_Hmapped_distance_1si3['BB2_BB3']
# BB2_BB3_Hmapped_distance_1rpu = df_Hmapped_distance_1rpu['BB2_BB3']

BB3_ASC1_Hmapped_distance_7w0f = df_Hmapped_distance_7w0f['BB3_ASC1']
BB3_ASC1_Hmapped_distance_6ra4 = df_Hmapped_distance_6ra4['BB3_ASC1']
BB3_ASC1_Hmapped_distance_6bjv = df_Hmapped_distance_6bjv['BB3_ASC1']
BB3_ASC1_Hmapped_distance_5n8l = df_Hmapped_distance_5n8l['BB3_ASC1']
BB3_ASC1_Hmapped_distance_4nh3 = df_Hmapped_distance_4nh3['BB3_ASC1']
BB3_ASC1_Hmapped_distance_4ngd = df_Hmapped_distance_4ngd['BB3_ASC1']
BB3_ASC1_Hmapped_distance_3cz3 = df_Hmapped_distance_3cz3['BB3_ASC1']
BB3_ASC1_Hmapped_distance_2f8s = df_Hmapped_distance_2f8s['BB3_ASC1']
BB3_ASC1_Hmapped_distance_1si3 = df_Hmapped_distance_1si3['BB3_ASC1']
# BB3_ASC1_Hmapped_distance_1rpu = df_Hmapped_distance_1rpu['BB3_ASC1']

BB3_USC1_Hmapped_distance_7w0f = df_Hmapped_distance_7w0f['BB3_USC1']
BB3_USC1_Hmapped_distance_6ra4 = df_Hmapped_distance_6ra4['BB3_USC1']
BB3_USC1_Hmapped_distance_6bjv = df_Hmapped_distance_6bjv['BB3_USC1']
BB3_USC1_Hmapped_distance_5n8l = df_Hmapped_distance_5n8l['BB3_USC1']
BB3_USC1_Hmapped_distance_4nh3 = df_Hmapped_distance_4nh3['BB3_USC1']
BB3_USC1_Hmapped_distance_4ngd = df_Hmapped_distance_4ngd['BB3_USC1']
BB3_USC1_Hmapped_distance_3cz3 = df_Hmapped_distance_3cz3['BB3_USC1']
BB3_USC1_Hmapped_distance_2f8s = df_Hmapped_distance_2f8s['BB3_USC1']
BB3_USC1_Hmapped_distance_1si3 = df_Hmapped_distance_1si3['BB3_USC1']
# BB3_USC1_Hmapped_distance_1rpu = df_Hmapped_distance_1rpu['BB3_USC1']


BB3_GSC1_Hmapped_distance_7w0f = df_Hmapped_distance_7w0f['BB3_GSC1']
BB3_GSC1_Hmapped_distance_6ra4 = df_Hmapped_distance_6ra4['BB3_GSC1']
BB3_GSC1_Hmapped_distance_6bjv = df_Hmapped_distance_6bjv['BB3_GSC1']
BB3_GSC1_Hmapped_distance_5n8l = df_Hmapped_distance_5n8l['BB3_GSC1']
BB3_GSC1_Hmapped_distance_4nh3 = df_Hmapped_distance_4nh3['BB3_GSC1']
BB3_GSC1_Hmapped_distance_4ngd = df_Hmapped_distance_4ngd['BB3_GSC1']
BB3_GSC1_Hmapped_distance_3cz3 = df_Hmapped_distance_3cz3['BB3_GSC1']
BB3_GSC1_Hmapped_distance_2f8s = df_Hmapped_distance_2f8s['BB3_GSC1']
BB3_GSC1_Hmapped_distance_1si3 = df_Hmapped_distance_1si3['BB3_GSC1']
# BB3_GSC1_Hmapped_distance_1rpu = df_Hmapped_distance_1rpu['BB3_GSC1']


BB3_CSC1_Hmapped_distance_7w0f = df_Hmapped_distance_7w0f['BB3_CSC1']
BB3_CSC1_Hmapped_distance_6ra4 = df_Hmapped_distance_6ra4['BB3_CSC1']
BB3_CSC1_Hmapped_distance_6bjv = df_Hmapped_distance_6bjv['BB3_CSC1']
BB3_CSC1_Hmapped_distance_5n8l = df_Hmapped_distance_5n8l['BB3_CSC1']
BB3_CSC1_Hmapped_distance_4nh3 = df_Hmapped_distance_4nh3['BB3_CSC1']
BB3_CSC1_Hmapped_distance_4ngd = df_Hmapped_distance_4ngd['BB3_CSC1']
BB3_CSC1_Hmapped_distance_3cz3 = df_Hmapped_distance_3cz3['BB3_CSC1']
BB3_CSC1_Hmapped_distance_2f8s = df_Hmapped_distance_2f8s['BB3_CSC1']
BB3_CSC1_Hmapped_distance_1si3 = df_Hmapped_distance_1si3['BB3_CSC1']
# BB3_CSC1_Hmapped_distance_1rpu = df_Hmapped_distance_1rpu['BB3_CSC1']


ASC1_ASC2_Hmapped_distance_7w0f = df_Hmapped_distance_7w0f['ASC1_ASC2']
ASC1_ASC2_Hmapped_distance_6ra4 = df_Hmapped_distance_6ra4['ASC1_ASC2']
ASC1_ASC2_Hmapped_distance_6bjv = df_Hmapped_distance_6bjv['ASC1_ASC2']
ASC1_ASC2_Hmapped_distance_5n8l = df_Hmapped_distance_5n8l['ASC1_ASC2']
ASC1_ASC2_Hmapped_distance_4nh3 = df_Hmapped_distance_4nh3['ASC1_ASC2']
ASC1_ASC2_Hmapped_distance_4ngd = df_Hmapped_distance_4ngd['ASC1_ASC2']
ASC1_ASC2_Hmapped_distance_3cz3 = df_Hmapped_distance_3cz3['ASC1_ASC2']
ASC1_ASC2_Hmapped_distance_2f8s = df_Hmapped_distance_2f8s['ASC1_ASC2']
ASC1_ASC2_Hmapped_distance_1si3 = df_Hmapped_distance_1si3['ASC1_ASC2']
# ASC1_ASC2_Hmapped_distance_1rpu = df_Hmapped_distance_1rpu['ASC1_ASC2']

ASC2_ASC3_Hmapped_distance_7w0f = df_Hmapped_distance_7w0f['ASC2_ASC3']
ASC2_ASC3_Hmapped_distance_6ra4 = df_Hmapped_distance_6ra4['ASC2_ASC3']
ASC2_ASC3_Hmapped_distance_6bjv = df_Hmapped_distance_6bjv['ASC2_ASC3']
ASC2_ASC3_Hmapped_distance_5n8l = df_Hmapped_distance_5n8l['ASC2_ASC3']
ASC2_ASC3_Hmapped_distance_4nh3 = df_Hmapped_distance_4nh3['ASC2_ASC3']
ASC2_ASC3_Hmapped_distance_4ngd = df_Hmapped_distance_4ngd['ASC2_ASC3']
ASC2_ASC3_Hmapped_distance_3cz3 = df_Hmapped_distance_3cz3['ASC2_ASC3']
ASC2_ASC3_Hmapped_distance_2f8s = df_Hmapped_distance_2f8s['ASC2_ASC3']
ASC2_ASC3_Hmapped_distance_1si3 = df_Hmapped_distance_1si3['ASC2_ASC3']
# ASC2_ASC3_Hmapped_distance_1rpu = df_Hmapped_distance_1rpu['ASC2_ASC3']

ASC3_ASC4_Hmapped_distance_7w0f = df_Hmapped_distance_7w0f['ASC3_ASC4']
ASC3_ASC4_Hmapped_distance_6ra4 = df_Hmapped_distance_6ra4['ASC3_ASC4']
ASC3_ASC4_Hmapped_distance_6bjv = df_Hmapped_distance_6bjv['ASC3_ASC4']
ASC3_ASC4_Hmapped_distance_5n8l = df_Hmapped_distance_5n8l['ASC3_ASC4']
ASC3_ASC4_Hmapped_distance_4nh3 = df_Hmapped_distance_4nh3['ASC3_ASC4']
ASC3_ASC4_Hmapped_distance_4ngd = df_Hmapped_distance_4ngd['ASC3_ASC4']
ASC3_ASC4_Hmapped_distance_3cz3 = df_Hmapped_distance_3cz3['ASC3_ASC4']
ASC3_ASC4_Hmapped_distance_2f8s = df_Hmapped_distance_2f8s['ASC3_ASC4']
ASC3_ASC4_Hmapped_distance_1si3 = df_Hmapped_distance_1si3['ASC3_ASC4']
# ASC3_ASC4_Hmapped_distance_1rpu = df_Hmapped_distance_1rpu['ASC3_ASC4']

ASC4_ASC1_Hmapped_distance_7w0f = df_Hmapped_distance_7w0f['ASC4_ASC1']
ASC4_ASC1_Hmapped_distance_6ra4 = df_Hmapped_distance_6ra4['ASC4_ASC1']
ASC4_ASC1_Hmapped_distance_6bjv = df_Hmapped_distance_6bjv['ASC4_ASC1']
ASC4_ASC1_Hmapped_distance_5n8l = df_Hmapped_distance_5n8l['ASC4_ASC1']
ASC4_ASC1_Hmapped_distance_4nh3 = df_Hmapped_distance_4nh3['ASC4_ASC1']
ASC4_ASC1_Hmapped_distance_4ngd = df_Hmapped_distance_4ngd['ASC4_ASC1']
ASC4_ASC1_Hmapped_distance_3cz3 = df_Hmapped_distance_3cz3['ASC4_ASC1']
ASC4_ASC1_Hmapped_distance_2f8s = df_Hmapped_distance_2f8s['ASC4_ASC1']
ASC4_ASC1_Hmapped_distance_1si3 = df_Hmapped_distance_1si3['ASC4_ASC1']
# ASC4_ASC1_Hmapped_distance_1rpu = df_Hmapped_distance_1rpu['ASC4_ASC1']

ASC2_ASC4_Hmapped_distance_7w0f = df_Hmapped_distance_7w0f['ASC2_ASC4']
ASC2_ASC4_Hmapped_distance_6ra4 = df_Hmapped_distance_6ra4['ASC2_ASC4']
ASC2_ASC4_Hmapped_distance_6bjv = df_Hmapped_distance_6bjv['ASC2_ASC4']
ASC2_ASC4_Hmapped_distance_5n8l = df_Hmapped_distance_5n8l['ASC2_ASC4']
ASC2_ASC4_Hmapped_distance_4nh3 = df_Hmapped_distance_4nh3['ASC2_ASC4']
ASC2_ASC4_Hmapped_distance_4ngd = df_Hmapped_distance_4ngd['ASC2_ASC4']
ASC2_ASC4_Hmapped_distance_3cz3 = df_Hmapped_distance_3cz3['ASC2_ASC4']
ASC2_ASC4_Hmapped_distance_2f8s = df_Hmapped_distance_2f8s['ASC2_ASC4']
ASC2_ASC4_Hmapped_distance_1si3 = df_Hmapped_distance_1si3['ASC2_ASC4']
# ASC2_ASC4_Hmapped_distance_1rpu = df_Hmapped_distance_1rpu['ASC2_ASC4']


ASC1_ASC3_Hmapped_distance_7w0f = df_Hmapped_distance_7w0f['ASC1_ASC3']
ASC1_ASC3_Hmapped_distance_6ra4 = df_Hmapped_distance_6ra4['ASC1_ASC3']
ASC1_ASC3_Hmapped_distance_6bjv = df_Hmapped_distance_6bjv['ASC1_ASC3']
ASC1_ASC3_Hmapped_distance_5n8l = df_Hmapped_distance_5n8l['ASC1_ASC3']
ASC1_ASC3_Hmapped_distance_4nh3 = df_Hmapped_distance_4nh3['ASC1_ASC3']
ASC1_ASC3_Hmapped_distance_4ngd = df_Hmapped_distance_4ngd['ASC1_ASC3']
ASC1_ASC3_Hmapped_distance_3cz3 = df_Hmapped_distance_3cz3['ASC1_ASC3']
ASC1_ASC3_Hmapped_distance_2f8s = df_Hmapped_distance_2f8s['ASC1_ASC3']
ASC1_ASC3_Hmapped_distance_1si3 = df_Hmapped_distance_1si3['ASC1_ASC3']
# ASC1_ASC3_Hmapped_distance_1rpu = df_Hmapped_distance_1rpu['ASC1_ASC3']


GSC1_GSC2_Hmapped_distance_7w0f = df_Hmapped_distance_7w0f['GSC1_GSC2']
GSC1_GSC2_Hmapped_distance_6ra4 = df_Hmapped_distance_6ra4['GSC1_GSC2']
GSC1_GSC2_Hmapped_distance_6bjv = df_Hmapped_distance_6bjv['GSC1_GSC2']
GSC1_GSC2_Hmapped_distance_5n8l = df_Hmapped_distance_5n8l['GSC1_GSC2']
GSC1_GSC2_Hmapped_distance_4nh3 = df_Hmapped_distance_4nh3['GSC1_GSC2']
GSC1_GSC2_Hmapped_distance_4ngd = df_Hmapped_distance_4ngd['GSC1_GSC2']
GSC1_GSC2_Hmapped_distance_3cz3 = df_Hmapped_distance_3cz3['GSC1_GSC2']
GSC1_GSC2_Hmapped_distance_2f8s = df_Hmapped_distance_2f8s['GSC1_GSC2']
GSC1_GSC2_Hmapped_distance_1si3 = df_Hmapped_distance_1si3['GSC1_GSC2']
# GSC1_GSC2_Hmapped_distance_1rpu = df_Hmapped_distance_1rpu['GSC1_GSC2']


GSC2_GSC3_Hmapped_distance_7w0f = df_Hmapped_distance_7w0f['GSC2_GSC3']
GSC2_GSC3_Hmapped_distance_6ra4 = df_Hmapped_distance_6ra4['GSC2_GSC3']
GSC2_GSC3_Hmapped_distance_6bjv = df_Hmapped_distance_6bjv['GSC2_GSC3']
GSC2_GSC3_Hmapped_distance_5n8l = df_Hmapped_distance_5n8l['GSC2_GSC3']
GSC2_GSC3_Hmapped_distance_4nh3 = df_Hmapped_distance_4nh3['GSC2_GSC3']
GSC2_GSC3_Hmapped_distance_4ngd = df_Hmapped_distance_4ngd['GSC2_GSC3']
GSC2_GSC3_Hmapped_distance_3cz3 = df_Hmapped_distance_3cz3['GSC2_GSC3']
GSC2_GSC3_Hmapped_distance_2f8s = df_Hmapped_distance_2f8s['GSC2_GSC3']
GSC2_GSC3_Hmapped_distance_1si3 = df_Hmapped_distance_1si3['GSC2_GSC3']
# GSC2_GSC3_Hmapped_distance_1rpu = df_Hmapped_distance_1rpu['GSC2_GSC3']

GSC3_GSC4_Hmapped_distance_7w0f = df_Hmapped_distance_7w0f['GSC3_GSC4']
GSC3_GSC4_Hmapped_distance_6ra4 = df_Hmapped_distance_6ra4['GSC3_GSC4']
GSC3_GSC4_Hmapped_distance_6bjv = df_Hmapped_distance_6bjv['GSC3_GSC4']
GSC3_GSC4_Hmapped_distance_5n8l = df_Hmapped_distance_5n8l['GSC3_GSC4']
GSC3_GSC4_Hmapped_distance_4nh3 = df_Hmapped_distance_4nh3['GSC3_GSC4']
GSC3_GSC4_Hmapped_distance_4ngd = df_Hmapped_distance_4ngd['GSC3_GSC4']
GSC3_GSC4_Hmapped_distance_3cz3 = df_Hmapped_distance_3cz3['GSC3_GSC4']
GSC3_GSC4_Hmapped_distance_2f8s = df_Hmapped_distance_2f8s['GSC3_GSC4']
GSC3_GSC4_Hmapped_distance_1si3 = df_Hmapped_distance_1si3['GSC3_GSC4']
# GSC3_GSC4_Hmapped_distance_1rpu = df_Hmapped_distance_1rpu['GSC3_GSC4']

GSC4_GSC1_Hmapped_distance_7w0f = df_Hmapped_distance_7w0f['GSC4_GSC1']
GSC4_GSC1_Hmapped_distance_6ra4 = df_Hmapped_distance_6ra4['GSC4_GSC1']
GSC4_GSC1_Hmapped_distance_6bjv = df_Hmapped_distance_6bjv['GSC4_GSC1']
GSC4_GSC1_Hmapped_distance_5n8l = df_Hmapped_distance_5n8l['GSC4_GSC1']
GSC4_GSC1_Hmapped_distance_4nh3 = df_Hmapped_distance_4nh3['GSC4_GSC1']
GSC4_GSC1_Hmapped_distance_4ngd = df_Hmapped_distance_4ngd['GSC4_GSC1']
GSC4_GSC1_Hmapped_distance_3cz3 = df_Hmapped_distance_3cz3['GSC4_GSC1']
GSC4_GSC1_Hmapped_distance_2f8s = df_Hmapped_distance_2f8s['GSC4_GSC1']
GSC4_GSC1_Hmapped_distance_1si3 = df_Hmapped_distance_1si3['GSC4_GSC1']
# GSC4_GSC1_Hmapped_distance_1rpu = df_Hmapped_distance_1rpu['GSC4_GSC1']


GSC2_GSC4_Hmapped_distance_7w0f = df_Hmapped_distance_7w0f['GSC2_GSC4']
GSC2_GSC4_Hmapped_distance_6ra4 = df_Hmapped_distance_6ra4['GSC2_GSC4']
GSC2_GSC4_Hmapped_distance_6bjv = df_Hmapped_distance_6bjv['GSC2_GSC4']
GSC2_GSC4_Hmapped_distance_5n8l = df_Hmapped_distance_5n8l['GSC2_GSC4']
GSC2_GSC4_Hmapped_distance_4nh3 = df_Hmapped_distance_4nh3['GSC2_GSC4']
GSC2_GSC4_Hmapped_distance_4ngd = df_Hmapped_distance_4ngd['GSC2_GSC4']
GSC2_GSC4_Hmapped_distance_3cz3 = df_Hmapped_distance_3cz3['GSC2_GSC4']
GSC2_GSC4_Hmapped_distance_2f8s = df_Hmapped_distance_2f8s['GSC2_GSC4']
GSC2_GSC4_Hmapped_distance_1si3 = df_Hmapped_distance_1si3['GSC2_GSC4']
# GSC2_GSC4_Hmapped_distance_1rpu = df_Hmapped_distance_1rpu['GSC2_GSC4']


GSC1_GSC3_Hmapped_distance_7w0f = df_Hmapped_distance_7w0f['GSC1_GSC3']
GSC1_GSC3_Hmapped_distance_6ra4 = df_Hmapped_distance_6ra4['GSC1_GSC3']
GSC1_GSC3_Hmapped_distance_6bjv = df_Hmapped_distance_6bjv['GSC1_GSC3']
GSC1_GSC3_Hmapped_distance_5n8l = df_Hmapped_distance_5n8l['GSC1_GSC3']
GSC1_GSC3_Hmapped_distance_4nh3 = df_Hmapped_distance_4nh3['GSC1_GSC3']
GSC1_GSC3_Hmapped_distance_4ngd = df_Hmapped_distance_4ngd['GSC1_GSC3']
GSC1_GSC3_Hmapped_distance_3cz3 = df_Hmapped_distance_3cz3['GSC1_GSC3']
GSC1_GSC3_Hmapped_distance_2f8s = df_Hmapped_distance_2f8s['GSC1_GSC3']
GSC1_GSC3_Hmapped_distance_1si3 = df_Hmapped_distance_1si3['GSC1_GSC3']
# GSC1_GSC3_Hmapped_distance_1rpu = df_Hmapped_distance_1rpu['GSC1_GSC3']

CSC1_CSC2_Hmapped_distance_7w0f = df_Hmapped_distance_7w0f['CSC1_CSC2']
CSC1_CSC2_Hmapped_distance_6ra4 = df_Hmapped_distance_6ra4['CSC1_CSC2']
CSC1_CSC2_Hmapped_distance_6bjv = df_Hmapped_distance_6bjv['CSC1_CSC2']
CSC1_CSC2_Hmapped_distance_5n8l = df_Hmapped_distance_5n8l['CSC1_CSC2']
CSC1_CSC2_Hmapped_distance_4nh3 = df_Hmapped_distance_4nh3['CSC1_CSC2']
CSC1_CSC2_Hmapped_distance_4ngd = df_Hmapped_distance_4ngd['CSC1_CSC2']
CSC1_CSC2_Hmapped_distance_3cz3 = df_Hmapped_distance_3cz3['CSC1_CSC2']
CSC1_CSC2_Hmapped_distance_2f8s = df_Hmapped_distance_2f8s['CSC1_CSC2']
CSC1_CSC2_Hmapped_distance_1si3 = df_Hmapped_distance_1si3['CSC1_CSC2']
# CSC1_CSC2_Hmapped_distance_1rpu = df_Hmapped_distance_1rpu['CSC1_CSC2']


CSC2_CSC3_Hmapped_distance_7w0f = df_Hmapped_distance_7w0f['CSC2_CSC3']
CSC2_CSC3_Hmapped_distance_6ra4 = df_Hmapped_distance_6ra4['CSC2_CSC3']
CSC2_CSC3_Hmapped_distance_6bjv = df_Hmapped_distance_6bjv['CSC2_CSC3']
CSC2_CSC3_Hmapped_distance_5n8l = df_Hmapped_distance_5n8l['CSC2_CSC3']
CSC2_CSC3_Hmapped_distance_4nh3 = df_Hmapped_distance_4nh3['CSC2_CSC3']
CSC2_CSC3_Hmapped_distance_4ngd = df_Hmapped_distance_4ngd['CSC2_CSC3']
CSC2_CSC3_Hmapped_distance_3cz3 = df_Hmapped_distance_3cz3['CSC2_CSC3']
CSC2_CSC3_Hmapped_distance_2f8s = df_Hmapped_distance_2f8s['CSC2_CSC3']
CSC2_CSC3_Hmapped_distance_1si3 = df_Hmapped_distance_1si3['CSC2_CSC3']
# CSC2_CSC3_Hmapped_distance_1rpu = df_Hmapped_distance_1rpu['CSC2_CSC3']


CSC3_CSC1_Hmapped_distance_7w0f = df_Hmapped_distance_7w0f['CSC3_CSC1']
CSC3_CSC1_Hmapped_distance_6ra4 = df_Hmapped_distance_6ra4['CSC3_CSC1']
CSC3_CSC1_Hmapped_distance_6bjv = df_Hmapped_distance_6bjv['CSC3_CSC1']
CSC3_CSC1_Hmapped_distance_5n8l = df_Hmapped_distance_5n8l['CSC3_CSC1']
CSC3_CSC1_Hmapped_distance_4nh3 = df_Hmapped_distance_4nh3['CSC3_CSC1']
CSC3_CSC1_Hmapped_distance_4ngd = df_Hmapped_distance_4ngd['CSC3_CSC1']
CSC3_CSC1_Hmapped_distance_3cz3 = df_Hmapped_distance_3cz3['CSC3_CSC1']
CSC3_CSC1_Hmapped_distance_2f8s = df_Hmapped_distance_2f8s['CSC3_CSC1']
CSC3_CSC1_Hmapped_distance_1si3 = df_Hmapped_distance_1si3['CSC3_CSC1']
# CSC3_CSC1_Hmapped_distance_1rpu = df_Hmapped_distance_1rpu['CSC3_CSC1']


USC1_USC2_Hmapped_distance_7w0f = df_Hmapped_distance_7w0f['USC1_USC2']
USC1_USC2_Hmapped_distance_6ra4 = df_Hmapped_distance_6ra4['USC1_USC2']
USC1_USC2_Hmapped_distance_6bjv = df_Hmapped_distance_6bjv['USC1_USC2']
USC1_USC2_Hmapped_distance_5n8l = df_Hmapped_distance_5n8l['USC1_USC2']
USC1_USC2_Hmapped_distance_4nh3 = df_Hmapped_distance_4nh3['USC1_USC2']
USC1_USC2_Hmapped_distance_4ngd = df_Hmapped_distance_4ngd['USC1_USC2']
USC1_USC2_Hmapped_distance_3cz3 = df_Hmapped_distance_3cz3['USC1_USC2']
USC1_USC2_Hmapped_distance_2f8s = df_Hmapped_distance_2f8s['USC1_USC2']
USC1_USC2_Hmapped_distance_1si3 = df_Hmapped_distance_1si3['USC1_USC2']
# USC1_USC2_Hmapped_distance_1rpu = df_Hmapped_distance_1rpu['USC1_USC2']

USC2_USC3_Hmapped_distance_7w0f = df_Hmapped_distance_7w0f['USC2_USC3']
USC2_USC3_Hmapped_distance_6ra4 = df_Hmapped_distance_6ra4['USC2_USC3']
USC2_USC3_Hmapped_distance_6bjv = df_Hmapped_distance_6bjv['USC2_USC3']
USC2_USC3_Hmapped_distance_5n8l = df_Hmapped_distance_5n8l['USC2_USC3']
USC2_USC3_Hmapped_distance_4nh3 = df_Hmapped_distance_4nh3['USC2_USC3']
USC2_USC3_Hmapped_distance_4ngd = df_Hmapped_distance_4ngd['USC2_USC3']
USC2_USC3_Hmapped_distance_3cz3 = df_Hmapped_distance_3cz3['USC2_USC3']
USC2_USC3_Hmapped_distance_2f8s = df_Hmapped_distance_2f8s['USC2_USC3']
USC2_USC3_Hmapped_distance_1si3 = df_Hmapped_distance_1si3['USC2_USC3']
# USC2_USC3_Hmapped_distance_1rpu = df_Hmapped_distance_1rpu['USC2_USC3']

USC3_USC1_Hmapped_distance_7w0f = df_Hmapped_distance_7w0f['USC3_USC1']
USC3_USC1_Hmapped_distance_6ra4 = df_Hmapped_distance_6ra4['USC3_USC1']
USC3_USC1_Hmapped_distance_6bjv = df_Hmapped_distance_6bjv['USC3_USC1']
USC3_USC1_Hmapped_distance_5n8l = df_Hmapped_distance_5n8l['USC3_USC1']
USC3_USC1_Hmapped_distance_4nh3 = df_Hmapped_distance_4nh3['USC3_USC1']
USC3_USC1_Hmapped_distance_4ngd = df_Hmapped_distance_4ngd['USC3_USC1']
USC3_USC1_Hmapped_distance_3cz3 = df_Hmapped_distance_3cz3['USC3_USC1']
USC3_USC1_Hmapped_distance_2f8s = df_Hmapped_distance_2f8s['USC3_USC1']
USC3_USC1_Hmapped_distance_1si3 = df_Hmapped_distance_1si3['USC3_USC1']
# USC3_USC1_Hmapped_distance_1rpu = df_Hmapped_distance_1rpu['USC3_USC1']

# %%
# Density Plot and Histogram 

plt = sns.distplot(BB1_BB2_Hmapped_distance_7w0f, kde=True, 
            color = 'darkblue', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_Hmapped_distance_6ra4, kde=True, 
            color = 'green', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_Hmapped_distance_6bjv, kde=True, 
            color = 'grey', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_Hmapped_distance_5n8l, kde=True, 
            color = 'purple', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_Hmapped_distance_4nh3, kde=True, 
            color = 'red', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_Hmapped_distance_4ngd, kde=True, 
            color = 'pink', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_Hmapped_distance_3cz3, kde=True, 
            color = 'cyan', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_Hmapped_distance_2f8s, kde=True, 
            color = 'orange', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB1_BB2_Hmapped_distance_1si3, kde=True, 
            color = 'black', norm_hist=False,
             kde_kws={'linewidth': 1})
# plt = sns.distplot(BB1_BB2_Hmapped_distance_1rpu, kde=True, 
#             color = 'lavendar', norm_hist=False,
#              kde_kws={'linewidth': 1})

plt.set_xlabel('BB1_BB2_Hmapped_distance(nm)'+'\nMean: '+str("{:.2f}".format(BB1_BB2_Hmapped_distance.mean()))+", \
SD: "+str("{:.2f}".format(BB1_BB2_Hmapped_distance.std())))
# plt.xlim(0,1)
distance_dict['BB1_BB2'] = [str("{:.2f}".format(BB1_BB2_Hmapped_distance.mean())),str("{:.2f}".format(BB1_BB2_Hmapped_distance.std()))]
# distance_dict
plt.figure.savefig("BB1_BB2.png")
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Density Plot and Histogram of all arrival delays
# plt = sns.distplot(BB2_BB3_Hmapped_distance, kde=True, 
#             color = 'darkblue', norm_hist=True,
#              kde_kws={'linewidth': 4})
plt = sns.distplot(BB2_BB3_Hmapped_distance_7w0f, kde=True, 
            color = 'darkblue', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_Hmapped_distance_6ra4, kde=True, 
            color = 'green', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_Hmapped_distance_6bjv, kde=True, 
            color = 'grey', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_Hmapped_distance_5n8l, kde=True, 
            color = 'purple', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_Hmapped_distance_4nh3, kde=True, 
            color = 'red', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_Hmapped_distance_4ngd, kde=True, 
            color = 'pink', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_Hmapped_distance_3cz3, kde=True, 
            color = 'cyan', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_Hmapped_distance_2f8s, kde=True, 
            color = 'orange', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB2_BB3_Hmapped_distance_1si3, kde=True, 
            color = 'black', norm_hist=False,
             kde_kws={'linewidth': 1})
# plt = sns.distplot(BB1_BB2_Hmapped_distance_1rpu, kde=True, 
#             color = 'lavendar', norm_hist=False,
#              kde_kws={'linewidth': 1})


plt.set_xlabel('BB2_BB3_Hmapped_distance(nm)'+'\nMean: '+str("{:.2f}".format(BB2_BB3_Hmapped_distance.mean()))+", \
SD: "+str("{:.2f}".format(BB2_BB3_Hmapped_distance.std())))

distance_dict['BB2_BB3'] = [str("{:.2f}".format(BB2_BB3_Hmapped_distance.mean())),str("{:.2f}".format(BB2_BB3_Hmapped_distance.std()))]
plt.figure.savefig("BB2_BB3.png")
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Density Plot and Histogram of all arrival delays
plt = sns.distplot(BB3_ASC1_Hmapped_distance_7w0f, kde=True, 
            color = 'darkblue', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB3_ASC1_Hmapped_distance_6ra4, kde=True, 
            color = 'green', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB3_ASC1_Hmapped_distance_6bjv, kde=True, 
            color = 'grey', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB3_ASC1_Hmapped_distance_5n8l, kde=True, 
            color = 'purple', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB3_ASC1_Hmapped_distance_4nh3, kde=True, 
            color = 'red', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB3_ASC1_Hmapped_distance_4ngd, kde=True, 
            color = 'pink', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB3_ASC1_Hmapped_distance_3cz3, kde=True, 
            color = 'cyan', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB3_ASC1_Hmapped_distance_2f8s, kde=True, 
            color = 'orange', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB3_ASC1_Hmapped_distance_1si3, kde=True, 
            color = 'black', norm_hist=False,
             kde_kws={'linewidth': 1})
# plt = sns.distplot(BB1_BB2_Hmapped_distance_1rpu, kde=True, 
#             color = 'lavendar', norm_hist=False,
#              kde_kws={'linewidth': 1})


distance_dict['BB3_ASC1'] = [str("{:.2f}".format(BB3_ASC1_Hmapped_distance.mean())),str("{:.2f}".format(BB3_ASC1_Hmapped_distance.std()))]
plt.figure.savefig("BB3_ASC1.png")
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Density Plot and Histogram of all arrival delays
plt = sns.distplot(BB3_USC1_Hmapped_distance_7w0f, kde=True, 
            color = 'darkblue', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB3_USC1_Hmapped_distance_6ra4, kde=True, 
            color = 'green', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB3_USC1_Hmapped_distance_6bjv, kde=True, 
            color = 'grey', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB3_USC1_Hmapped_distance_5n8l, kde=True, 
            color = 'purple', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB3_USC1_Hmapped_distance_4nh3, kde=True, 
            color = 'red', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB3_USC1_Hmapped_distance_4ngd, kde=True, 
            color = 'pink', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB3_USC1_Hmapped_distance_3cz3, kde=True, 
            color = 'cyan', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB3_USC1_Hmapped_distance_2f8s, kde=True, 
            color = 'orange', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB3_USC1_Hmapped_distance_1si3, kde=True, 
            color = 'black', norm_hist=False,
             kde_kws={'linewidth': 1})
# plt = sns.distplot(BB1_BB2_Hmapped_distance_1rpu, kde=True, 
#             color = 'lavendar', norm_hist=False,
#              kde_kws={'linewidth': 1})



# plt = sns.distplot(BB3_USC1_Hmapped_distance, kde=True, 
#             color = 'darkblue', norm_hist=True,
#              kde_kws={'linewidth': 4})
# plt.set_xlabel('BB3_USC1_Hmapped_distance(nm)'+'\nMean: '+str("{:.2f}".format(BB3_USC1_Hmapped_distance.mean()))+", \
# SD: "+str("{:.2f}".format(BB3_USC1_Hmapped_distance.std())))

distance_dict['BB3_USC1'] = [str("{:.2f}".format(BB3_USC1_Hmapped_distance.mean())),str("{:.2f}".format(BB3_USC1_Hmapped_distance.std()))]
plt.figure.savefig("BB3_USC1.png")
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Density Plot and Histogram of all arrival delays
plt = sns.distplot(BB3_GSC1_Hmapped_distance_7w0f, kde=True, 
            color = 'darkblue', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB3_GSC1_Hmapped_distance_6ra4, kde=True, 
            color = 'green', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB3_GSC1_Hmapped_distance_6bjv, kde=True, 
            color = 'grey', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB3_GSC1_Hmapped_distance_5n8l, kde=True, 
            color = 'purple', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB3_GSC1_Hmapped_distance_4nh3, kde=True, 
            color = 'red', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB3_GSC1_Hmapped_distance_4ngd, kde=True, 
            color = 'pink', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB3_GSC1_Hmapped_distance_3cz3, kde=True, 
            color = 'cyan', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB3_GSC1_Hmapped_distance_2f8s, kde=True, 
            color = 'orange', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB3_GSC1_Hmapped_distance_1si3, kde=True, 
            color = 'black', norm_hist=False,
             kde_kws={'linewidth': 1})
# plt = sns.distplot(BB1_BB2_Hmapped_distance_1rpu, kde=True, 
#             color = 'lavendar', norm_hist=False,
#              kde_kws={'linewidth': 1})



plt = sns.distplot(BB3_GSC1_Hmapped_distance, kde=True, 
            color = 'darkblue', norm_hist=True,
             kde_kws={'linewidth': 4})
plt.set_xlabel('BB3_GSC1_Hmapped_distance(nm)'+'\nMean: '+str("{:.2f}".format(BB3_GSC1_Hmapped_distance.mean()))+", \
SD: "+str("{:.2f}".format(BB3_GSC1_Hmapped_distance.std())))

distance_dict['BB3_GSC1'] = [str("{:.2f}".format(BB3_GSC1_Hmapped_distance.mean())),str("{:.2f}".format(BB3_GSC1_Hmapped_distance.std()))]

plt.figure.savefig("BB3_GSC1.png")
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Density Plot and Histogram of all arrival delays
plt = sns.distplot(BB3_CSC1_Hmapped_distance_7w0f, kde=True, 
            color = 'darkblue', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB3_CSC1_Hmapped_distance_6ra4, kde=True, 
            color = 'green', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB3_CSC1_Hmapped_distance_6bjv, kde=True, 
            color = 'grey', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB3_CSC1_Hmapped_distance_5n8l, kde=True, 
            color = 'purple', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB3_CSC1_Hmapped_distance_4nh3, kde=True, 
            color = 'red', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB3_CSC1_Hmapped_distance_4ngd, kde=True, 
            color = 'pink', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB3_CSC1_Hmapped_distance_3cz3, kde=True, 
            color = 'cyan', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB3_CSC1_Hmapped_distance_2f8s, kde=True, 
            color = 'orange', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB3_CSC1_Hmapped_distance_1si3, kde=True, 
            color = 'black', norm_hist=False,
             kde_kws={'linewidth': 1})
# plt = sns.distplot(BB1_BB2_Hmapped_distance_1rpu, kde=True, 
#             color = 'lavendar', norm_hist=False,
#              kde_kws={'linewidth': 1})



# plt = sns.distplot(BB3_CSC1_Hmapped_distance, kde=True, 
#             color = 'darkblue', norm_hist=True,
#              kde_kws={'linewidth': 4})
# plt.set_xlabel('BB3_CSC1_Hmapped_distance(nm)'+'\nMean: '+str("{:.2f}".format(BB3_CSC1_Hmapped_distance.mean()))+", \
# SD: "+str("{:.2f}".format(BB3_CSC1_Hmapped_distance.std())))

distance_dict['BB3_CSC1'] = [str("{:.2f}".format(BB3_CSC1_Hmapped_distance.mean())),str("{:.2f}".format(BB3_CSC1_Hmapped_distance.std()))]

plt.figure.savefig("BB3_CSC1.png")
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Density Plot and Histogram of all arrival delays
plt = sns.distplot(ASC1_ASC2_Hmapped_distance_7w0f, kde=True, 
            color = 'darkblue', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC1_ASC2_Hmapped_distance_6ra4, kde=True, 
            color = 'green', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(BB3_ASC1_Hmapped_distance_6bjv, kde=True, 
            color = 'grey', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC1_ASC2_Hmapped_distance_5n8l, kde=True, 
            color = 'purple', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC1_ASC2_Hmapped_distance_4nh3, kde=True, 
            color = 'red', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC1_ASC2_Hmapped_distance_4ngd, kde=True, 
            color = 'pink', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC1_ASC2_Hmapped_distance_3cz3, kde=True, 
            color = 'cyan', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC1_ASC2_Hmapped_distance_2f8s, kde=True, 
            color = 'orange', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC1_ASC2_Hmapped_distance_1si3, kde=True, 
            color = 'black', norm_hist=False,
             kde_kws={'linewidth': 1})
# plt = sns.distplot(BB1_BB2_Hmapped_distance_1rpu, kde=True, 
#             color = 'lavendar', norm_hist=False,
#              kde_kws={'linewidth': 1})



# plt = sns.distplot(ASC1_ASC2_Hmapped_distance, kde=True, 
#             color = 'darkblue', norm_hist=True,
#              kde_kws={'linewidth': 4})
# plt.set_xlabel('ASC1_ASC2_Hmapped_distance(nm)'+'\nMean: '+str("{:.2f}".format(ASC1_ASC2_Hmapped_distance.mean()))+", \
# SD: "+str("{:.2f}".format(ASC1_ASC2_Hmapped_distance.std())))

distance_dict['ASC1_ASC2'] = [str("{:.2f}".format(ASC1_ASC2_Hmapped_distance.mean())),str("{:.2f}".format(ASC1_ASC2_Hmapped_distance.std()))]
plt.figure.savefig("ASC1_ASC2.png")
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Density Plot and Histogram of all arrival delays
plt = sns.distplot(ASC2_ASC3_Hmapped_distance_7w0f, kde=True, 
            color = 'darkblue', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC2_ASC3_Hmapped_distance_6ra4, kde=True, 
            color = 'green', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC2_ASC3_Hmapped_distance_6bjv, kde=True, 
            color = 'grey', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC2_ASC3_Hmapped_distance_5n8l, kde=True, 
            color = 'purple', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC2_ASC3_Hmapped_distance_4nh3, kde=True, 
            color = 'red', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC2_ASC3_Hmapped_distance_4ngd, kde=True, 
            color = 'pink', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC2_ASC3_Hmapped_distance_3cz3, kde=True, 
            color = 'cyan', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC2_ASC3_Hmapped_distance_2f8s, kde=True, 
            color = 'orange', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC2_ASC3_Hmapped_distance_1si3, kde=True, 
            color = 'black', norm_hist=False,
             kde_kws={'linewidth': 1})
# plt = sns.distplot(BB1_BB2_Hmapped_distance_1rpu, kde=True, 
#             color = 'lavendar', norm_hist=False,
#              kde_kws={'linewidth': 1})



# plt = sns.distplot(ASC2_ASC3_Hmapped_distance, kde=True, 
#             color = 'darkblue', norm_hist=True,
#              kde_kws={'linewidth': 4})
# plt.set_xlabel('ASC2_ASC3_Hmapped_distance(nm)'+'\nMean: '+str("{:.2f}".format(ASC2_ASC3_Hmapped_distance.mean()))+", \
# SD: "+str("{:.2f}".format(ASC2_ASC3_Hmapped_distance.std())))

distance_dict['ASC2_ASC3'] = [str("{:.2f}".format(ASC2_ASC3_Hmapped_distance.mean())),str("{:.2f}".format(ASC2_ASC3_Hmapped_distance.std()))]
plt.figure.savefig("ASC2_ASC3.png")
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Density Plot and Histogram of all arrival delays
plt = sns.distplot(ASC3_ASC4_Hmapped_distance_7w0f, kde=True, 
            color = 'darkblue', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC3_ASC4_Hmapped_distance_6ra4, kde=True, 
            color = 'green', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC3_ASC4_Hmapped_distance_6bjv, kde=True, 
            color = 'grey', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC3_ASC4_Hmapped_distance_5n8l, kde=True, 
            color = 'purple', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC3_ASC4_Hmapped_distance_4nh3, kde=True, 
            color = 'red', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC3_ASC4_Hmapped_distance_4ngd, kde=True, 
            color = 'pink', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC3_ASC4_Hmapped_distance_3cz3, kde=True, 
            color = 'cyan', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC3_ASC4_Hmapped_distance_2f8s, kde=True, 
            color = 'orange', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC3_ASC4_Hmapped_distance_1si3, kde=True, 
            color = 'black', norm_hist=False,
             kde_kws={'linewidth': 1})
# plt = sns.distplot(BB1_BB2_Hmapped_distance_1rpu, kde=True, 
#             color = 'lavendar', norm_hist=False,
#              kde_kws={'linewidth': 1})



# plt = sns.distplot(ASC3_ASC4_Hmapped_distance, kde=True, 
#             color = 'darkblue', norm_hist=True,
#              kde_kws={'linewidth': 4})
# plt.set_xlabel('ASC3_ASC4_Hmapped_distance(nm)'+'\nMean: '+str("{:.2f}".format(ASC3_ASC4_Hmapped_distance.mean()))+", \
# SD: "+str("{:.2f}".format(ASC3_ASC4_Hmapped_distance.std())))

distance_dict['ASC3_ASC4'] = [str("{:.2f}".format(ASC3_ASC4_Hmapped_distance.mean())),str("{:.2f}".format(ASC3_ASC4_Hmapped_distance.std()))]
plt.figure.savefig("ASC3_ASC4.png")
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Density Plot and Histogram of all arrival delays
plt = sns.distplot(ASC4_ASC1_Hmapped_distance_7w0f, kde=True, 
            color = 'darkblue', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC4_ASC1_Hmapped_distance_6ra4, kde=True, 
            color = 'green', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC4_ASC1_Hmapped_distance_6bjv, kde=True, 
            color = 'grey', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC4_ASC1_Hmapped_distance_5n8l, kde=True, 
            color = 'purple', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC4_ASC1_Hmapped_distance_4nh3, kde=True, 
            color = 'red', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC4_ASC1_Hmapped_distance_4ngd, kde=True, 
            color = 'pink', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC4_ASC1_Hmapped_distance_3cz3, kde=True, 
            color = 'cyan', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC4_ASC1_Hmapped_distance_2f8s, kde=True, 
            color = 'orange', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC4_ASC1_Hmapped_distance_1si3, kde=True, 
            color = 'black', norm_hist=False,
             kde_kws={'linewidth': 1})
# plt = sns.distplot(BB1_BB2_Hmapped_distance_1rpu, kde=True, 
#             color = 'lavendar', norm_hist=False,
#              kde_kws={'linewidth': 1})



# plt = sns.distplot(ASC4_ASC1_Hmapped_distance, kde=True, 
#             color = 'darkblue', norm_hist=True,
#              kde_kws={'linewidth': 4})
# plt.set_xlabel('ASC4_ASC1_Hmapped_distance(nm)'+'\nMean: '+str("{:.2f}".format(ASC4_ASC1_Hmapped_distance.mean()))+", \
# SD: "+str("{:.2f}".format(ASC4_ASC1_Hmapped_distance.std())))

distance_dict['ASC4_ASC1'] = [str("{:.2f}".format(ASC4_ASC1_Hmapped_distance.mean())),str("{:.2f}".format(ASC4_ASC1_Hmapped_distance.std()))]
plt.figure.savefig("ASC4_ASC1.png")
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Density Plot and Histogram of all arrival delays
plt = sns.distplot(ASC2_ASC4_Hmapped_distance_7w0f, kde=True, 
            color = 'darkblue', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC2_ASC4_Hmapped_distance_6ra4, kde=True, 
            color = 'green', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC2_ASC4_Hmapped_distance_6bjv, kde=True, 
            color = 'grey', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC2_ASC4_Hmapped_distance_5n8l, kde=True, 
            color = 'purple', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC2_ASC4_Hmapped_distance_4nh3, kde=True, 
            color = 'red', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC2_ASC4_Hmapped_distance_4ngd, kde=True, 
            color = 'pink', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC2_ASC4_Hmapped_distance_3cz3, kde=True, 
            color = 'cyan', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC2_ASC4_Hmapped_distance_2f8s, kde=True, 
            color = 'orange', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC2_ASC4_Hmapped_distance_1si3, kde=True, 
            color = 'black', norm_hist=False,
             kde_kws={'linewidth': 1})
# plt = sns.distplot(BB1_BB2_Hmapped_distance_1rpu, kde=True, 
#             color = 'lavendar', norm_hist=False,
#              kde_kws={'linewidth': 1})



# plt = sns.distplot(ASC2_ASC4_Hmapped_distance, kde=True, 
#             color = 'darkblue', norm_hist=True,
#              kde_kws={'linewidth': 4})
# plt.set_xlabel('ASC2_ASC4_Hmapped_distance(nm)'+'\nMean: '+str("{:.2f}".format(ASC2_ASC4_Hmapped_distance.mean()))+", \
# SD: "+str("{:.2f}".format(ASC2_ASC4_Hmapped_distance.std())))

distance_dict['ASC2_ASC4'] = [str("{:.2f}".format(ASC2_ASC4_Hmapped_distance.mean())),str("{:.2f}".format(ASC2_ASC4_Hmapped_distance.std()))]
plt.figure.savefig("ASC2_ASC4.png")
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Density Plot and Histogram of all arrival delays
plt = sns.distplot(ASC1_ASC3_Hmapped_distance_7w0f, kde=True, 
            color = 'darkblue', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC1_ASC3_Hmapped_distance_6ra4, kde=True, 
            color = 'green', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC1_ASC3_Hmapped_distance_6bjv, kde=True, 
            color = 'grey', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC1_ASC3_Hmapped_distance_5n8l, kde=True, 
            color = 'purple', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC1_ASC3_Hmapped_distance_4nh3, kde=True, 
            color = 'red', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC1_ASC3_Hmapped_distance_4ngd, kde=True, 
            color = 'pink', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC1_ASC3_Hmapped_distance_3cz3, kde=True, 
            color = 'cyan', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC1_ASC3_Hmapped_distance_2f8s, kde=True, 
            color = 'orange', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(ASC1_ASC3_Hmapped_distance_1si3, kde=True, 
            color = 'black', norm_hist=False,
             kde_kws={'linewidth': 1})
# plt = sns.distplot(BB1_BB2_Hmapped_distance_1rpu, kde=True, 
#             color = 'lavendar', norm_hist=False,
#              kde_kws={'linewidth': 1})



# plt = sns.distplot(ASC1_ASC3_Hmapped_distance, kde=True, 
#             color = 'darkblue', norm_hist=True,
#              kde_kws={'linewidth': 4})
# plt.set_xlabel('ASC1_ASC3_Hmapped_distance(nm)'+'\nMean: '+str("{:.2f}".format(ASC1_ASC3_Hmapped_distance.mean()))+", \
# SD: "+str("{:.2f}".format(ASC1_ASC3_Hmapped_distance.std())))

distance_dict['ASC1_ASC3'] = [str("{:.2f}".format(ASC1_ASC3_Hmapped_distance.mean())),str("{:.2f}".format(ASC1_ASC3_Hmapped_distance.std()))]

plt.figure.savefig("ASC1_ASC3.png")
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Density Plot and Histogram of all arrival delays
plt = sns.distplot(GSC1_GSC2_Hmapped_distance_7w0f, kde=True, 
            color = 'darkblue', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC1_GSC2_Hmapped_distance_6ra4, kde=True, 
            color = 'green', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC1_GSC2_Hmapped_distance_6bjv, kde=True, 
            color = 'grey', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC1_GSC2_Hmapped_distance_5n8l, kde=True, 
            color = 'purple', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC1_GSC2_Hmapped_distance_4nh3, kde=True, 
            color = 'red', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC1_GSC2_Hmapped_distance_4ngd, kde=True, 
            color = 'pink', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC1_GSC2_Hmapped_distance_3cz3, kde=True, 
            color = 'cyan', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC1_GSC2_Hmapped_distance_2f8s, kde=True, 
            color = 'orange', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC1_GSC2_Hmapped_distance_1si3, kde=True, 
            color = 'black', norm_hist=False,
             kde_kws={'linewidth': 1})
# plt = sns.distplot(BB1_BB2_Hmapped_distance_1rpu, kde=True, 
#             color = 'lavendar', norm_hist=False,
#              kde_kws={'linewidth': 1})



# plt = sns.distplot(GSC1_GSC2_Hmapped_distance, kde=True, 
#             color = 'darkblue', norm_hist=True,
#              kde_kws={'linewidth': 4})
# plt.set_xlabel('GSC1_GSC2_Hmapped_distance(nm)'+'\nMean: '+str("{:.2f}".format(GSC1_GSC2_Hmapped_distance.mean()))+", \
# SD: "+str("{:.2f}".format(GSC1_GSC2_Hmapped_distance.std())))

distance_dict['GSC1_GSC2'] = [str("{:.2f}".format(GSC1_GSC2_Hmapped_distance.mean())),str("{:.2f}".format(GSC1_GSC2_Hmapped_distance.std()))]
plt.figure.savefig("GSC1_GSC2.png")
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Density Plot and Histogram of all arrival delays
plt = sns.distplot(GSC2_GSC3_Hmapped_distance_7w0f, kde=True, 
            color = 'darkblue', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC2_GSC3_Hmapped_distance_6ra4, kde=True, 
            color = 'green', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC2_GSC3_Hmapped_distance_6bjv, kde=True, 
            color = 'grey', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC2_GSC3_Hmapped_distance_5n8l, kde=True, 
            color = 'purple', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC2_GSC3_Hmapped_distance_4nh3, kde=True, 
            color = 'red', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC2_GSC3_Hmapped_distance_4ngd, kde=True, 
            color = 'pink', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC2_GSC3_Hmapped_distance_3cz3, kde=True, 
            color = 'cyan', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC2_GSC3_Hmapped_distance_2f8s, kde=True, 
            color = 'orange', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC2_GSC3_Hmapped_distance_1si3, kde=True, 
            color = 'black', norm_hist=False,
             kde_kws={'linewidth': 1})
# plt = sns.distplot(BB1_BB2_Hmapped_distance_1rpu, kde=True, 
#             color = 'lavendar', norm_hist=False,
#              kde_kws={'linewidth': 1})



# plt = sns.distplot(GSC2_GSC3_Hmapped_distance, kde=True, 
#             color = 'darkblue', norm_hist=True,
#              kde_kws={'linewidth': 4})
# plt.set_xlabel('GSC2_GSC3_Hmapped_distance(nm)'+'\nMean: '+str("{:.2f}".format(GSC2_GSC3_Hmapped_distance.mean()))+", \
# SD: "+str("{:.2f}".format(GSC2_GSC3_Hmapped_distance.std())))

distance_dict['GSC2_GSC3'] = [str("{:.2f}".format(GSC2_GSC3_Hmapped_distance.mean())),str("{:.2f}".format(GSC2_GSC3_Hmapped_distance.std()))]

plt.figure.savefig("GSC2_GSC3.png")
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Density Plot and Histogram of all arrival delays
plt = sns.distplot(GSC3_GSC4_Hmapped_distance_7w0f, kde=True, 
            color = 'darkblue', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC3_GSC4_Hmapped_distance_6ra4, kde=True, 
            color = 'green', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC3_GSC4_Hmapped_distance_6bjv, kde=True, 
            color = 'grey', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC3_GSC4_Hmapped_distance_5n8l, kde=True, 
            color = 'purple', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC3_GSC4_Hmapped_distance_4nh3, kde=True, 
            color = 'red', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC3_GSC4_Hmapped_distance_4ngd, kde=True, 
            color = 'pink', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC3_GSC4_Hmapped_distance_3cz3, kde=True, 
            color = 'cyan', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC3_GSC4_Hmapped_distance_2f8s, kde=True, 
            color = 'orange', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC3_GSC4_Hmapped_distance_1si3, kde=True, 
            color = 'black', norm_hist=False,
             kde_kws={'linewidth': 1})
# plt = sns.distplot(BB1_BB2_Hmapped_distance_1rpu, kde=True, 
#             color = 'lavendar', norm_hist=False,
#              kde_kws={'linewidth': 1})



# plt = sns.distplot(GSC3_GSC4_Hmapped_distance, kde=True, 
#             color = 'darkblue', norm_hist=True,
#              kde_kws={'linewidth': 4})
# plt.set_xlabel('GSC3_GSC4_Hmapped_distance(nm)'+'\nMean: '+str("{:.2f}".format(GSC3_GSC4_Hmapped_distance.mean()))+", \
# SD: "+str("{:.2f}".format(GSC3_GSC4_Hmapped_distance.std())))

distance_dict['GSC3_GSC4'] = [str("{:.2f}".format(GSC3_GSC4_Hmapped_distance.mean())),str("{:.2f}".format(GSC3_GSC4_Hmapped_distance.std()))]
plt.figure.savefig("GSC3_GSC4.png")
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Density Plot and Histogram of all arrival delays
plt = sns.distplot(GSC4_GSC1_Hmapped_distance_7w0f, kde=True, 
            color = 'darkblue', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC4_GSC1_Hmapped_distance_6ra4, kde=True, 
            color = 'green', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC4_GSC1_Hmapped_distance_6bjv, kde=True, 
            color = 'grey', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC4_GSC1_Hmapped_distance_5n8l, kde=True, 
            color = 'purple', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC4_GSC1_Hmapped_distance_4nh3, kde=True, 
            color = 'red', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC4_GSC1_Hmapped_distance_4ngd, kde=True, 
            color = 'pink', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC4_GSC1_Hmapped_distance_3cz3, kde=True, 
            color = 'cyan', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC4_GSC1_Hmapped_distance_2f8s, kde=True, 
            color = 'orange', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC4_GSC1_Hmapped_distance_1si3, kde=True, 
            color = 'black', norm_hist=False,
             kde_kws={'linewidth': 1})
# plt = sns.distplot(BB1_BB2_Hmapped_distance_1rpu, kde=True, 
#             color = 'lavendar', norm_hist=False,
#              kde_kws={'linewidth': 1})



# plt = sns.distplot(GSC4_GSC1_Hmapped_distance, kde=True, 
#             color = 'darkblue', norm_hist=True,
#              kde_kws={'linewidth': 4})
# plt.set_xlabel('GSC4_GSC1_Hmapped_distance(nm)'+'\nMean: '+str("{:.2f}".format(GSC4_GSC1_Hmapped_distance.mean()))+", \
# SD: "+str("{:.2f}".format(GSC4_GSC1_Hmapped_distance.std())))

distance_dict['GSC4_GSC1'] = [str("{:.2f}".format(GSC4_GSC1_Hmapped_distance.mean())),str("{:.2f}".format(GSC4_GSC1_Hmapped_distance.std()))]
plt.figure.savefig("GSC4_GSC1.png")
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Density Plot and Histogram of all arrival delays
plt = sns.distplot(GSC2_GSC4_Hmapped_distance_7w0f, kde=True, 
            color = 'darkblue', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC2_GSC4_Hmapped_distance_6ra4, kde=True, 
            color = 'green', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC2_GSC4_Hmapped_distance_6bjv, kde=True, 
            color = 'grey', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC2_GSC4_Hmapped_distance_5n8l, kde=True, 
            color = 'purple', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC2_GSC4_Hmapped_distance_4nh3, kde=True, 
            color = 'red', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC2_GSC4_Hmapped_distance_4ngd, kde=True, 
            color = 'pink', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC2_GSC4_Hmapped_distance_3cz3, kde=True, 
            color = 'cyan', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC2_GSC4_Hmapped_distance_2f8s, kde=True, 
            color = 'orange', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC2_GSC4_Hmapped_distance_1si3, kde=True, 
            color = 'black', norm_hist=False,
             kde_kws={'linewidth': 1})
# plt = sns.distplot(BB1_BB2_Hmapped_distance_1rpu, kde=True, 
#             color = 'lavendar', norm_hist=False,
#              kde_kws={'linewidth': 1})



# plt = sns.distplot(GSC2_GSC4_Hmapped_distance, kde=True, 
#             color = 'darkblue', norm_hist=True,
#              kde_kws={'linewidth': 4})
# plt.set_xlabel('GSC2_GSC4_Hmapped_distance(nm)'+'\nMean: '+str("{:.2f}".format(GSC2_GSC4_Hmapped_distance.mean()))+", \
# SD: "+str("{:.2f}".format(GSC2_GSC4_Hmapped_distance.std())))

distance_dict['GSC2_GSC4'] = [str("{:.2f}".format(GSC2_GSC4_Hmapped_distance.mean())),str("{:.2f}".format(GSC2_GSC4_Hmapped_distance.std()))]

plt.figure.savefig("GSC2_GSC4.png")
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Density Plot and Histogram of all arrival delays
plt = sns.distplot(GSC1_GSC3_Hmapped_distance_7w0f, kde=True, 
            color = 'darkblue', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC1_GSC3_Hmapped_distance_6ra4, kde=True, 
            color = 'green', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC1_GSC3_Hmapped_distance_6bjv, kde=True, 
            color = 'grey', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC1_GSC3_Hmapped_distance_5n8l, kde=True, 
            color = 'purple', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC1_GSC3_Hmapped_distance_4nh3, kde=True, 
            color = 'red', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC1_GSC3_Hmapped_distance_4ngd, kde=True, 
            color = 'pink', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC1_GSC3_Hmapped_distance_3cz3, kde=True, 
            color = 'cyan', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC1_GSC3_Hmapped_distance_2f8s, kde=True, 
            color = 'orange', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(GSC1_GSC3_Hmapped_distance_1si3, kde=True, 
            color = 'black', norm_hist=False,
             kde_kws={'linewidth': 1})
# plt = sns.distplot(BB1_BB2_Hmapped_distance_1rpu, kde=True, 
#             color = 'lavendar', norm_hist=False,
#              kde_kws={'linewidth': 1})



# plt = sns.distplot(GSC1_GSC3_Hmapped_distance, kde=True, 
#             color = 'darkblue', norm_hist=True,
#              kde_kws={'linewidth': 4})
# plt.set_xlabel('GSC1_GSC3_Hmapped_distance(nm)'+'\nMean: '+str("{:.2f}".format(GSC1_GSC3_Hmapped_distance.mean()))+", \
# SD: "+str("{:.2f}".format(GSC1_GSC3_Hmapped_distance.std())))

distance_dict['GSC1_GSC3'] = [str("{:.2f}".format(GSC1_GSC3_Hmapped_distance.mean())),str("{:.2f}".format(GSC1_GSC3_Hmapped_distance.std()))]
plt.figure.savefig("GSC1_GSC3.png")
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Density Plot and Histogram of all arrival delays
plt = sns.distplot(CSC1_CSC2_Hmapped_distance_7w0f, kde=True, 
            color = 'darkblue', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(CSC1_CSC2_Hmapped_distance_6ra4, kde=True, 
            color = 'green', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(CSC1_CSC2_Hmapped_distance_6bjv, kde=True, 
            color = 'grey', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(CSC1_CSC2_Hmapped_distance_5n8l, kde=True, 
            color = 'purple', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(CSC1_CSC2_Hmapped_distance_4nh3, kde=True, 
            color = 'red', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(CSC1_CSC2_Hmapped_distance_4ngd, kde=True, 
            color = 'pink', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(CSC1_CSC2_Hmapped_distance_3cz3, kde=True, 
            color = 'cyan', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(CSC1_CSC2_Hmapped_distance_2f8s, kde=True, 
            color = 'orange', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(CSC1_CSC2_Hmapped_distance_1si3, kde=True, 
            color = 'black', norm_hist=False,
             kde_kws={'linewidth': 1})
# plt = sns.distplot(BB1_BB2_Hmapped_distance_1rpu, kde=True, 
#             color = 'lavendar', norm_hist=False,
#              kde_kws={'linewidth': 1})



# plt = sns.distplot(CSC1_CSC2_Hmapped_distance, kde=True, 
#             color = 'darkblue', norm_hist=True,
#              kde_kws={'linewidth': 4})
# plt.set_xlabel('CSC1_CSC2_Hmapped_distance(nm)'+'\nMean: '+str("{:.2f}".format(CSC1_CSC2_Hmapped_distance.mean()))+", \
# SD: "+str("{:.2f}".format(CSC1_CSC2_Hmapped_distance.std())))

distance_dict['CSC1_CSC2'] = [str("{:.2f}".format(CSC1_CSC2_Hmapped_distance.mean())),str("{:.2f}".format(CSC1_CSC2_Hmapped_distance.std()))]
plt.figure.savefig("CSC1_CSC2.png")
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Density Plot and Histogram of all arrival delays
plt = sns.distplot(CSC2_CSC3_Hmapped_distance_7w0f, kde=True, 
            color = 'darkblue', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(CSC2_CSC3_Hmapped_distance_6ra4, kde=True, 
            color = 'green', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(CSC2_CSC3_Hmapped_distance_6bjv, kde=True, 
            color = 'grey', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(CSC2_CSC3_Hmapped_distance_5n8l, kde=True, 
            color = 'purple', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(CSC2_CSC3_Hmapped_distance_4nh3, kde=True, 
            color = 'red', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(CSC2_CSC3_Hmapped_distance_4ngd, kde=True, 
            color = 'pink', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(CSC2_CSC3_Hmapped_distance_3cz3, kde=True, 
            color = 'cyan', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(CSC2_CSC3_Hmapped_distance_2f8s, kde=True, 
            color = 'orange', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(CSC2_CSC3_Hmapped_distance_1si3, kde=True, 
            color = 'black', norm_hist=False,
             kde_kws={'linewidth': 1})
# plt = sns.distplot(BB1_BB2_Hmapped_distance_1rpu, kde=True, 
#             color = 'lavendar', norm_hist=False,
#              kde_kws={'linewidth': 1})



# plt = sns.distplot(CSC2_CSC3_Hmapped_distance, kde=True, 
#             color = 'darkblue', norm_hist=True,
#              kde_kws={'linewidth': 4})
# plt.set_xlabel('CSC2_CSC3_Hmapped_distance(nm)'+'\nMean: '+str("{:.2f}".format(CSC2_CSC3_Hmapped_distance.mean()))+", \
# SD: "+str("{:.2f}".format(CSC2_CSC3_Hmapped_distance.std())))

distance_dict['CSC2_CSC3'] = [str("{:.2f}".format(CSC2_CSC3_Hmapped_distance.mean())),str("{:.2f}".format(CSC2_CSC3_Hmapped_distance.std()))]
plt.figure.savefig("CSC2_CSC3.png")
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Density Plot and Histogram of all arrival delays
plt = sns.distplot(CSC3_CSC1_Hmapped_distance_7w0f, kde=True, 
            color = 'darkblue', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(CSC3_CSC1_Hmapped_distance_6ra4, kde=True, 
            color = 'green', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(CSC3_CSC1_Hmapped_distance_6bjv, kde=True, 
            color = 'grey', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(CSC3_CSC1_Hmapped_distance_5n8l, kde=True, 
            color = 'purple', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(CSC3_CSC1_Hmapped_distance_4nh3, kde=True, 
            color = 'red', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(CSC3_CSC1_Hmapped_distance_4ngd, kde=True, 
            color = 'pink', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(CSC3_CSC1_Hmapped_distance_3cz3, kde=True, 
            color = 'cyan', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(CSC3_CSC1_Hmapped_distance_2f8s, kde=True, 
            color = 'orange', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(CSC3_CSC1_Hmapped_distance_1si3, kde=True, 
            color = 'black', norm_hist=False,
             kde_kws={'linewidth': 1})
# plt = sns.distplot(BB1_BB2_Hmapped_distance_1rpu, kde=True, 
#             color = 'lavendar', norm_hist=False,
#              kde_kws={'linewidth': 1})



# plt = sns.distplot(CSC3_CSC1_Hmapped_distance, kde=True, 
#             color = 'darkblue', norm_hist=True,
#              kde_kws={'linewidth': 4})
# plt.set_xlabel('CSC3_CSC1_Hmapped_distance(nm)'+'\nMean: '+str("{:.2f}".format(CSC3_CSC1_Hmapped_distance.mean()))+", \
# SD: "+str("{:.2f}".format(CSC3_CSC1_Hmapped_distance.std())))

distance_dict['CSC3_CSC1'] = [str("{:.2f}".format(CSC3_CSC1_Hmapped_distance.mean())),str("{:.2f}".format(CSC3_CSC1_Hmapped_distance.std()))]
plt.figure.savefig("CSC3_CSC1.png")
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Density Plot and Histogram of all arrival delays
plt = sns.distplot(USC1_USC2_Hmapped_distance_7w0f, kde=True, 
            color = 'darkblue', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(USC1_USC2_Hmapped_distance_6ra4, kde=True, 
            color = 'green', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(USC1_USC2_Hmapped_distance_6bjv, kde=True, 
            color = 'grey', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(USC1_USC2_Hmapped_distance_5n8l, kde=True, 
            color = 'purple', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(USC1_USC2_Hmapped_distance_4nh3, kde=True, 
            color = 'red', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(USC1_USC2_Hmapped_distance_4ngd, kde=True, 
            color = 'pink', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(USC1_USC2_Hmapped_distance_3cz3, kde=True, 
            color = 'cyan', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(USC1_USC2_Hmapped_distance_2f8s, kde=True, 
            color = 'orange', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(USC1_USC2_Hmapped_distance_1si3, kde=True, 
            color = 'black', norm_hist=False,
             kde_kws={'linewidth': 1})
# plt = sns.distplot(BB1_BB2_Hmapped_distance_1rpu, kde=True, 
#             color = 'lavendar', norm_hist=False,
#              kde_kws={'linewidth': 1})



# plt = sns.distplot(USC1_USC2_Hmapped_distance, kde=True, 
#             color = 'darkblue', norm_hist=True,
#              kde_kws={'linewidth': 4})
# plt.set_xlabel('USC1_USC2_Hmapped_distance(nm)'+'\nMean: '+str("{:.2f}".format(USC1_USC2_Hmapped_distance.mean()))+", \
# SD: "+str("{:.2f}".format(USC1_USC2_Hmapped_distance.std())))

distance_dict['USC1_USC2'] = [str("{:.2f}".format(USC1_USC2_Hmapped_distance.mean())),str("{:.2f}".format(USC1_USC2_Hmapped_distance.std()))]
plt.figure.savefig("USC1_USC2.png")
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Density Plot and Histogram of all arrival delays
plt = sns.distplot(USC2_USC3_Hmapped_distance_7w0f, kde=True, 
            color = 'darkblue', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(USC2_USC3_Hmapped_distance_6ra4, kde=True, 
            color = 'green', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(USC2_USC3_Hmapped_distance_6bjv, kde=True, 
            color = 'grey', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(USC2_USC3_Hmapped_distance_5n8l, kde=True, 
            color = 'purple', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(USC2_USC3_Hmapped_distance_4nh3, kde=True, 
            color = 'red', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(USC2_USC3_Hmapped_distance_4ngd, kde=True, 
            color = 'pink', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(USC2_USC3_Hmapped_distance_3cz3, kde=True, 
            color = 'cyan', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(USC2_USC3_Hmapped_distance_2f8s, kde=True, 
            color = 'orange', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(USC2_USC3_Hmapped_distance_1si3, kde=True, 
            color = 'black', norm_hist=False,
             kde_kws={'linewidth': 1})
# plt = sns.distplot(BB1_BB2_Hmapped_distance_1rpu, kde=True, 
#             color = 'lavendar', norm_hist=False,
#              kde_kws={'linewidth': 1})



# plt = sns.distplot(USC2_USC3_Hmapped_distance, kde=True, 
#             color = 'darkblue', norm_hist=True,
#              kde_kws={'linewidth': 4})
# plt.set_xlabel('USC2_USC3_Hmapped_distance(nm)'+'\nMean: '+str("{:.2f}".format(USC2_USC3_Hmapped_distance.mean()))+", \
# SD: "+str("{:.2f}".format(USC2_USC3_Hmapped_distance.std())))

distance_dict['USC2_USC3'] = [str("{:.2f}".format(USC2_USC3_Hmapped_distance.mean())),str("{:.2f}".format(USC2_USC3_Hmapped_distance.std()))]

plt.figure.savefig("USC2_USC3.png")
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Density Plot and Histogram of all arrival delays

plt = sns.distplot(USC3_USC1_Hmapped_distance_7w0f, kde=True, 
            color = 'darkblue', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(USC3_USC1_Hmapped_distance_6ra4, kde=True, 
            color = 'green', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(USC3_USC1_Hmapped_distance_6bjv, kde=True, 
            color = 'grey', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(USC3_USC1_Hmapped_distance_5n8l, kde=True, 
            color = 'purple', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(USC3_USC1_Hmapped_distance_4nh3, kde=True, 
            color = 'red', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(USC3_USC1_Hmapped_distance_4ngd, kde=True, 
            color = 'pink', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(USC3_USC1_Hmapped_distance_3cz3, kde=True, 
            color = 'cyan', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(USC3_USC1_Hmapped_distance_2f8s, kde=True, 
            color = 'orange', norm_hist=False,
             kde_kws={'linewidth': 1})
plt = sns.distplot(USC3_USC1_Hmapped_distance_1si3, kde=True, 
            color = 'black', norm_hist=False,
             kde_kws={'linewidth': 1})
# plt = sns.distplot(BB1_BB2_Hmapped_distance_1rpu, kde=True, 
#             color = 'lavendar', norm_hist=False,
#              kde_kws={'linewidth': 1})



# plt = sns.distplot(USC3_USC1_Hmapped_distance, kde=True, 
#             color = 'darkblue', norm_hist=True,
#              kde_kws={'linewidth': 4})
# plt.set_xlabel('USC3_USC1_Hmapped_distance(nm)'+'\nMean: '+str("{:.2f}".format(USC3_USC1_Hmapped_distance.mean()))+", \
# SD: "+str("{:.2f}".format(USC3_USC1_Hmapped_distance.std())))

distance_dict['USC3_USC1'] = [str("{:.2f}".format(USC3_USC1_Hmapped_distance.mean())),str("{:.2f}".format(USC3_USC1_Hmapped_distance.std()))]
plt.figure.savefig("USC3_USC1.png")
# Out:
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/subhasree/.local/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
distance_dict
# Out:
# {'BB1_BB2': ['0.40', '0.01'],
#  'BB2_BB3': ['0.24', '0.00'],
#  'BB3_ASC1': ['0.34', '0.01'],
#  'ASC2_ASC4': ['0.33', '0.01'],
#  'ASC1_ASC3': ['0.34', '0.01'],
#  'ASC1_ASC2': ['0.23', '0.01'],
#  'ASC2_ASC3': ['0.27', '0.01'],
#  'ASC3_ASC4': ['0.29', '0.01'],
#  'ASC4_ASC1': ['0.16', '0.00'],
#  'BB3_USC1': ['0.33', '0.00'],
#  'USC1_USC2': ['0.22', '0.00'],
#  'USC2_USC3': ['0.27', '0.00'],
#  'USC3_USC1': ['0.21', '0.00'],
#  'BB3_GSC1': ['0.34', '0.01'],
#  'GSC2_GSC4': ['0.39', '0.00'],
#  'GSC1_GSC3': ['0.34', '0.00'],
#  'GSC1_GSC2': ['0.30', '0.00'],
#  'GSC2_GSC3': ['0.29', '0.00'],
#  'GSC3_GSC4': ['0.29', '0.00'],
#  'GSC4_GSC1': ['0.16', '0.00'],
#  'BB3_CSC1': ['0.33', '0.01'],
#  'CSC1_CSC2': ['0.22', '0.00'],
#  'CSC2_CSC3': ['0.29', '0.00'],
#  'CSC3_CSC1': ['0.27', '0.00']}
