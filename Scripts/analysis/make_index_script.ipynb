# %%
path = "/home/subhasree/IISC_Bangalore/My_PhD_Studies/Lab_work/CG_Models/PDB_files/mirna_pdb/"
filename = "3a6p_CG_2.gro"

# %%
 with open(path+filename) as aa_f:
            lines = aa_f.readlines()
            print(lines)
            lines.pop(0)
            lines.pop(0)
            lines.pop(-1)
# Out:
# ['Georgetown Riga Oslo Madrid Amsterdam Chisinau Stockholm\n', '  296\n', '    1G      BB2    1   2.638   7.610   1.545\n', '    1G      BB3    2   2.369   7.615   1.513\n', '    1G     GSC1    3   2.414   7.814   1.772\n', '    1G     GSC2    4   2.160   7.889   1.913\n', '    1G     GSC3    5   2.345   8.111   1.939\n', '    1G     GSC4    6   2.519   7.931   1.780\n', '    2G      BB1    7   2.399   7.730   1.198\n', '    2G      BB2    8   2.121   7.803   1.344\n', '    2G      BB3    9   1.918   7.965   1.390\n', '    2G     GSC1   10   2.117   8.104   1.609\n', '    2G     GSC2   11   1.973   8.300   1.782\n', '    2G     GSC3   12   2.247   8.386   1.747\n', '    2G     GSC4   13   2.269   8.148   1.584\n', '    3U      BB1   14   1.905   8.063   1.048\n', '    3U      BB2   15   1.764   8.261   1.274\n', '    3U      BB3   16   1.692   8.510   1.318\n', '    3U     USC1   17   2.002   8.421   1.394\n', '    3U     USC2   18   2.048   8.596   1.524\n', '    3U     USC3   19   
# ...

# %%
lines[1:5]
# Out:
# ['    1G      BB3    2   2.369   7.615   1.513\n',
#  '    1G     GSC1    3   2.414   7.814   1.772\n',
#  '    1G     GSC2    4   2.160   7.889   1.913\n',
#  '    1G     GSC3    5   2.345   8.111   1.939\n']

# %% [markdown]
# #### creating index_distance file

# %%
BB1_BB2 = []
BB2_BB3 = []
BB3_ASC1 = []
ASC2_ASC4 = []
ASC1_ASC3 = []
ASC1_ASC2 = []
ASC2_ASC3 = []
ASC3_ASC4 = []
ASC4_ASC1 = []
BB3_USC1 = []
USC1_USC2 = []
USC2_USC3 = []
USC3_USC1 = []
BB3_GSC1 = []
GSC2_GSC4 = []
GSC1_GSC3 = []
GSC1_GSC2 = []
GSC2_GSC3 = []
GSC3_GSC4 = []
GSC4_GSC1 = []
BB3_CSC1 = []
CSC1_CSC2 = []
CSC2_CSC3 = []
CSC3_CSC1 = []
BB3_pBB1 = []


BB1_BB2_BB3 = []
BB2_BB3_ASC1 = []
BB3_ASC1_ASC2 = []
BB3_ASC1_ASC4 = []
ASC1_ASC2_ASC3 = []
ASC2_ASC1_ASC4 = []
ASC2_ASC3_ASC4 = []
ASC3_ASC4_ASC1 = []
BB2_BB3_USC1 = []
BB3_USC1_USC2 = []
BB3_USC1_USC3 = []
USC1_USC2_USC3 = []
USC2_USC1_USC3 = []
USC2_USC3_USC1 = []
BB2_BB3_GSC1 = []
BB3_GSC1_GSC2 = []
BB3_GSC1_GSC4 = []
GSC1_GSC2_GSC3 = []
GSC2_GSC1_GSC4 = []
GSC2_GSC3_GSC4 = []
GSC3_GSC4_GSC1 = []
BB2_BB3_CSC1 = []
BB3_CSC1_CSC2 = []
BB3_CSC1_CSC3 = []
CSC1_CSC2_CSC3 = []
CSC2_CSC1_CSC3 = []
CSC2_CSC3_CSC1 = []
BB2_BB3_pBB1 = []
BB3_pBB1_pBB2 = []
ASC1_BB3_pBB1 = []
USC1_BB3_pBB1 = []
GSC1_BB3_pBB1 = []
CSC1_BB3_pBB1 = []
BB1_BB2_BB3_pBB1 = []
BB2_BB3_pBB1_pBB2 = []
BB3_BB1_BB2_pBB3 = []
BB3_pBB1_pBB2_pBB3 = []


BB1_BB2_BB3_ASC1 = []
BB2_BB3_ASC1_ASC2 = []
BB2_BB3_ASC1_ASC4 = []
ASC1_ASC2_ASC3_ASC4 = []
BB1_BB2_BB3_USC1 = []
BB2_BB3_USC1_USC2 = []
BB2_BB3_USC1_USC3 = []
BB1_BB2_BB3_GSC1 = []
BB2_BB3_GSC1_GSC2 = []
BB2_BB3_GSC1_GSC4 = []
GSC1_GSC2_GSC3_GSC4 = []
BB1_BB2_BB3_CSC1 = []
BB2_BB3_CSC1_CSC2 = []
BB2_BB3_CSC1_CSC3 = []

# %%
#distance indexes
for i in range(0,len(lines)):
    try:
        line_elements = lines[i].split()
        if(lines[i].split()[1] == "BB1" and lines[i+1].split()[1] == "BB2"):
            BB1_BB2.append(lines[i].split()[2] + " " + lines[i+1].split()[2])
        if(lines[i].split()[1] == "BB2" and lines[i+1].split()[1] == "BB3"):
            BB2_BB3.append(lines[i].split()[2] + " " + lines[i+1].split()[2])
        if(lines[i].split()[1] == "BB3" and lines[i+1].split()[1] == "ASC1"):
            BB3_ASC1.append(lines[i].split()[2] + " " + lines[i+1].split()[2])
        if(lines[i].split()[1] == "ASC2" and lines[i+2].split()[1] == "ASC4"):
            ASC2_ASC4.append(lines[i].split()[2] + " " + lines[i+2].split()[2])
        if(lines[i].split()[1] == "ASC1" and lines[i+2].split()[1] == "ASC3"):
            ASC1_ASC3.append(lines[i].split()[2] + " " + lines[i+2].split()[2])
        if(lines[i].split()[1] == "ASC1" and lines[i+1].split()[1] == "ASC2"):
            ASC1_ASC2.append(lines[i].split()[2] + " " + lines[i+1].split()[2])
        if(lines[i].split()[1] == "ASC2" and lines[i+1].split()[1] == "ASC3"):
            ASC2_ASC3.append(lines[i].split()[2] + " " + lines[i+1].split()[2])
        if(lines[i].split()[1] == "ASC3" and lines[i+1].split()[1] == "ASC4"):
            ASC3_ASC4.append(lines[i].split()[2] + " " + lines[i+1].split()[2])
        if(lines[i].split()[1] == "ASC1" and lines[i+3].split()[1] == "ASC4"):
            ASC4_ASC1.append(lines[i].split()[2] + " " + lines[i+3].split()[2])

        if(lines[i].split()[1] == "BB3" and lines[i+1].split()[1] == "USC1"):
            BB3_USC1.append(lines[i].split()[2] + " " + lines[i+1].split()[2])
        if(lines[i].split()[1] == "USC1" and lines[i+1].split()[1] == "USC2"):
            USC1_USC2.append(lines[i].split()[2] + " " + lines[i+1].split()[2])
        if(lines[i].split()[1] == "USC2" and lines[i+1].split()[1] == "USC3"):
            USC2_USC3.append(lines[i].split()[2] + " " + lines[i+1].split()[2])
        if(lines[i].split()[1] == "USC1" and lines[i+2].split()[1] == "USC3"):
            USC3_USC1.append(lines[i].split()[2] + " " + lines[i+2].split()[2]) 

        if(lines[i].split()[1] == "BB3" and lines[i+1].split()[1] == "GSC1"):
            BB3_GSC1.append(lines[i].split()[2] + " " + lines[i+1].split()[2])
        if(lines[i].split()[1] == "GSC2" and lines[i+2].split()[1] == "GSC4"):
            GSC2_GSC4.append(lines[i].split()[2] + " " + lines[i+2].split()[2])
        if(lines[i].split()[1] == "GSC1" and lines[i+2].split()[1] == "GSC3"):
            GSC1_GSC3.append(lines[i].split()[2] + " " + lines[i+2].split()[2])
        if(lines[i].split()[1] == "GSC1" and lines[i+1].split()[1] == "GSC2"):
            GSC1_GSC2.append(lines[i].split()[2] + " " + lines[i+1].split()[2])
        if(lines[i].split()[1] == "GSC2" and lines[i+1].split()[1] == "GSC3"):
            GSC2_GSC3.append(lines[i].split()[2] + " " + lines[i+1].split()[2])
        if(lines[i].split()[1] == "GSC3" and lines[i+1].split()[1] == "GSC4"):
            GSC3_GSC4.append(lines[i].split()[2] + " " + lines[i+1].split()[2])
        if(lines[i].split()[1] == "GSC1" and lines[i+3].split()[1] == "GSC4"):
            GSC4_GSC1.append(lines[i].split()[2] + " " + lines[i+3].split()[2])

        if(lines[i].split()[1] == "BB3" and lines[i+1].split()[1] == "CSC1"):
            BB3_CSC1.append(lines[i].split()[2] + " " + lines[i+1].split()[2])
        if(lines[i].split()[1] == "CSC1" and lines[i+1].split()[1] == "CSC2"):
            CSC1_CSC2.append(lines[i].split()[2] + " " + lines[i+1].split()[2])
        if(lines[i].split()[1] == "CSC2" and lines[i+1].split()[1] == "CSC3"):
            CSC2_CSC3.append(lines[i].split()[2] + " " + lines[i+1].split()[2])
        if(lines[i].split()[1] == "CSC1" and lines[i+2].split()[1] == "CSC3"):
            CSC3_CSC1.append(lines[i].split()[2] + " " + lines[i+2].split()[2]) 

        #for U and C
        if(lines[i].split()[1] == "BB3" and lines[i+4].split()[1] == "BB1"):
            BB3_pBB1.append(lines[i].split()[2] + " " + lines[i+4].split()[2])
        #for A and G
        if(lines[i].split()[1] == "BB3" and lines[i+5].split()[1] == "BB1"):
            BB3_pBB1.append(lines[i].split()[2] + " " + lines[i+5].split()[2]) 
    except Exception as e:
        print(e)
        continue
    #         BB3_pBB1
# Out:
# list index out of range

# %%
BB3_pBB1
# Out:
# ['2 7',
#  '9 14',
#  '16 20',
#  '22 27',
#  '29 34',
#  '36 41',
#  '43 47',
#  '49 54',
#  '56 60',
#  '62 66',
#  '73 78',
#  '80 85',
#  '87 91',
#  '93 97',
#  '99 104',
#  '106 111',
#  '113 118',
#  '120 125',
#  '127 132',
#  '134 138',
#  '145 150',
#  '152 157',
#  '159 163',
#  '165 169',
#  '171 175',
#  '177 181',
#  '183 187',
#  '189 194',
#  '196 201',
#  '203 207',
#  '209 213',
#  '215 220',
#  '222 227',
#  '229 234',
#  '236 240',
#  '242 247',
#  '249 253',
#  '255 259',
#  '261 265',
#  '267 272',
#  '274 278',
#  '280 284',
#  '286 291']

# %%
#angle indexes
for i in range(0,len(lines)):
    try:
        line_elements = lines[i].split()
        if(lines[i].split()[1] == "BB1" and lines[i+1].split()[1] == "BB2" and lines[i+2].split()[1] == "BB3"):
            BB1_BB2_BB3.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " +lines[i+2].split()[2])
        if(lines[i].split()[1] == "BB2" and lines[i+1].split()[1] == "BB3" and lines[i+2].split()[1] == "ASC1"):
            BB2_BB3_ASC1.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " +lines[i+2].split()[2])
        if(lines[i].split()[1] == "BB3" and lines[i+1].split()[1] == "ASC1" and lines[i+2].split()[1] == "ASC2"):
            BB3_ASC1_ASC2.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " +lines[i+2].split()[2])

        if(lines[i].split()[1] == "BB3" and lines[i+1].split()[1] == "ASC1" and lines[i+4].split()[1] == "ASC4"):
            BB3_ASC1_ASC4.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " +lines[i+4].split()[2])
        if(lines[i].split()[1] == "ASC1" and lines[i+1].split()[1] == "ASC2" and lines[i+2].split()[1] == "ASC3"):
            ASC1_ASC2_ASC3.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " +lines[i+2].split()[2])
        if(lines[i].split()[1] == "ASC2" and lines[i-1].split()[1] == "ASC1" and lines[i+2].split()[1] == "ASC4"):
            ASC2_ASC1_ASC4.append(lines[i].split()[2] + " " + lines[i-1].split()[2] + " " +lines[i+2].split()[2])
        if(lines[i].split()[1] == "ASC2" and lines[i+1].split()[1] == "ASC3" and lines[i+2].split()[1] == "ASC4"):
            ASC2_ASC3_ASC4.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " +lines[i+2].split()[2])
        if(lines[i].split()[1] == "ASC3" and lines[i+1].split()[1] == "ASC4" and lines[i-2].split()[1] == "ASC1"):
            ASC3_ASC4_ASC1.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " +lines[i-2].split()[2])

        if(lines[i].split()[1] == "BB2" and lines[i+1].split()[1] == "BB3" and lines[i+2].split()[1] == "USC1"):
            BB2_BB3_USC1.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " +lines[i+2].split()[2])
        if(lines[i].split()[1] == "BB3" and lines[i+1].split()[1] == "USC1" and lines[i+2].split()[1] == "USC2"):
            BB3_USC1_USC2.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " +lines[i+2].split()[2])
        if(lines[i].split()[1] == "BB3" and lines[i+1].split()[1] == "USC1" and lines[i+3].split()[1] == "USC3"):
            BB3_USC1_USC3.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " +lines[i+3].split()[2])
        if(lines[i].split()[1] == "USC1" and lines[i+1].split()[1] == "USC2" and lines[i+2].split()[1] == "USC3"):
            USC1_USC2_USC3.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " +lines[i+2].split()[2])
        if(lines[i].split()[1] == "USC2" and lines[i-1].split()[1] == "USC1" and lines[i+1].split()[1] == "USC3"):
            USC2_USC1_USC3.append(lines[i].split()[2] + " " + lines[i-1].split()[2] + " " +lines[i+1].split()[2])
        if(lines[i].split()[1] == "USC2" and lines[i+1].split()[1] == "USC3" and lines[i-1].split()[1] == "USC1"):
            USC2_USC3_USC1.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " +lines[i-1].split()[2])

        if(lines[i].split()[1] == "BB2" and lines[i+1].split()[1] == "BB3" and lines[i+2].split()[1] == "GSC1"):
            BB2_BB3_GSC1.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " +lines[i+2].split()[2])
        if(lines[i].split()[1] == "BB3" and lines[i+1].split()[1] == "GSC1" and lines[i+2].split()[1] == "GSC2"):
            BB3_GSC1_GSC2.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " +lines[i+2].split()[2])
        if(lines[i].split()[1] == "BB3" and lines[i+1].split()[1] == "GSC1" and lines[i+4].split()[1] == "GSC4"):
            BB3_GSC1_GSC4.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " +lines[i+4].split()[2])
        if(lines[i].split()[1] == "GSC1" and lines[i+1].split()[1] == "GSC2" and lines[i+2].split()[1] == "GSC3"):
            GSC1_GSC2_GSC3.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " +lines[i+2].split()[2])
        if(lines[i].split()[1] == "GSC2" and lines[i-1].split()[1] == "GSC1" and lines[i+2].split()[1] == "GSC4"):
            GSC2_GSC1_GSC4.append(lines[i].split()[2] + " " + lines[i-1].split()[2] + " " +lines[i+2].split()[2])
        if(lines[i].split()[1] == "GSC2" and lines[i+1].split()[1] == "GSC3" and lines[i+2].split()[1] == "GSC4"):
            GSC2_GSC3_GSC4.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " +lines[i+2].split()[2])
        if(lines[i].split()[1] == "GSC3" and lines[i+1].split()[1] == "GSC4" and lines[i-2].split()[1] == "GSC1"):
            GSC3_GSC4_GSC1.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " +lines[i-2].split()[2])

        if(lines[i].split()[1] == "BB2" and lines[i+1].split()[1] == "BB3" and lines[i+2].split()[1] == "CSC1"):
            BB2_BB3_CSC1.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " +lines[i+2].split()[2])
        if(lines[i].split()[1] == "BB3" and lines[i+1].split()[1] == "CSC1" and lines[i+2].split()[1] == "CSC2"):
            BB3_CSC1_CSC2.append(lines[i].split()[2] + " " + lines[i+1].split()[2] +" " +lines[i+2].split()[2])
        if(lines[i].split()[1] == "BB3" and lines[i+1].split()[1] == "CSC1" and lines[i+3].split()[1] == "CSC3"):
            BB3_CSC1_CSC3.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " +lines[i+3].split()[2])
        if(lines[i].split()[1] == "CSC1" and lines[i+1].split()[1] == "CSC2" and lines[i+2].split()[1] == "CSC3"):
            CSC1_CSC2_CSC3.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " +lines[i+2].split()[2])
        if(lines[i].split()[1] == "CSC2" and lines[i-1].split()[1] == "CSC1" and lines[i+1].split()[1] == "CSC3"):
            CSC2_CSC1_CSC3.append(lines[i].split()[2] + " " + lines[i-1].split()[2] + " " +lines[i+1].split()[2])
        if(lines[i].split()[1] == "CSC2" and lines[i+1].split()[1] == "CSC3" and lines[i-1].split()[1] == "CSC1"):
            CSC2_CSC3_CSC1.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " +lines[i-1].split()[2])

        #for U and C
        if(lines[i].split()[1] == "BB2" and lines[i+1].split()[1] == "BB3" and 
           lines[i+5].split()[1] == "BB1"):
            BB2_BB3_pBB1.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " +lines[i+5].split()[2])

        if(lines[i].split()[1] == "BB3" and lines[i+4].split()[1] == "BB1" and 
           lines[i+5].split()[1] == "BB2"):
            BB3_pBB1_pBB2.append(lines[i].split()[2] + " " + lines[i+4].split()[2] + " " +lines[i+5].split()[2])

        #for A and G
        if(lines[i].split()[1] == "BB2" and lines[i+1].split()[1] == "BB3" and 
           lines[i+6].split()[1] == "BB1"):
            BB2_BB3_pBB1.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " +lines[i+6].split()[2])

        if(lines[i].split()[1] == "BB3" and lines[i+5].split()[1] == "BB1" and 
           lines[i+6].split()[1] == "BB2"):
            BB3_pBB1_pBB2.append(lines[i].split()[2] + " " + lines[i+5].split()[2] + " " +lines[i+6].split()[2])

        if(lines[i].split()[1] == "ASC1" and lines[i-1].split()[1] == "BB3" and 
           lines[i+4].split()[1] == "BB1"):
            ASC1_BB3_pBB1.append(lines[i].split()[2] + " " + lines[i-1].split()[2] + " " +lines[i+4].split()[2])

        if(lines[i].split()[1] == "GSC1" and lines[i-1].split()[1] == "BB3" and 
           lines[i+4].split()[1] == "BB1"):
            GSC1_BB3_pBB1.append(lines[i].split()[2] + " " + lines[i-1].split()[2] + " " +lines[i+4].split()[2])

        if(lines[i].split()[1] == "USC1" and lines[i-1].split()[1] == "BB3" and 
           lines[i+3].split()[1] == "BB1"):
            USC1_BB3_pBB1.append(lines[i].split()[2] + " " + lines[i-1].split()[2] + " " +lines[i+3].split()[2])

        if(lines[i].split()[1] == "CSC1" and lines[i-1].split()[1] == "BB3" and 
           lines[i+3].split()[1] == "BB1"):
            CSC1_BB3_pBB1.append(lines[i].split()[2] + " " + lines[i-1].split()[2] + " " +lines[i+3].split()[2])

    except Exception as e:
        print(e)
        continue
# Out:
# list index out of range
# list index out of range
# list index out of range

# %%
#dihedral indices
for i in range(0,len(lines)):
    try:
        line_elements = lines[i].split()
        if(lines[i].split()[1] == "BB1" and lines[i+1].split()[1] == "BB2" and lines[i+2].split()[1] == "BB3" and lines[i+3].split()[1] == "ASC1" ):
            BB1_BB2_BB3_ASC1.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " +lines[i+2].split()[2] + " " +lines[i+3].split()[2])
        if(lines[i].split()[1] == "BB2" and lines[i+1].split()[1] == "BB3" and lines[i+2].split()[1] == "ASC1" and lines[i+3].split()[1] == "ASC2" ):
            BB2_BB3_ASC1_ASC2.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " +lines[i+2].split()[2] + " " +lines[i+3].split()[2])
        if(lines[i].split()[1] == "BB2" and lines[i+1].split()[1] == "BB3" and lines[i+2].split()[1] == "ASC1" and lines[i+3].split()[1] == "ASC4" ):
            BB2_BB3_ASC1_ASC4.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " +lines[i+2].split()[2] + " " +lines[i+3].split()[2])

        if(lines[i].split()[1] == "ASC1" and lines[i+1].split()[1] == "ASC2" and lines[i+2].split()[1] == "ASC3" and lines[i+3].split()[1] == "ASC4" ):
            ASC1_ASC2_ASC3_ASC4.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " +lines[i+2].split()[2] + " " +lines[i+3].split()[2])
        if(lines[i].split()[1] == "BB1" and lines[i+1].split()[1] == "BB2" and lines[i+2].split()[1] == "BB3" and lines[i+3].split()[1] == "USC1" ):
            BB1_BB2_BB3_USC1.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " +lines[i+2].split()[2] + " " +lines[i+3].split()[2])
        if(lines[i].split()[1] == "BB2" and lines[i+1].split()[1] == "BB3" and lines[i+2].split()[1] == "USC1" and lines[i+3].split()[1] == "USC2" ):
            BB2_BB3_USC1_USC2.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " +lines[i+2].split()[2] + " " +lines[i+3].split()[2])
        if(lines[i].split()[1] == "BB2" and lines[i+1].split()[1] == "BB3" and 
           lines[i+2].split()[1] == "USC1" and lines[i+4].split()[1] == "USC3" ):
            BB2_BB3_USC1_USC3.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " 
                                     +lines[i+2].split()[2] + " " +lines[i+4].split()[2])
        if(lines[i].split()[1] == "BB1" and lines[i+1].split()[1] == "BB2" and lines[i+2].split()[1] == "BB3" and lines[i+3].split()[1] == "GSC1" ):
            BB1_BB2_BB3_GSC1.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " +lines[i+2].split()[2] + " " +lines[i+3].split()[2])
        if(lines[i].split()[1] == "BB2" and lines[i+1].split()[1] == "BB3" and lines[i+2].split()[1] == "GSC1" and lines[i+3].split()[1] == "GSC2" ):
            BB2_BB3_GSC1_GSC2.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " +lines[i+2].split()[2] + " " +lines[i+3].split()[2])

        if(lines[i].split()[1] == "BB2" and lines[i+1].split()[1] == "BB3" and lines[i+2].split()[1] == "GSC1" and lines[i+5].split()[1] == "GSC4" ):
            BB2_BB3_GSC1_GSC4.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " +lines[i+2].split()[2] + " " +lines[i+5].split()[2])    
        if(lines[i].split()[1] == "GSC1" and lines[i+1].split()[1] == "GSC2" and lines[i+2].split()[1] == "GSC3" and lines[i+3].split()[1] == "GSC4" ):
            GSC1_GSC2_GSC3_GSC4.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " +lines[i+2].split()[2] + " " +lines[i+3].split()[2])

        if(lines[i].split()[1] == "BB1" and lines[i+1].split()[1] == "BB2" and lines[i+2].split()[1] == "BB3" and lines[i+3].split()[1] == "CSC1" ):
            BB1_BB2_BB3_CSC1.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " +lines[i+2].split()[2] + " " +lines[i+3].split()[2])
        if(lines[i].split()[1] == "BB2" and lines[i+1].split()[1] == "BB3" and lines[i+2].split()[1] == "CSC1" and lines[i+3].split()[1] == "CSC2" ):
            BB2_BB3_CSC1_CSC2.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " +lines[i+2].split()[2] + " " +lines[i+3].split()[2])
        if(lines[i].split()[1] == "BB2" and lines[i+1].split()[1] == "BB3" and 
           lines[i+2].split()[1] == "CSC1" and lines[i+4].split()[1] == "CSC3" ):
            BB2_BB3_CSC1_CSC3.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " +
                                     lines[i+2].split()[2] + " " +lines[i+4].split()[2])
    # for U and C
        if(lines[i].split()[1] == "BB1" and lines[i+1].split()[1] == "BB2" and 
           lines[i+2].split()[1] == "BB3" and lines[i+6].split()[1] == "BB1" ):
            BB1_BB2_BB3_pBB1.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " +
                                     lines[i+2].split()[2] + " " +lines[i+6].split()[2])

        if(lines[i].split()[1] == "BB2" and lines[i+1].split()[1] == "BB3" and 
           lines[i+5].split()[1] == "BB1" and lines[i+6].split()[1] == "BB2" ):
            BB2_BB3_pBB1_pBB2.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " +
                                     lines[i+5].split()[2] + " " +lines[i+6].split()[2])
        if(lines[i].split()[1] == "BB3" and lines[i+4].split()[1] == "BB1" and 
           lines[i+5].split()[1] == "BB2" and lines[i+6].split()[1] == "BB3" ):
            BB3_pBB1_pBB2_pBB3.append(lines[i].split()[2] + " " + lines[i+4].split()[2] + " " +
                                     lines[i+5].split()[2] + " " +lines[i+6].split()[2])

        # for A and G
        if(lines[i].split()[1] == "BB1" and lines[i+1].split()[1] == "BB2" and 
           lines[i+2].split()[1] == "BB3" and lines[i+7].split()[1] == "BB1" ):
            BB1_BB2_BB3_pBB1.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " +
                                     lines[i+2].split()[2] + " " +lines[i+7].split()[2])

        if(lines[i].split()[1] == "BB2" and lines[i+1].split()[1] == "BB3" and 
           lines[i+6].split()[1] == "BB1" and lines[i+7].split()[1] == "BB2" ):
            BB2_BB3_pBB1_pBB2.append(lines[i].split()[2] + " " + lines[i+1].split()[2] + " " +
                                     lines[i+6].split()[2] + " " +lines[i+7].split()[2])
        if(lines[i].split()[1] == "BB3" and lines[i+5].split()[1] == "BB1" and 
           lines[i+6].split()[1] == "BB2" and lines[i+7].split()[1] == "BB3" ):
            BB3_pBB1_pBB2_pBB3.append(lines[i].split()[2] + " " + lines[i+5].split()[2] + " " +
                                     lines[i+6].split()[2] + " " +lines[i+7].split()[2])
    except Exception as e:
        print(e)
        continue
# Out:
# list index out of range
# list index out of range
# list index out of range

# %%
with open(path+filename+"_index_distance.ndx","w") as f:
    f.write("[BB1_BB2]"+"\n")
    for i in BB1_BB2:
        f.write(i+"\n")
    
    f.write("[BB2_BB3]"+"\n")
    for i in BB2_BB3:
        f.write(i+"\n")
        
    f.write("[BB3_ASC1]"+"\n")
    for i in BB3_ASC1:
        f.write(i+"\n")
    
    f.write("[ASC2_ASC4]"+"\n")
    for i in ASC2_ASC4:
        f.write(i+"\n")
    
    f.write("[ASC1_ASC3]"+"\n")
    for i in ASC1_ASC3:
        f.write(i+"\n")
        
    f.write("[ASC1_ASC2]"+"\n")
    for i in ASC1_ASC2:
        f.write(i+"\n")
    
            
    f.write("[ASC2_ASC3]"+"\n")
    for i in ASC2_ASC3:
        f.write(i+"\n")
    
    f.write("[ASC3_ASC4]"+"\n")
    for i in ASC3_ASC4:
        f.write(i+"\n")
    
    f.write("[ASC4_ASC1]"+"\n")
    for i in ASC4_ASC1:
        f.write(i+"\n")
  
    f.write("[BB3_USC1]"+"\n")
    for i in BB3_USC1:
        f.write(i+"\n")
    
    f.write("[USC1_USC2]"+"\n")
    for i in USC1_USC2:
        f.write(i+"\n")
    
    f.write("[USC2_USC3]"+"\n")
    for i in USC2_USC3:
        f.write(i+"\n")
    
    f.write("[USC3_USC1]"+"\n")
    for i in USC3_USC1:
        f.write(i+"\n")
    
            
    f.write("[BB3_GSC1]"+"\n")
    for i in BB3_GSC1:
        f.write(i+"\n")
    
    f.write("[GSC2_GSC4]"+"\n")
    for i in GSC2_GSC4:
        f.write(i+"\n")
    
    f.write("[GSC1_GSC3]"+"\n")
    for i in GSC1_GSC3:
        f.write(i+"\n")
        
    f.write("[GSC1_GSC2]"+"\n")
    for i in GSC1_GSC2:
        f.write(i+"\n")
            
    f.write("[GSC2_GSC3]"+"\n")
    for i in GSC2_GSC3:
        f.write(i+"\n")
    
    f.write("[GSC3_GSC4]"+"\n")
    for i in GSC3_GSC4:
        f.write(i+"\n")
    
    f.write("[GSC4_GSC1]"+"\n")
    for i in GSC4_GSC1:
        f.write(i+"\n")
    
    f.write("[BB3_CSC1]"+"\n")
    for i in BB3_CSC1:
        f.write(i+"\n")
    
    f.write("[CSC1_CSC2]"+"\n")
    for i in CSC1_CSC2:
        f.write(i+"\n")
    
    f.write("[CSC2_CSC3]"+"\n")
    for i in CSC2_CSC3:
        f.write(i+"\n")
    
    f.write("[CSC3_CSC1]"+"\n")
    for i in CSC3_CSC1:
        f.write(i+"\n")

#     f.write("[BB3_pBB1]" + "\n")
    f.write("[BB3_pBB1]"+"\n")
    for i in BB3_pBB1:
        f.write(i+"\n")

# %%
with open(path+filename+"_index_angle.ndx","w") as f:
    
    f.write("[BB1_BB2_BB3]"+"\n")
    for i in BB1_BB2_BB3:
        f.write(i+"\n")
    
    f.write("[BB2_BB3_ASC1]"+"\n")
    for i in BB2_BB3_ASC1:
        f.write(i+"\n")
    
    f.write("[BB3_ASC1_ASC2]"+"\n")
    for i in BB3_ASC1_ASC2:
        f.write(i+"\n")
    
    f.write("[BB3_ASC1_ASC4]"+"\n")
    for i in BB3_ASC1_ASC4:
        f.write(i+"\n")
    
    f.write("[ASC1_ASC2_ASC3]"+"\n")
    for i in ASC1_ASC2_ASC3:
        f.write(i+"\n")
    
    f.write("[ASC2_ASC1_ASC4]"+"\n")
    for i in ASC2_ASC1_ASC4:
        f.write(i+"\n")
    
    f.write("[ASC2_ASC3_ASC4]"+"\n")
    for i in ASC2_ASC3_ASC4:
        f.write(i+"\n")
    
    f.write("[ASC3_ASC4_ASC1]"+"\n")
    for i in ASC3_ASC4_ASC1:
        f.write(i+"\n")
    
    f.write("[BB2_BB3_USC1]"+"\n")
    for i in BB2_BB3_USC1:
        f.write(i+"\n")
    
    f.write("[BB3_USC1_USC2]"+"\n")
    for i in BB3_USC1_USC2:
        f.write(i+"\n")
    
    f.write("[BB3_USC1_USC3]"+"\n")
    for i in BB3_USC1_USC3:
        f.write(i+"\n")
    
    f.write("[USC1_USC2_USC3]"+"\n")
    for i in USC1_USC2_USC3:
        f.write(i+"\n")
    
    f.write("[USC2_USC1_USC3]"+"\n")
    for i in USC2_USC1_USC3:
        f.write(i+"\n")
    
    f.write("[USC2_USC3_USC1]"+"\n")
    for i in USC2_USC3_USC1:
        f.write(i+"\n")
    
    f.write("[BB2_BB3_GSC1]"+"\n")
    for i in BB2_BB3_GSC1:
        f.write(i+"\n")
    
    f.write("[BB3_GSC1_GSC2]"+"\n")
    for i in BB3_GSC1_GSC2:
        f.write(i+"\n")

    f.write("[BB3_GSC1_GSC4]"+"\n")
    for i in BB3_GSC1_GSC4:
        f.write(i+"\n")
    
    f.write("[GSC1_GSC2_GSC3]"+"\n")
    for i in GSC1_GSC2_GSC3:
        f.write(i+"\n")   
    
    f.write("[GSC2_GSC1_GSC4]"+"\n")
    for i in GSC2_GSC1_GSC4:
        f.write(i+"\n")
    
    f.write("[GSC2_GSC3_GSC4]"+"\n")
    for i in GSC2_GSC3_GSC4:
        f.write(i+"\n")
    
    f.write("[GSC3_GSC4_GSC1]"+"\n")
    for i in GSC3_GSC4_GSC1:
        f.write(i+"\n")
    
    f.write("[BB2_BB3_CSC1]"+"\n")
    for i in BB2_BB3_CSC1:
        f.write(i+"\n")
    
    f.write("[BB3_CSC1_CSC2]"+"\n")
    for i in BB3_CSC1_CSC2:
        f.write(i+"\n")
    
    f.write("[BB3_CSC1_CSC3]"+"\n")
    for i in BB3_CSC1_CSC3:
        f.write(i+"\n")
    
    f.write("[CSC1_CSC2_CSC3]"+"\n")
    for i in CSC1_CSC2_CSC3:
        f.write(i+"\n")
    
    f.write("[CSC2_CSC1_CSC3]"+"\n")
    for i in CSC2_CSC1_CSC3:
        f.write(i+"\n")
    
    f.write("[CSC2_CSC3_CSC1]"+"\n")
    for i in CSC2_CSC3_CSC1:
        f.write(i+"\n")
    
    f.write("[BB2_BB3_pBB1]"+"\n")
    for i in BB2_BB3_pBB1:
        f.write(i+"\n")
        
    f.write("[BB3_pBB1_pBB2]"+"\n")
    for i in BB3_pBB1_pBB2:
        f.write(i+"\n")
    
    f.write("[ASC1_BB3_pBB1]"+"\n")
    for i in ASC1_BB3_pBB1:
        f.write(i+"\n")
    
    f.write("[USC1_BB3_pBB1]"+"\n")
    for i in USC1_BB3_pBB1:
        f.write(i+"\n")
    
    f.write("[GSC1_BB3_pBB1]"+"\n")
    for i in GSC1_BB3_pBB1:
        f.write(i+"\n")
    
    f.write("[CSC1_BB3_pBB1]"+"\n")
    for i in CSC1_BB3_pBB1:
        f.write(i+"\n")

# %%
with open(path+filename+"_index_dihedral.ndx","w") as f:
    
    f.write("[BB1_BB2_BB3_ASC1]"+"\n")
    for i in BB1_BB2_BB3_ASC1:
        f.write(i+"\n")
    
    f.write("[BB2_BB3_ASC1_ASC2]"+"\n")
    for i in BB2_BB3_ASC1_ASC2:
        f.write(i+"\n")
    
    f.write("[BB2_BB3_ASC1_ASC4]"+"\n")
    for i in BB2_BB3_ASC1_ASC4:
        f.write(i+"\n")
    
    f.write("[ASC1_ASC2_ASC3_ASC4]"+"\n")
    for i in ASC1_ASC2_ASC3_ASC4:
        f.write(i+"\n")
    
    f.write("[BB1_BB2_BB3_USC1]"+"\n")
    for i in BB1_BB2_BB3_USC1:
        f.write(i+"\n")
    
    f.write("[BB2_BB3_USC1_USC2]"+"\n")
    for i in BB2_BB3_USC1_USC2:
        f.write(i+"\n")
    
    f.write("[BB2_BB3_USC1_USC3]"+"\n")
    for i in BB2_BB3_USC1_USC3:
        f.write(i+"\n")
    
    f.write("[BB1_BB2_BB3_GSC1]"+"\n")
    for i in BB1_BB2_BB3_GSC1:
        f.write(i+"\n")
    
    f.write("[BB2_BB3_GSC1_GSC2]"+"\n")
    for i in BB2_BB3_GSC1_GSC2:
        f.write(i+"\n")
    
    f.write("[BB2_BB3_GSC1_GSC4]"+"\n")
    for i in BB2_BB3_GSC1_GSC4:
        f.write(i+"\n")
    
    f.write("[GSC1_GSC2_GSC3_GSC4]"+"\n")
    for i in GSC1_GSC2_GSC3_GSC4:
        f.write(i+"\n")
    
    f.write("[BB1_BB2_BB3_CSC1]"+"\n")
    for i in BB1_BB2_BB3_CSC1:
        f.write(i+"\n")
    
    f.write("[BB2_BB3_CSC1_CSC2]"+"\n")
    for i in BB2_BB3_CSC1_CSC2:
        f.write(i+"\n")
    
    f.write("[BB2_BB3_CSC1_CSC3]"+"\n")
    for i in BB2_BB3_CSC1_CSC3:
        f.write(i+"\n")
    
        
    f.write("[BB1_BB2_BB3_pBB1]"+"\n")
    for i in BB1_BB2_BB3_pBB1:
        f.write(i+"\n")
    
    f.write("[BB2_BB3_pBB1_pBB2]"+"\n")
    for i in BB2_BB3_pBB1_pBB2:
        f.write(i+"\n")
    
    f.write("[BB3_pBB1_pBB2_pBB3]"+"\n")
    for i in BB3_pBB1_pBB2_pBB3:
        f.write(i+"\n")
